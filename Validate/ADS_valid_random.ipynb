# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import copy
import math
import random

from collections import deque
# Out:
# 2025-05-02 15:36:24.740599: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-02 15:36:24.740629: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-02 15:36:24.741501: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-02 15:36:24.749249: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-02 15:36:25.604413: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
batch_size = 256
l_rate = 0.001

# %%
@tf.keras.utils.register_keras_serializable()
class MLP(tf.keras.Model):
    def __init__(self, trainable=True, dtype=None, **kwargs):
        super().__init__(trainable=trainable, dtype=dtype, **kwargs)
        self.dense1 = tf.keras.layers.Dense(units=512, activation=tf.nn.leaky_relu)
        self.dense2 = tf.keras.layers.Dense(units=1024, activation=tf.nn.leaky_relu)
        self.dense3 = tf.keras.layers.Dense(units=512, activation=tf.nn.leaky_relu)
        self.dense4 = tf.keras.layers.Dense(units=256, activation=tf.nn.leaky_relu)
        self.dense5 = tf.keras.layers.Dense(units=8)

    def get_config(self):
        config = super().get_config()
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        output = self.dense5(x)
        return output

# %%
class ParaServer:
    def __init__(self):
        self.model = MLP()
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=l_rate)
        self.freqs = {}
        test_dataset = pd.read_csv("Test.csv", encoding='utf-8').sample(frac=1).reset_index(drop=True)
        self.X_v_all = test_dataset.loc[:,'freq':'L4'].to_numpy(dtype = np.float32) 
        self.y_v_all = test_dataset.loc[:,'S11r':'S41i'].to_numpy(dtype = np.float32)

        test_dataset_24 = test_dataset[test_dataset['freq'] == 2.4]
        test_dataset_25 = test_dataset[test_dataset['freq'] == 2.5]
        test_dataset_26 = test_dataset[test_dataset['freq'] == 2.6]
        self.X_v = {}
        self.y_v = {}
        self.X_v[2.4] = test_dataset_24.loc[:,'freq':'L4'].to_numpy(dtype = np.float32)
        self.y_v[2.4] = test_dataset_24.loc[:,'S11r':'S41i'].to_numpy(dtype = np.float32)
        self.X_v[2.5] = test_dataset_25.loc[:,'freq':'L4'].to_numpy(dtype = np.float32)
        self.y_v[2.5] = test_dataset_25.loc[:,'S11r':'S41i'].to_numpy(dtype = np.float32)
        self.X_v[2.6] = test_dataset_26.loc[:,'freq':'L4'].to_numpy(dtype = np.float32)
        self.y_v[2.6] = test_dataset_26.loc[:,'S11r':'S41i'].to_numpy(dtype = np.float32)
        
        self.r2sv = []
        self.model(self.X_v_all)

        self.node_mse_his = {}
        self.node_grad_norm_his = {}


        self.node_A = {2.4: 0, 2.5: 0, 2.6: 0}
        self.node_D = {2.4: 0, 2.5: 0, 2.6: 0}
        
        self.Dic_A = {2.4: 'A', 2.5: 'B', 2.6: 'C'}
        self.Dic_D = {2.4: 'a', 2.5: 'b', 2.6: 'c'}

        self.TP = 0
        self.TN = 0
        self.FP = 0
        self.FN = 0

    def upload(self, grads, freq, GROUNDTRUTH):
        checkpoint = tf.train.Checkpoint(model=self.model, optimizer=self.optimizer)
        save_path = checkpoint.save('./save')

        # 更新
        self.optimizer.apply_gradients(grads_and_vars=zip(grads, self.model.variables))

        after_y_v = self.model(self.X_v_all)
        after_mse = tf.reduce_mean(tf.square(after_y_v - self.y_v_all))

        poision_judge = self.check_anoymous(after_mse, grads, freq)

        if GROUNDTRUTH:
            checkpoint.restore(save_path)
            if poision_judge:
                self.TP += 1
                self.node_D[freq] += 1
            else:
                self.FN += 1
                self.node_D[freq] += 1
        else:
            if poision_judge:
                self.FP += 1
                self.node_A[freq] += 1
            else:
                self.TN += 1
                self.node_A[freq] += 1
                
        cur_y_v = self.model(self.X_v[freq])
        score = 1 - tf.reduce_sum(tf.square(cur_y_v - self.y_v[freq])) / tf.reduce_sum(tf.square(self.y_v[freq] - tf.reduce_mean(self.y_v[freq])))

        self.freqs[freq] = max(0, score)

        return self.model, self.freqs
    
    def download(self):
        return self.model, self.freqs

    def lr_decay(self, ratio):
        self.optimizer.learning_rate = self.optimizer.learning_rate * ratio

    def check_anoymous(self, cur_mse, cur_grad, nodeId):
        # 检查MSE异常
        if nodeId not in self.node_mse_his:
            self.node_mse_his[nodeId] = deque(maxlen=16)
        if len(self.node_mse_his[nodeId]) < 16:
            is_mse_anomaly = False
        else:
            mse_mean = np.mean(self.node_mse_his[nodeId])
            mse_std = np.std(self.node_mse_his[nodeId])
            mse_threshold = mse_mean + 3 * mse_std
            is_mse_anomaly = cur_mse > mse_threshold
        

        # 检查梯度异常
        grad_vector = tf.concat([tf.reshape(g, [-1]) for g in cur_grad], axis=0)
        grad_norm = np.linalg.norm(grad_vector)
        if nodeId not in self.node_grad_norm_his:
            self.node_grad_norm_his[nodeId] = deque(maxlen=16)

        if len(self.node_grad_norm_his[nodeId]) < 16:
            is_grad_anomaly = False
        else:
            grad_mean = np.mean(self.node_grad_norm_his[nodeId])
            grad_std = np.std(self.node_grad_norm_his[nodeId])
            grad_threshold = grad_mean + 3 * grad_std
            is_grad_anomaly = grad_norm > grad_threshold

        if is_mse_anomaly and is_grad_anomaly:
            return True
        else:
            self.node_mse_his[nodeId].append(cur_mse)
            self.node_grad_norm_his[nodeId].append(grad_norm)
            return False

# %%
r2s = {2.4:[],2.5:[],2.6:[]}

# %%
ps = ParaServer()
# Out:
# 2025-05-02 15:36:28.687236: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8695 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:17:00.0, compute capability: 7.5
# 2025-05-02 15:36:28.687884: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9619 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5

# %%
# Label Poisoning
# Feature Poisoning
# Outlier Injection

# %%
class Node:
    def __init__(self, dsName, freq):
        self.freq = freq
        self.otfreqs = {}
        self.model = MLP()
        self.zeroModel = MLP()
        self.dataset = pd.read_csv(dsName, encoding='utf-8').sample(frac=1).reset_index(drop=True)
        self.X = self.dataset.loc[:,'freq':'L4'].to_numpy(dtype = np.float32)
        self.y = self.dataset.loc[:,'S11r':'S41i'].to_numpy(dtype = np.float32)
        self.dataset_train = tf.data.Dataset.from_tensor_slices((self.X, self.y))
        self.dataset_train = self.dataset_train.shuffle(buffer_size=self.X.shape[0])
        self.dataset_train = self.dataset_train.batch(batch_size)
        self.dataset_train = self.dataset_train.prefetch(tf.data.experimental.AUTOTUNE)
        self.iterator = iter(self.dataset_train)

        self.current_epoch = 0
        self.epoch_r2 = []
        self.epoch_mse = []
        self.epoch_rmse = []
        self.epoch_mae = []
        self.batch_count = 0

    def getZero(self):
        m, freqs = ps.download()
        self.otfreqs = copy.deepcopy(freqs)
        self.zeroModel = copy.deepcopy(m)
        # print(self.otfreqs)
    def train(self, index_round):
        poisioning = False
        if index_round > 300 * 112 and random.random() < 0.01:
            poisioning = True
            # print('*',end="")
            poisoned_indices = np.random.choice(len(self.X), size=batch_size, replace=False)
            posionedX = self.X[poisoned_indices].copy()
            posionedY = self.y[poisoned_indices].copy()
            epsilon = np.random.normal(0, 10, posionedY.shape)
            posionedY += epsilon
            X, y = tf.convert_to_tensor(posionedX, dtype=tf.float32), tf.convert_to_tensor(posionedY, dtype=tf.float32)
        else:
            # print('-', end="")
            try:
                X, y = next(self.iterator)
                    
            except StopIteration:
                avg_r2 = np.mean(self.epoch_r2)
                avg_mse = np.mean(self.epoch_mse)
                avg_mae = np.mean(self.epoch_mae)
                avg_rmse = np.mean(self.epoch_rmse)
                print(f"\nNode {self.freq} Epoch {self.current_epoch} Summary:")
                print(f"  MSE: {avg_mse:.4f} | RMSE: {avg_rmse:.4f}")
                print(f"  MAE: {avg_mae:.4f} | R²: {avg_r2:.4f}")
                print(f"  Anomaly Detection: {ps.node_A[self.freq]}/{ps.node_D[self.freq]}")
                print(f"  {ps.TP} | {ps.FN}")
                print(f"  {ps.FP} | {ps.TN}")
                r2s[self.freq].append(avg_r2)
                ps.node_A[self.freq], ps.node_D[self.freq] = 0, 0

                self.epoch_r2 = []
                self.epoch_mse = []
                self.epoch_mae = []
                self.epoch_rmse = []
                self.current_epoch += 1
                self.batch_count = 0

                self.dataset_train = tf.data.Dataset.from_tensor_slices((self.X, self.y))
                self.dataset_train = self.dataset_train.shuffle(buffer_size=self.X.shape[0])
                self.dataset_train = self.dataset_train.batch(batch_size)
                self.dataset_train = self.dataset_train.prefetch(tf.data.experimental.AUTOTUNE)
                self.iterator = iter(self.dataset_train)
                X, y = next(self.iterator)

        self.model, _ = ps.download()

        with tf.GradientTape() as tape:
            y_pred = self.model(X)
            tr_mse = tf.reduce_mean(tf.square(y_pred - y))

        tr_rmse = tf.sqrt(tr_mse)
        tr_mae = tf.reduce_mean(tf.abs(y_pred - y))
        tr_r2 = 1 - tf.reduce_sum(tf.square(y_pred - y)) / tf.reduce_sum(tf.square(y - tf.reduce_mean(y)))

        grads = tape.gradient(tr_mse, self.model.variables)

        sum_r2 = 1
        for k, v in self.otfreqs.items():
            if math.isclose(k, self.freq) or math.isclose(v, 0):
                continue
            X_i = tf.tensor_scatter_nd_update(X, [[i, 0] for i in range(X.shape[0])], [k] * X.shape[0])
            y_i = self.zeroModel(X_i)
            with tf.GradientTape() as tape:
                y_pred_i = self.model(X_i)
                loss = tf.reduce_mean(tf.square(y_pred_i - y_i))
            grad = tape.gradient(loss, self.model.variables)
            grads = [grads[i] + grad[i] * v for i in range(len(grads))]
            sum_r2 += v
        self.model, _ = ps.upload([i / sum_r2 for i in grads], self.freq, poisioning)

        # if epoch_index in np.arange(0, num_epochs, 25).tolist() or epoch_index == num_epochs - 1:
        self.epoch_r2.append(tr_r2)
        self.epoch_mse.append(tr_mse)
        self.epoch_mae.append(tr_mae)
        self.epoch_rmse.append(tr_rmse)

# %%
nodeList = [Node('./24Train.csv', 2.4), Node('./25Train.csv', 2.5), Node('./26Train.csv', 2.6)]

# %%
turn = [np.array([[26, 104], [178, 312], [344, 464], [520, 600]]) * 112,
        np.array([[0, 94], [149, 223], [319, 433], [464, 580]]) * 112,
        np.array([[32, 151], [155, 248], [270, 354], [378, 502]]) * 112]

# %%
orders = [0, 1, 2]

for i in range(600 * 112):
    if i % 112 == 0:
        print(f"EPOCH: {i // 112}")
    random.shuffle(orders)
    for j in orders:
        for l, r in turn[j]:
            if l <= i < r:
                if math.isclose(l, i):
                    nodeList[j].getZero()
                nodeList[j].train(i)
    # valiAll(i)
    if i in [100 * 112, 200 * 112, 300 * 112, 400 * 112, 500 * 112]:
        ps.lr_decay(0.7)
# Out:
# EPOCH: 0
# 2025-05-02 15:36:31.220607: I external/local_xla/xla/service/service.cc:168] XLA service 0x55fcba472bd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-05-02 15:36:31.220634: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-05-02 15:36:31.220638: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-05-02 15:36:31.223802: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-05-02 15:36:31.997130: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746196592.117184   17534 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7fcf0c168160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7fcf0c168160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# EPOCH: 1
#
# Node 2.5 Epoch 0 Summary:
#   MSE: 2.0044 | RMSE: 0.6500
#   MAE: 0.5223 | R²: -15.5515
#   Anomaly Detection: 112/0
#   0 | 0
#   1 | 111
# EPOCH: 2
#
# Node 2.5 Epoch 1 Summary:
#   MSE: 0.0951 | RMSE: 0.3080
#   MAE: 0.2494 | R²: 0.2114
#   Anomaly Detection: 112/0
#   0 | 0
#   2 | 222
# EPOCH: 3
#
# Node 2.5 Epoch 2 Summary:
#   MSE: 0.0893 | RMSE: 0.2986
#   MAE: 0.2412 | R²: 0.2593
#   Anomaly Detection: 112/0
#   0 | 0
#   2 | 334
# EPOCH: 4
#
# Node 2.5 Epoch 3 Summary:
#   MSE: 0.0828 | RMSE: 0.2876
#   MAE: 0.2319 | R²: 0.3131
#   Anomaly Detection: 112/0
#   0 | 0
#   3 | 445
# EPOCH: 5
#
# Node 2.5 Epoch 4 Summary:
#   MSE: 0.0822 | RMSE: 0.2866
#   MAE: 0.2310 | R²: 0.3178
#   Anomaly Detection: 112/0
#   0 | 0
#   4 | 556
# EPOCH: 6
#
# Node 2.5 Epoch 5 Summary:
#   MSE: 0.0767 | RMSE: 0.2768
#   MAE: 0.2227 | R²: 0.3641
#   Anomaly Detection: 112/0
#   0 | 0
#   4 | 668
# EPOCH: 7
#
# Node 2.5 Epoch 6 Summary:
#   MSE: 0.0751 | RMSE: 0.2739
#   MAE: 0.2204 | R²: 0.3770
#   Anomaly Detection: 112/0
#   0 | 0
#   4 | 780
# EPOCH: 8
#
# Node 2.5 Epoch 7 Summary:
#   MSE: 0.0715 | RMSE: 0.2673
#   MAE: 0.2149 | R²: 0.4069
#   Anomaly Detection: 112/0
#   0 | 0
#   4 | 892
# EPOCH: 9
#
# Node 2.5 Epoch 8 Summary:
#   MSE: 0.0702 | RMSE: 0.2649
#   MAE: 0.2125 | R²: 0.4176
#   Anomaly Detection: 112/0
#   0 | 0
#   4 | 1004
# EPOCH: 10
#
# Node 2.5 Epoch 9 Summary:
#   MSE: 0.0677 | RMSE: 0.2602
#   MAE: 0.2085 | R²: 0.4381
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 1115
# EPOCH: 11
#
# Node 2.5 Epoch 10 Summary:
#   MSE: 0.0660 | RMSE: 0.2568
#   MAE: 0.2058 | R²: 0.4526
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 1227
# EPOCH: 12
#
# Node 2.5 Epoch 11 Summary:
#   MSE: 0.0635 | RMSE: 0.2520
#   MAE: 0.2018 | R²: 0.4730
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 1339
# EPOCH: 13
#
# Node 2.5 Epoch 12 Summary:
#   MSE: 0.0643 | RMSE: 0.2535
#   MAE: 0.2026 | R²: 0.4665
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 1451
# EPOCH: 14
#
# Node 2.5 Epoch 13 Summary:
#   MSE: 0.0618 | RMSE: 0.2486
#   MAE: 0.1987 | R²: 0.4870
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 1563
# EPOCH: 15
#
# Node 2.5 Epoch 14 Summary:
#   MSE: 0.0596 | RMSE: 0.2441
#   MAE: 0.1948 | R²: 0.5055
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 1675
# EPOCH: 16
#
# Node 2.5 Epoch 15 Summary:
#   MSE: 0.0579 | RMSE: 0.2405
#   MAE: 0.1919 | R²: 0.5199
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 1787
# EPOCH: 17
#
# Node 2.5 Epoch 16 Summary:
#   MSE: 0.0574 | RMSE: 0.2394
#   MAE: 0.1908 | R²: 0.5242
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 1899
# EPOCH: 18
#
# Node 2.5 Epoch 17 Summary:
#   MSE: 0.0555 | RMSE: 0.2355
#   MAE: 0.1875 | R²: 0.5397
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 2011
# EPOCH: 19
#
# Node 2.5 Epoch 18 Summary:
#   MSE: 0.0538 | RMSE: 0.2318
#   MAE: 0.1842 | R²: 0.5540
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 2123
# EPOCH: 20
#
# Node 2.5 Epoch 19 Summary:
#   MSE: 0.0514 | RMSE: 0.2266
#   MAE: 0.1798 | R²: 0.5738
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 2235
# EPOCH: 21
#
# Node 2.5 Epoch 20 Summary:
#   MSE: 0.0488 | RMSE: 0.2208
#   MAE: 0.1748 | R²: 0.5953
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 2347
# EPOCH: 22
#
# Node 2.5 Epoch 21 Summary:
#   MSE: 0.0452 | RMSE: 0.2124
#   MAE: 0.1675 | R²: 0.6255
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 2459
# EPOCH: 23
#
# Node 2.5 Epoch 22 Summary:
#   MSE: 0.0429 | RMSE: 0.2070
#   MAE: 0.1626 | R²: 0.6442
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 2571
# EPOCH: 24
#
# Node 2.5 Epoch 23 Summary:
#   MSE: 0.0402 | RMSE: 0.2005
#   MAE: 0.1569 | R²: 0.6664
#   Anomaly Detection: 112/0
#   0 | 0
#   5 | 2683
# EPOCH: 25
#
# Node 2.5 Epoch 24 Summary:
#   MSE: 0.0390 | RMSE: 0.1973
#   MAE: 0.1538 | R²: 0.6768
#   Anomaly Detection: 112/0
#   0 | 0
#   6 | 2794
# EPOCH: 26
#
# Node 2.5 Epoch 25 Summary:
#   MSE: 0.0376 | RMSE: 0.1938
#   MAE: 0.1507 | R²: 0.6881
#   Anomaly Detection: 112/0
#   0 | 0
#   6 | 2907
# EPOCH: 27
#
# Node 2.5 Epoch 26 Summary:
#   MSE: 0.0483 | RMSE: 0.2184
#   MAE: 0.1716 | R²: 0.5992
#   Anomaly Detection: 112/0
#   0 | 0
#   9 | 3127
#
# Node 2.4 Epoch 0 Summary:
#   MSE: 0.0495 | RMSE: 0.2213
#   MAE: 0.1752 | R²: 0.5902
#   Anomaly Detection: 112/0
#   0 | 0
#   9 | 3128
# EPOCH: 28
#
# Node 2.5 Epoch 27 Summary:
#   MSE: 0.0437 | RMSE: 0.2085
#   MAE: 0.1634 | R²: 0.6373
#   Anomaly Detection: 112/0
#   0 | 0
#   10 | 3350
#
# Node 2.4 Epoch 1 Summary:
#   MSE: 0.0465 | RMSE: 0.2149
#   MAE: 0.1699 | R²: 0.6149
#   Anomaly Detection: 112/0
#   0 | 0
#   10 | 3351
# EPOCH: 29
#
# Node 2.5 Epoch 28 Summary:
#   MSE: 0.0404 | RMSE: 0.2006
#   MAE: 0.1567 | R²: 0.6646
#   Anomaly Detection: 112/0
#   0 | 0
#   10 | 3574
#
# Node 2.4 Epoch 2 Summary:
#   MSE: 0.0436 | RMSE: 0.2081
#   MAE: 0.1642 | R²: 0.6396
#   Anomaly Detection: 112/0
#   0 | 0
#   10 | 3575
# EPOCH: 30
#
# Node 2.5 Epoch 29 Summary:
#   MSE: 0.0385 | RMSE: 0.1957
#   MAE: 0.1525 | R²: 0.6808
#   Anomaly Detection: 112/0
#   0 | 0
#   11 | 3797
#
# Node 2.4 Epoch 3 Summary:
#   MSE: 0.0419 | RMSE: 0.2041
#   MAE: 0.1611 | R²: 0.6531
#   Anomaly Detection: 112/0
#   0 | 0
#   11 | 3798
# EPOCH: 31
#
# Node 2.4 Epoch 4 Summary:
#   MSE: 0.0421 | RMSE: 0.2045
#   MAE: 0.1613 | R²: 0.6517
#   Anomaly Detection: 112/0
#   0 | 0
#   12 | 4020
#
# Node 2.5 Epoch 30 Summary:
#   MSE: 0.0384 | RMSE: 0.1954
#   MAE: 0.1523 | R²: 0.6811
#   Anomaly Detection: 112/0
#   0 | 0
#   12 | 4021
# EPOCH: 32
#
# Node 2.4 Epoch 5 Summary:
#   MSE: 0.0421 | RMSE: 0.2043
#   MAE: 0.1612 | R²: 0.6517
#   Anomaly Detection: 112/0
#   0 | 0
#   15 | 4241
#
# Node 2.5 Epoch 31 Summary:
#   MSE: 0.0388 | RMSE: 0.1964
#   MAE: 0.1529 | R²: 0.6781
#   Anomaly Detection: 112/0
#   0 | 0
#   15 | 4243
# EPOCH: 33
#
# Node 2.4 Epoch 6 Summary:
#   MSE: 0.0486 | RMSE: 0.2194
#   MAE: 0.1742 | R²: 0.5981
#   Anomaly Detection: 112/0
#   0 | 0
#   16 | 4576
#
# Node 2.5 Epoch 32 Summary:
#   MSE: 0.0370 | RMSE: 0.1922
#   MAE: 0.1498 | R²: 0.6930
#   Anomaly Detection: 112/0
#   0 | 0
#   16 | 4577
#
# Node 2.6 Epoch 0 Summary:
#   MSE: 0.0570 | RMSE: 0.2375
#   MAE: 0.1886 | R²: 0.5261
#   Anomaly Detection: 112/0
#   0 | 0
#   17 | 4577
# EPOCH: 34
#
# Node 2.5 Epoch 33 Summary:
#   MSE: 0.0357 | RMSE: 0.1888
#   MAE: 0.1470 | R²: 0.7035
#   Anomaly Detection: 112/0
#   0 | 0
#   18 | 4910
#
# Node 2.4 Epoch 7 Summary:
#   MSE: 0.0470 | RMSE: 0.2160
#   MAE: 0.1714 | R²: 0.6108
#   Anomaly Detection: 112/0
#   0 | 0
#   18 | 4911
#
# Node 2.6 Epoch 1 Summary:
#   MSE: 0.0560 | RMSE: 0.2356
#   MAE: 0.1869 | R²: 0.5347
#   Anomaly Detection: 112/0
#   0 | 0
#   18 | 4912
# EPOCH: 35
#
# Node 2.5 Epoch 34 Summary:
#   MSE: 0.0345 | RMSE: 0.1854
#   MAE: 0.1440 | R²: 0.7141
#   Anomaly Detection: 112/0
#   0 | 0
#   19 | 5245
#
# Node 2.6 Epoch 2 Summary:
#   MSE: 0.0551 | RMSE: 0.2334
#   MAE: 0.1850 | R²: 0.5425
#   Anomaly Detection: 112/0
#   0 | 0
#   19 | 5246
#
# Node 2.4 Epoch 8 Summary:
#   MSE: 0.0455 | RMSE: 0.2123
#   MAE: 0.1682 | R²: 0.6234
#   Anomaly Detection: 112/0
#   0 | 0
#   19 | 5247
# EPOCH: 36
#
# Node 2.5 Epoch 35 Summary:
#   MSE: 0.0337 | RMSE: 0.1834
#   MAE: 0.1426 | R²: 0.7202
#   Anomaly Detection: 112/0
#   0 | 0
#   22 | 5578
#
# Node 2.4 Epoch 9 Summary:
#   MSE: 0.0461 | RMSE: 0.2138
#   MAE: 0.1696 | R²: 0.6185
#   Anomaly Detection: 112/0
#   0 | 0
#   22 | 5579
#
# Node 2.6 Epoch 3 Summary:
#   MSE: 0.0549 | RMSE: 0.2330
#   MAE: 0.1849 | R²: 0.5444
#   Anomaly Detection: 112/0
#   0 | 0
#   22 | 5580
# EPOCH: 37
#
# Node 2.6 Epoch 4 Summary:
#   MSE: 0.0536 | RMSE: 0.2301
#   MAE: 0.1824 | R²: 0.5548
#   Anomaly Detection: 112/0
#   0 | 0
#   23 | 5913
#
# Node 2.4 Epoch 10 Summary:
#   MSE: 0.0451 | RMSE: 0.2117
#   MAE: 0.1679 | R²: 0.6266
#   Anomaly Detection: 112/0
#   0 | 0
#   23 | 5914
#
# Node 2.5 Epoch 36 Summary:
#   MSE: 0.0337 | RMSE: 0.1834
#   MAE: 0.1427 | R²: 0.7201
#   Anomaly Detection: 112/0
#   0 | 0
#   23 | 5915
# EPOCH: 38
#
# Node 2.6 Epoch 5 Summary:
#   MSE: 0.0539 | RMSE: 0.2310
#   MAE: 0.1834 | R²: 0.5519
#   Anomaly Detection: 112/0
#   0 | 0
#   24 | 6248
#
# Node 2.5 Epoch 37 Summary:
#   MSE: 0.0329 | RMSE: 0.1812
#   MAE: 0.1407 | R²: 0.7267
#   Anomaly Detection: 112/0
#   0 | 0
#   24 | 6249
#
# Node 2.4 Epoch 11 Summary:
#   MSE: 0.0446 | RMSE: 0.2102
#   MAE: 0.1665 | R²: 0.6314
#   Anomaly Detection: 112/0
#   0 | 0
#   24 | 6250
# EPOCH: 39
#
# Node 2.6 Epoch 6 Summary:
#   MSE: 0.0543 | RMSE: 0.2315
#   MAE: 0.1836 | R²: 0.5492
#   Anomaly Detection: 112/0
#   0 | 0
#   26 | 6582
#
# Node 2.5 Epoch 38 Summary:
#   MSE: 0.0331 | RMSE: 0.1817
#   MAE: 0.1412 | R²: 0.7252
#   Anomaly Detection: 112/0
#   0 | 0
#   26 | 6583
#
# Node 2.4 Epoch 12 Summary:
#   MSE: 0.0445 | RMSE: 0.2100
#   MAE: 0.1664 | R²: 0.6321
#   Anomaly Detection: 112/0
#   0 | 0
#   26 | 6584
# EPOCH: 40
#
# Node 2.5 Epoch 39 Summary:
#   MSE: 0.0321 | RMSE: 0.1789
#   MAE: 0.1387 | R²: 0.7338
#   Anomaly Detection: 112/0
#   0 | 0
#   27 | 6917
#
# Node 2.4 Epoch 13 Summary:
#   MSE: 0.0436 | RMSE: 0.2080
#   MAE: 0.1648 | R²: 0.6391
#   Anomaly Detection: 112/0
#   0 | 0
#   27 | 6918
#
# Node 2.6 Epoch 7 Summary:
#   MSE: 0.0533 | RMSE: 0.2294
#   MAE: 0.1820 | R²: 0.5574
#   Anomaly Detection: 112/0
#   0 | 0
#   27 | 6919
# EPOCH: 41
#
# Node 2.5 Epoch 40 Summary:
#   MSE: 0.0322 | RMSE: 0.1791
#   MAE: 0.1390 | R²: 0.7330
#   Anomaly Detection: 112/0
#   0 | 0
#   30 | 7250
#
# Node 2.4 Epoch 14 Summary:
#   MSE: 0.0435 | RMSE: 0.2076
#   MAE: 0.1647 | R²: 0.6401
#   Anomaly Detection: 112/0
#   0 | 0
#   30 | 7251
#
# Node 2.6 Epoch 8 Summary:
#   MSE: 0.0529 | RMSE: 0.2287
#   MAE: 0.1814 | R²: 0.5608
#   Anomaly Detection: 112/0
#   0 | 0
#   30 | 7252
# EPOCH: 42
#
# Node 2.4 Epoch 15 Summary:
#   MSE: 0.0428 | RMSE: 0.2058
#   MAE: 0.1629 | R²: 0.6461
#   Anomaly Detection: 112/0
#   0 | 0
#   32 | 7584
#
# Node 2.6 Epoch 9 Summary:
#   MSE: 0.0529 | RMSE: 0.2289
#   MAE: 0.1816 | R²: 0.5601
#   Anomaly Detection: 112/0
#   0 | 0
#   32 | 7585
#
# Node 2.5 Epoch 41 Summary:
#   MSE: 0.0311 | RMSE: 0.1761
#   MAE: 0.1364 | R²: 0.7420
#   Anomaly Detection: 112/0
#   0 | 0
#   32 | 7586
# EPOCH: 43
#
# Node 2.4 Epoch 16 Summary:
#   MSE: 0.0428 | RMSE: 0.2061
#   MAE: 0.1633 | R²: 0.6456
#   Anomaly Detection: 112/0
#   0 | 0
#   33 | 7919
#
# Node 2.6 Epoch 10 Summary:
#   MSE: 0.0510 | RMSE: 0.2249
#   MAE: 0.1784 | R²: 0.5762
#   Anomaly Detection: 112/0
#   0 | 0
#   33 | 7920
#
# Node 2.5 Epoch 42 Summary:
#   MSE: 0.0295 | RMSE: 0.1716
#   MAE: 0.1326 | R²: 0.7551
#   Anomaly Detection: 112/0
#   0 | 0
#   33 | 7921
# EPOCH: 44
#
# Node 2.6 Epoch 11 Summary:
#   MSE: 0.0507 | RMSE: 0.2243
#   MAE: 0.1780 | R²: 0.5784
#   Anomaly Detection: 112/0
#   0 | 0
#   34 | 8254
#
# Node 2.4 Epoch 17 Summary:
#   MSE: 0.0423 | RMSE: 0.2049
#   MAE: 0.1624 | R²: 0.6497
#   Anomaly Detection: 112/0
#   0 | 0
#   34 | 8255
#
# Node 2.5 Epoch 43 Summary:
#   MSE: 0.0289 | RMSE: 0.1698
#   MAE: 0.1310 | R²: 0.7605
#   Anomaly Detection: 112/0
#   0 | 0
#   34 | 8256
# EPOCH: 45
#
# Node 2.5 Epoch 44 Summary:
#   MSE: 0.0302 | RMSE: 0.1735
#   MAE: 0.1344 | R²: 0.7494
#   Anomaly Detection: 112/0
#   0 | 0
#   36 | 8588
#
# Node 2.4 Epoch 18 Summary:
#   MSE: 0.0423 | RMSE: 0.2044
#   MAE: 0.1618 | R²: 0.6502
#   Anomaly Detection: 112/0
#   0 | 0
#   36 | 8589
#
# Node 2.6 Epoch 12 Summary:
#   MSE: 0.0527 | RMSE: 0.2278
#   MAE: 0.1808 | R²: 0.5622
#   Anomaly Detection: 112/0
#   0 | 0
#   36 | 8590
# EPOCH: 46
#
# Node 2.6 Epoch 13 Summary:
#   MSE: 0.0519 | RMSE: 0.2266
#   MAE: 0.1799 | R²: 0.5690
#   Anomaly Detection: 112/0
#   0 | 0
#   36 | 8924
#
# Node 2.4 Epoch 19 Summary:
#   MSE: 0.0426 | RMSE: 0.2053
#   MAE: 0.1625 | R²: 0.6474
#   Anomaly Detection: 112/0
#   0 | 0
#   36 | 8925
#
# Node 2.5 Epoch 45 Summary:
#   MSE: 0.0295 | RMSE: 0.1715
#   MAE: 0.1327 | R²: 0.7555
#   Anomaly Detection: 112/0
#   0 | 0
#   36 | 8926
# EPOCH: 47
#
# Node 2.6 Epoch 14 Summary:
#   MSE: 0.0509 | RMSE: 0.2243
#   MAE: 0.1778 | R²: 0.5771
#   Anomaly Detection: 112/0
#   0 | 0
#   38 | 9258
#
# Node 2.4 Epoch 20 Summary:
#   MSE: 0.0409 | RMSE: 0.2013
#   MAE: 0.1591 | R²: 0.6618
#   Anomaly Detection: 112/0
#   0 | 0
#   38 | 9259
#
# Node 2.5 Epoch 46 Summary:
#   MSE: 0.0287 | RMSE: 0.1692
#   MAE: 0.1308 | R²: 0.7618
#   Anomaly Detection: 112/0
#   0 | 0
#   38 | 9260
# EPOCH: 48
#
# Node 2.5 Epoch 47 Summary:
#   MSE: 0.0282 | RMSE: 0.1678
#   MAE: 0.1296 | R²: 0.7658
#   Anomaly Detection: 112/0
#   0 | 0
#   39 | 9593
#
# Node 2.4 Epoch 21 Summary:
#   MSE: 0.0415 | RMSE: 0.2029
#   MAE: 0.1606 | R²: 0.6565
#   Anomaly Detection: 112/0
#   0 | 0
#   39 | 9594
#
# Node 2.6 Epoch 15 Summary:
#   MSE: 0.0512 | RMSE: 0.2253
#   MAE: 0.1788 | R²: 0.5745
#   Anomaly Detection: 112/0
#   0 | 0
#   39 | 9595
# EPOCH: 49
#
# Node 2.4 Epoch 22 Summary:
#   MSE: 0.0411 | RMSE: 0.2019
#   MAE: 0.1598 | R²: 0.6597
#   Anomaly Detection: 112/0
#   0 | 0
#   40 | 9928
#
# Node 2.5 Epoch 48 Summary:
#   MSE: 0.0278 | RMSE: 0.1666
#   MAE: 0.1284 | R²: 0.7694
#   Anomaly Detection: 112/0
#   0 | 0
#   40 | 9929
#
# Node 2.6 Epoch 16 Summary:
#   MSE: 0.0506 | RMSE: 0.2241
#   MAE: 0.1778 | R²: 0.5792
#   Anomaly Detection: 112/0
#   0 | 0
#   40 | 9930
# EPOCH: 50
#
# Node 2.5 Epoch 49 Summary:
#   MSE: 0.0271 | RMSE: 0.1645
#   MAE: 0.1267 | R²: 0.7751
#   Anomaly Detection: 112/0
#   0 | 0
#   42 | 10262
#
# Node 2.4 Epoch 23 Summary:
#   MSE: 0.0403 | RMSE: 0.2000
#   MAE: 0.1583 | R²: 0.6662
#   Anomaly Detection: 112/0
#   0 | 0
#   42 | 10263
#
# Node 2.6 Epoch 17 Summary:
#   MSE: 0.0508 | RMSE: 0.2244
#   MAE: 0.1782 | R²: 0.5782
#   Anomaly Detection: 112/0
#   0 | 0
#   42 | 10264
# EPOCH: 51
#
# Node 2.6 Epoch 18 Summary:
#   MSE: 0.0495 | RMSE: 0.2212
#   MAE: 0.1754 | R²: 0.5888
#   Anomaly Detection: 112/0
#   0 | 0
#   43 | 10597
#
# Node 2.5 Epoch 50 Summary:
#   MSE: 0.0273 | RMSE: 0.1651
#   MAE: 0.1274 | R²: 0.7734
#   Anomaly Detection: 112/0
#   0 | 0
#   43 | 10598
#
# Node 2.4 Epoch 24 Summary:
#   MSE: 0.0402 | RMSE: 0.1997
#   MAE: 0.1579 | R²: 0.6673
#   Anomaly Detection: 112/0
#   0 | 0
#   43 | 10599
# EPOCH: 52
#
# Node 2.4 Epoch 25 Summary:
#   MSE: 0.0403 | RMSE: 0.2000
#   MAE: 0.1582 | R²: 0.6665
#   Anomaly Detection: 112/0
#   0 | 0
#   50 | 10926
#
# Node 2.5 Epoch 51 Summary:
#   MSE: 0.0262 | RMSE: 0.1616
#   MAE: 0.1243 | R²: 0.7828
#   Anomaly Detection: 112/0
#   0 | 0
#   50 | 10927
#
# Node 2.6 Epoch 19 Summary:
#   MSE: 0.0491 | RMSE: 0.2207
#   MAE: 0.1752 | R²: 0.5923
#   Anomaly Detection: 112/0
#   0 | 0
#   51 | 10927
# EPOCH: 53
#
# Node 2.5 Epoch 52 Summary:
#   MSE: 0.0271 | RMSE: 0.1643
#   MAE: 0.1267 | R²: 0.7753
#   Anomaly Detection: 112/0
#   0 | 0
#   54 | 11258
#
# Node 2.6 Epoch 20 Summary:
#   MSE: 0.0499 | RMSE: 0.2222
#   MAE: 0.1763 | R²: 0.5857
#   Anomaly Detection: 112/0
#   0 | 0
#   54 | 11259
#
# Node 2.4 Epoch 26 Summary:
#   MSE: 0.0406 | RMSE: 0.2006
#   MAE: 0.1587 | R²: 0.6642
#   Anomaly Detection: 112/0
#   0 | 0
#   54 | 11260
# EPOCH: 54
#
# Node 2.6 Epoch 21 Summary:
#   MSE: 0.0489 | RMSE: 0.2201
#   MAE: 0.1746 | R²: 0.5942
#   Anomaly Detection: 112/0
#   0 | 0
#   59 | 11589
#
# Node 2.4 Epoch 27 Summary:
#   MSE: 0.0392 | RMSE: 0.1974
#   MAE: 0.1560 | R²: 0.6752
#   Anomaly Detection: 112/0
#   0 | 0
#   59 | 11590
#
# Node 2.5 Epoch 53 Summary:
#   MSE: 0.0256 | RMSE: 0.1598
#   MAE: 0.1228 | R²: 0.7878
#   Anomaly Detection: 112/0
#   0 | 0
#   59 | 11591
# EPOCH: 55
#
# Node 2.6 Epoch 22 Summary:
#   MSE: 0.0488 | RMSE: 0.2198
#   MAE: 0.1743 | R²: 0.5944
#   Anomaly Detection: 112/0
#   0 | 0
#   64 | 11920
#
# Node 2.5 Epoch 54 Summary:
#   MSE: 0.0258 | RMSE: 0.1605
#   MAE: 0.1235 | R²: 0.7858
#   Anomaly Detection: 112/0
#   0 | 0
#   64 | 11921
#
# Node 2.4 Epoch 28 Summary:
#   MSE: 0.0392 | RMSE: 0.1971
#   MAE: 0.1558 | R²: 0.6755
#   Anomaly Detection: 112/0
#   0 | 0
#   64 | 11922
# EPOCH: 56
#
# Node 2.6 Epoch 23 Summary:
#   MSE: 0.0488 | RMSE: 0.2198
#   MAE: 0.1745 | R²: 0.5948
#   Anomaly Detection: 112/0
#   0 | 0
#   67 | 12253
#
# Node 2.4 Epoch 29 Summary:
#   MSE: 0.0395 | RMSE: 0.1978
#   MAE: 0.1565 | R²: 0.6736
#   Anomaly Detection: 112/0
#   0 | 0
#   67 | 12254
#
# Node 2.5 Epoch 55 Summary:
#   MSE: 0.0254 | RMSE: 0.1590
#   MAE: 0.1223 | R²: 0.7896
#   Anomaly Detection: 112/0
#   0 | 0
#   67 | 12255
# EPOCH: 57
#
# Node 2.4 Epoch 30 Summary:
#   MSE: 0.0390 | RMSE: 0.1966
#   MAE: 0.1554 | R²: 0.6773
#   Anomaly Detection: 112/0
#   0 | 0
#   68 | 12588
#
# Node 2.5 Epoch 56 Summary:
#   MSE: 0.0247 | RMSE: 0.1569
#   MAE: 0.1205 | R²: 0.7953
#   Anomaly Detection: 112/0
#   0 | 0
#   68 | 12589
#
# Node 2.6 Epoch 24 Summary:
#   MSE: 0.0478 | RMSE: 0.2179
#   MAE: 0.1729 | R²: 0.6027
#   Anomaly Detection: 112/0
#   0 | 0
#   68 | 12590
# EPOCH: 58
#
# Node 2.5 Epoch 57 Summary:
#   MSE: 0.0248 | RMSE: 0.1572
#   MAE: 0.1208 | R²: 0.7945
#   Anomaly Detection: 112/0
#   0 | 0
#   70 | 12922
#
# Node 2.4 Epoch 31 Summary:
#   MSE: 0.0389 | RMSE: 0.1963
#   MAE: 0.1552 | R²: 0.6784
#   Anomaly Detection: 112/0
#   0 | 0
#   70 | 12923
#
# Node 2.6 Epoch 25 Summary:
#   MSE: 0.0480 | RMSE: 0.2179
#   MAE: 0.1727 | R²: 0.6015
#   Anomaly Detection: 112/0
#   0 | 0
#   70 | 12924
# EPOCH: 59
#
# Node 2.5 Epoch 58 Summary:
#   MSE: 0.0241 | RMSE: 0.1551
#   MAE: 0.1191 | R²: 0.8001
#   Anomaly Detection: 112/0
#   0 | 0
#   74 | 13254
#
# Node 2.6 Epoch 26 Summary:
#   MSE: 0.0479 | RMSE: 0.2179
#   MAE: 0.1728 | R²: 0.6023
#   Anomaly Detection: 112/0
#   0 | 0
#   74 | 13255
#
# Node 2.4 Epoch 32 Summary:
#   MSE: 0.0381 | RMSE: 0.1945
#   MAE: 0.1538 | R²: 0.6846
#   Anomaly Detection: 112/0
#   0 | 0
#   74 | 13256
# EPOCH: 60
#
# Node 2.6 Epoch 27 Summary:
#   MSE: 0.0481 | RMSE: 0.2183
#   MAE: 0.1731 | R²: 0.6002
#   Anomaly Detection: 112/0
#   0 | 0
#   75 | 13589
#
# Node 2.5 Epoch 59 Summary:
#   MSE: 0.0240 | RMSE: 0.1546
#   MAE: 0.1188 | R²: 0.8013
#   Anomaly Detection: 112/0
#   0 | 0
#   75 | 13590
#
# Node 2.4 Epoch 33 Summary:
#   MSE: 0.0386 | RMSE: 0.1957
#   MAE: 0.1546 | R²: 0.6805
#   Anomaly Detection: 112/0
#   0 | 0
#   75 | 13591
# EPOCH: 61
#
# Node 2.6 Epoch 28 Summary:
#   MSE: 0.0468 | RMSE: 0.2154
#   MAE: 0.1708 | R²: 0.6114
#   Anomaly Detection: 112/0
#   0 | 0
#   77 | 13923
#
# Node 2.4 Epoch 34 Summary:
#   MSE: 0.0375 | RMSE: 0.1928
#   MAE: 0.1523 | R²: 0.6900
#   Anomaly Detection: 112/0
#   0 | 0
#   77 | 13924
#
# Node 2.5 Epoch 60 Summary:
#   MSE: 0.0234 | RMSE: 0.1529
#   MAE: 0.1172 | R²: 0.8058
#   Anomaly Detection: 112/0
#   0 | 0
#   77 | 13925
# EPOCH: 62
#
# Node 2.6 Epoch 29 Summary:
#   MSE: 0.0480 | RMSE: 0.2183
#   MAE: 0.1733 | R²: 0.6012
#   Anomaly Detection: 112/0
#   0 | 0
#   80 | 14256
#
# Node 2.4 Epoch 35 Summary:
#   MSE: 0.0376 | RMSE: 0.1932
#   MAE: 0.1526 | R²: 0.6893
#   Anomaly Detection: 112/0
#   0 | 0
#   80 | 14257
#
# Node 2.5 Epoch 61 Summary:
#   MSE: 0.0231 | RMSE: 0.1517
#   MAE: 0.1161 | R²: 0.8088
#   Anomaly Detection: 112/0
#   0 | 0
#   80 | 14258
# EPOCH: 63
#
# Node 2.5 Epoch 62 Summary:
#   MSE: 0.0231 | RMSE: 0.1520
#   MAE: 0.1166 | R²: 0.8081
#   Anomaly Detection: 112/0
#   0 | 0
#   83 | 14589
#
# Node 2.6 Epoch 30 Summary:
#   MSE: 0.0470 | RMSE: 0.2161
#   MAE: 0.1714 | R²: 0.6092
#   Anomaly Detection: 112/0
#   0 | 0
#   83 | 14590
#
# Node 2.4 Epoch 36 Summary:
#   MSE: 0.0380 | RMSE: 0.1941
#   MAE: 0.1535 | R²: 0.6858
#   Anomaly Detection: 112/0
#   0 | 0
#   83 | 14591
# EPOCH: 64
#
# Node 2.5 Epoch 63 Summary:
#   MSE: 0.0230 | RMSE: 0.1515
#   MAE: 0.1161 | R²: 0.8092
#   Anomaly Detection: 112/0
#   0 | 0
#   84 | 14924
#
# Node 2.4 Epoch 37 Summary:
#   MSE: 0.0372 | RMSE: 0.1918
#   MAE: 0.1514 | R²: 0.6925
#   Anomaly Detection: 112/0
#   0 | 0
#   84 | 14925
#
# Node 2.6 Epoch 31 Summary:
#   MSE: 0.0472 | RMSE: 0.2164
#   MAE: 0.1716 | R²: 0.6079
#   Anomaly Detection: 112/0
#   0 | 0
#   84 | 14926
# EPOCH: 65
#
# Node 2.6 Epoch 32 Summary:
#   MSE: 0.0471 | RMSE: 0.2161
#   MAE: 0.1713 | R²: 0.6088
#   Anomaly Detection: 112/0
#   0 | 0
#   87 | 15257
#
# Node 2.5 Epoch 64 Summary:
#   MSE: 0.0232 | RMSE: 0.1520
#   MAE: 0.1165 | R²: 0.8079
#   Anomaly Detection: 112/0
#   0 | 0
#   87 | 15258
#
# Node 2.4 Epoch 38 Summary:
#   MSE: 0.0381 | RMSE: 0.1945
#   MAE: 0.1537 | R²: 0.6848
#   Anomaly Detection: 112/0
#   0 | 0
#   87 | 15259
# EPOCH: 66
#
# Node 2.5 Epoch 65 Summary:
#   MSE: 0.0224 | RMSE: 0.1494
#   MAE: 0.1142 | R²: 0.8145
#   Anomaly Detection: 112/0
#   0 | 0
#   90 | 15590
#
# Node 2.6 Epoch 33 Summary:
#   MSE: 0.0471 | RMSE: 0.2162
#   MAE: 0.1715 | R²: 0.6086
#   Anomaly Detection: 112/0
#   0 | 0
#   90 | 15591
#
# Node 2.4 Epoch 39 Summary:
#   MSE: 0.0370 | RMSE: 0.1916
#   MAE: 0.1514 | R²: 0.6938
#   Anomaly Detection: 112/0
#   0 | 0
#   90 | 15592
# EPOCH: 67
#
# Node 2.6 Epoch 34 Summary:
#   MSE: 0.0473 | RMSE: 0.2163
#   MAE: 0.1716 | R²: 0.6071
#   Anomaly Detection: 112/0
#   0 | 0
#   92 | 15924
#
# Node 2.5 Epoch 66 Summary:
#   MSE: 0.0236 | RMSE: 0.1534
#   MAE: 0.1177 | R²: 0.8042
#   Anomaly Detection: 112/0
#   0 | 0
#   92 | 15925
#
# Node 2.4 Epoch 40 Summary:
#   MSE: 0.0374 | RMSE: 0.1923
#   MAE: 0.1518 | R²: 0.6906
#   Anomaly Detection: 112/0
#   0 | 0
#   92 | 15926
# EPOCH: 68
#
# Node 2.5 Epoch 67 Summary:
#   MSE: 0.0222 | RMSE: 0.1490
#   MAE: 0.1140 | R²: 0.8155
#   Anomaly Detection: 112/0
#   0 | 0
#   97 | 16255
#
# Node 2.6 Epoch 35 Summary:
#   MSE: 0.0462 | RMSE: 0.2143
#   MAE: 0.1699 | R²: 0.6160
#   Anomaly Detection: 112/0
#   0 | 0
#   97 | 16256
#
# Node 2.4 Epoch 41 Summary:
#   MSE: 0.0368 | RMSE: 0.1912
#   MAE: 0.1509 | R²: 0.6955
#   Anomaly Detection: 112/0
#   0 | 0
#   97 | 16257
# EPOCH: 69
#
# Node 2.4 Epoch 42 Summary:
#   MSE: 0.0367 | RMSE: 0.1911
#   MAE: 0.1509 | R²: 0.6961
#   Anomaly Detection: 112/0
#   0 | 0
#   99 | 16589
#
# Node 2.6 Epoch 36 Summary:
#   MSE: 0.0464 | RMSE: 0.2144
#   MAE: 0.1700 | R²: 0.6146
#   Anomaly Detection: 112/0
#   0 | 0
#   99 | 16590
#
# Node 2.5 Epoch 68 Summary:
#   MSE: 0.0220 | RMSE: 0.1482
#   MAE: 0.1133 | R²: 0.8175
#   Anomaly Detection: 112/0
#   0 | 0
#   99 | 16591
# EPOCH: 70
#
# Node 2.5 Epoch 69 Summary:
#   MSE: 0.0225 | RMSE: 0.1497
#   MAE: 0.1146 | R²: 0.8137
#   Anomaly Detection: 112/0
#   0 | 0
#   102 | 16922
#
# Node 2.6 Epoch 37 Summary:
#   MSE: 0.0459 | RMSE: 0.2130
#   MAE: 0.1687 | R²: 0.6190
#   Anomaly Detection: 112/0
#   0 | 0
#   102 | 16923
#
# Node 2.4 Epoch 43 Summary:
#   MSE: 0.0369 | RMSE: 0.1912
#   MAE: 0.1508 | R²: 0.6951
#   Anomaly Detection: 112/0
#   0 | 0
#   102 | 16924
# EPOCH: 71
#
# Node 2.4 Epoch 44 Summary:
#   MSE: 0.0366 | RMSE: 0.1903
#   MAE: 0.1502 | R²: 0.6975
#   Anomaly Detection: 112/0
#   0 | 0
#   107 | 17253
#
# Node 2.6 Epoch 38 Summary:
#   MSE: 0.0458 | RMSE: 0.2132
#   MAE: 0.1691 | R²: 0.6193
#   Anomaly Detection: 112/0
#   0 | 0
#   107 | 17254
#
# Node 2.5 Epoch 70 Summary:
#   MSE: 0.0221 | RMSE: 0.1484
#   MAE: 0.1134 | R²: 0.8170
#   Anomaly Detection: 112/0
#   0 | 0
#   107 | 17255
# EPOCH: 72
#
# Node 2.5 Epoch 71 Summary:
#   MSE: 0.0223 | RMSE: 0.1493
#   MAE: 0.1143 | R²: 0.8147
#   Anomaly Detection: 112/0
#   0 | 0
#   113 | 17583
#
# Node 2.4 Epoch 45 Summary:
#   MSE: 0.0366 | RMSE: 0.1905
#   MAE: 0.1503 | R²: 0.6970
#   Anomaly Detection: 112/0
#   0 | 0
#   113 | 17584
#
# Node 2.6 Epoch 39 Summary:
#   MSE: 0.0461 | RMSE: 0.2135
#   MAE: 0.1691 | R²: 0.6174
#   Anomaly Detection: 112/0
#   0 | 0
#   113 | 17585
# EPOCH: 73
#
# Node 2.6 Epoch 40 Summary:
#   MSE: 0.0454 | RMSE: 0.2125
#   MAE: 0.1682 | R²: 0.6225
#   Anomaly Detection: 112/0
#   0 | 0
#   114 | 17918
#
# Node 2.4 Epoch 46 Summary:
#   MSE: 0.0357 | RMSE: 0.1883
#   MAE: 0.1486 | R²: 0.7043
#   Anomaly Detection: 112/0
#   0 | 0
#   114 | 17919
#
# Node 2.5 Epoch 72 Summary:
#   MSE: 0.0212 | RMSE: 0.1455
#   MAE: 0.1111 | R²: 0.8240
#   Anomaly Detection: 112/0
#   0 | 0
#   114 | 17920
# EPOCH: 74
#
# Node 2.5 Epoch 73 Summary:
#   MSE: 0.0215 | RMSE: 0.1464
#   MAE: 0.1119 | R²: 0.8218
#   Anomaly Detection: 112/0
#   0 | 0
#   118 | 18250
#
# Node 2.4 Epoch 47 Summary:
#   MSE: 0.0363 | RMSE: 0.1897
#   MAE: 0.1497 | R²: 0.6999
#   Anomaly Detection: 112/0
#   0 | 0
#   118 | 18251
#
# Node 2.6 Epoch 41 Summary:
#   MSE: 0.0455 | RMSE: 0.2124
#   MAE: 0.1682 | R²: 0.6223
#   Anomaly Detection: 112/0
#   0 | 0
#   118 | 18252
# EPOCH: 75
#
# Node 2.6 Epoch 42 Summary:
#   MSE: 0.0450 | RMSE: 0.2114
#   MAE: 0.1674 | R²: 0.6259
#   Anomaly Detection: 112/0
#   0 | 0
#   122 | 18582
#
# Node 2.5 Epoch 74 Summary:
#   MSE: 0.0211 | RMSE: 0.1451
#   MAE: 0.1107 | R²: 0.8249
#   Anomaly Detection: 112/0
#   0 | 0
#   122 | 18583
#
# Node 2.4 Epoch 48 Summary:
#   MSE: 0.0361 | RMSE: 0.1894
#   MAE: 0.1494 | R²: 0.7010
#   Anomaly Detection: 112/0
#   0 | 0
#   122 | 18584
# EPOCH: 76
#
# Node 2.5 Epoch 75 Summary:
#   MSE: 0.0215 | RMSE: 0.1464
#   MAE: 0.1118 | R²: 0.8217
#   Anomaly Detection: 112/0
#   0 | 0
#   122 | 18918
#
# Node 2.4 Epoch 49 Summary:
#   MSE: 0.0361 | RMSE: 0.1893
#   MAE: 0.1494 | R²: 0.7012
#   Anomaly Detection: 112/0
#   0 | 0
#   122 | 18919
#
# Node 2.6 Epoch 43 Summary:
#   MSE: 0.0453 | RMSE: 0.2120
#   MAE: 0.1678 | R²: 0.6232
#   Anomaly Detection: 112/0
#   0 | 0
#   122 | 18920
# EPOCH: 77
#
# Node 2.6 Epoch 44 Summary:
#   MSE: 0.0456 | RMSE: 0.2125
#   MAE: 0.1683 | R²: 0.6213
#   Anomaly Detection: 112/0
#   0 | 0
#   122 | 19254
#
# Node 2.4 Epoch 50 Summary:
#   MSE: 0.0361 | RMSE: 0.1890
#   MAE: 0.1491 | R²: 0.7017
#   Anomaly Detection: 112/0
#   0 | 0
#   122 | 19255
#
# Node 2.5 Epoch 76 Summary:
#   MSE: 0.0215 | RMSE: 0.1464
#   MAE: 0.1120 | R²: 0.8219
#   Anomaly Detection: 112/0
#   0 | 0
#   122 | 19256
# EPOCH: 78
#
# Node 2.5 Epoch 77 Summary:
#   MSE: 0.0213 | RMSE: 0.1457
#   MAE: 0.1114 | R²: 0.8233
#   Anomaly Detection: 112/0
#   0 | 0
#   125 | 19587
#
# Node 2.4 Epoch 51 Summary:
#   MSE: 0.0357 | RMSE: 0.1881
#   MAE: 0.1483 | R²: 0.7044
#   Anomaly Detection: 112/0
#   0 | 0
#   125 | 19588
#
# Node 2.6 Epoch 45 Summary:
#   MSE: 0.0453 | RMSE: 0.2118
#   MAE: 0.1677 | R²: 0.6237
#   Anomaly Detection: 112/0
#   0 | 0
#   125 | 19589
# EPOCH: 79
#
# Node 2.4 Epoch 52 Summary:
#   MSE: 0.0351 | RMSE: 0.1865
#   MAE: 0.1470 | R²: 0.7095
#   Anomaly Detection: 112/0
#   0 | 0
#   127 | 19921
#
# Node 2.5 Epoch 78 Summary:
#   MSE: 0.0207 | RMSE: 0.1438
#   MAE: 0.1097 | R²: 0.8281
#   Anomaly Detection: 112/0
#   0 | 0
#   127 | 19922
#
# Node 2.6 Epoch 46 Summary:
#   MSE: 0.0454 | RMSE: 0.2122
#   MAE: 0.1681 | R²: 0.6226
#   Anomaly Detection: 112/0
#   0 | 0
#   127 | 19923
# EPOCH: 80
#
# Node 2.4 Epoch 53 Summary:
#   MSE: 0.0358 | RMSE: 0.1886
#   MAE: 0.1487 | R²: 0.7038
#   Anomaly Detection: 112/0
#   0 | 0
#   130 | 20254
#
# Node 2.5 Epoch 79 Summary:
#   MSE: 0.0206 | RMSE: 0.1434
#   MAE: 0.1094 | R²: 0.8289
#   Anomaly Detection: 112/0
#   0 | 0
#   130 | 20255
#
# Node 2.6 Epoch 47 Summary:
#   MSE: 0.0449 | RMSE: 0.2109
#   MAE: 0.1670 | R²: 0.6271
#   Anomaly Detection: 112/0
#   0 | 0
#   130 | 20256
# EPOCH: 81
#
# Node 2.5 Epoch 80 Summary:
#   MSE: 0.0205 | RMSE: 0.1432
#   MAE: 0.1092 | R²: 0.8296
#   Anomaly Detection: 112/0
#   0 | 0
#   132 | 20588
#
# Node 2.4 Epoch 54 Summary:
#   MSE: 0.0350 | RMSE: 0.1863
#   MAE: 0.1469 | R²: 0.7105
#   Anomaly Detection: 112/0
#   0 | 0
#   132 | 20589
#
# Node 2.6 Epoch 48 Summary:
#   MSE: 0.0445 | RMSE: 0.2100
#   MAE: 0.1662 | R²: 0.6307
#   Anomaly Detection: 112/0
#   0 | 0
#   132 | 20590
# EPOCH: 82
#
# Node 2.4 Epoch 55 Summary:
#   MSE: 0.0348 | RMSE: 0.1858
#   MAE: 0.1464 | R²: 0.7117
#   Anomaly Detection: 112/0
#   0 | 0
#   135 | 20921
#
# Node 2.5 Epoch 81 Summary:
#   MSE: 0.0201 | RMSE: 0.1415
#   MAE: 0.1078 | R²: 0.8336
#   Anomaly Detection: 112/0
#   0 | 0
#   135 | 20922
#
# Node 2.6 Epoch 49 Summary:
#   MSE: 0.0439 | RMSE: 0.2086
#   MAE: 0.1652 | R²: 0.6353
#   Anomaly Detection: 112/0
#   0 | 0
#   135 | 20923
# EPOCH: 83
#
# Node 2.6 Epoch 50 Summary:
#   MSE: 0.0432 | RMSE: 0.2070
#   MAE: 0.1637 | R²: 0.6407
#   Anomaly Detection: 112/0
#   0 | 0
#   135 | 21257
#
# Node 2.5 Epoch 82 Summary:
#   MSE: 0.0201 | RMSE: 0.1417
#   MAE: 0.1079 | R²: 0.8333
#   Anomaly Detection: 112/0
#   0 | 0
#   135 | 21258
#
# Node 2.4 Epoch 56 Summary:
#   MSE: 0.0347 | RMSE: 0.1856
#   MAE: 0.1463 | R²: 0.7126
#   Anomaly Detection: 112/0
#   0 | 0
#   135 | 21259
# EPOCH: 84
#
# Node 2.6 Epoch 51 Summary:
#   MSE: 0.0437 | RMSE: 0.2082
#   MAE: 0.1646 | R²: 0.6367
#   Anomaly Detection: 112/0
#   0 | 0
#   138 | 21590
#
# Node 2.5 Epoch 83 Summary:
#   MSE: 0.0201 | RMSE: 0.1416
#   MAE: 0.1081 | R²: 0.8332
#   Anomaly Detection: 112/0
#   0 | 0
#   138 | 21591
#
# Node 2.4 Epoch 57 Summary:
#   MSE: 0.0346 | RMSE: 0.1853
#   MAE: 0.1460 | R²: 0.7138
#   Anomaly Detection: 112/0
#   0 | 0
#   138 | 21592
# EPOCH: 85
#
# Node 2.6 Epoch 52 Summary:
#   MSE: 0.0437 | RMSE: 0.2084
#   MAE: 0.1649 | R²: 0.6367
#   Anomaly Detection: 112/0
#   0 | 0
#   141 | 21923
#
# Node 2.5 Epoch 84 Summary:
#   MSE: 0.0198 | RMSE: 0.1405
#   MAE: 0.1071 | R²: 0.8359
#   Anomaly Detection: 112/0
#   0 | 0
#   141 | 21924
#
# Node 2.4 Epoch 58 Summary:
#   MSE: 0.0340 | RMSE: 0.1838
#   MAE: 0.1447 | R²: 0.7185
#   Anomaly Detection: 112/0
#   0 | 0
#   141 | 21925
# EPOCH: 86
#
# Node 2.4 Epoch 59 Summary:
#   MSE: 0.0344 | RMSE: 0.1847
#   MAE: 0.1453 | R²: 0.7157
#   Anomaly Detection: 112/0
#   0 | 0
#   143 | 22257
#
# Node 2.5 Epoch 85 Summary:
#   MSE: 0.0198 | RMSE: 0.1406
#   MAE: 0.1072 | R²: 0.8357
#   Anomaly Detection: 112/0
#   0 | 0
#   143 | 22258
#
# Node 2.6 Epoch 53 Summary:
#   MSE: 0.0431 | RMSE: 0.2068
#   MAE: 0.1636 | R²: 0.6417
#   Anomaly Detection: 112/0
#   0 | 0
#   143 | 22259
# EPOCH: 87
#
# Node 2.4 Epoch 60 Summary:
#   MSE: 0.0339 | RMSE: 0.1836
#   MAE: 0.1445 | R²: 0.7193
#   Anomaly Detection: 112/0
#   0 | 0
#   144 | 22592
#
# Node 2.6 Epoch 54 Summary:
#   MSE: 0.0441 | RMSE: 0.2090
#   MAE: 0.1655 | R²: 0.6338
#   Anomaly Detection: 112/0
#   0 | 0
#   144 | 22593
#
# Node 2.5 Epoch 86 Summary:
#   MSE: 0.0196 | RMSE: 0.1400
#   MAE: 0.1066 | R²: 0.8371
#   Anomaly Detection: 112/0
#   0 | 0
#   144 | 22594
# EPOCH: 88
#
# Node 2.5 Epoch 87 Summary:
#   MSE: 0.0201 | RMSE: 0.1416
#   MAE: 0.1079 | R²: 0.8332
#   Anomaly Detection: 112/0
#   0 | 0
#   145 | 22927
#
# Node 2.6 Epoch 55 Summary:
#   MSE: 0.0432 | RMSE: 0.2070
#   MAE: 0.1636 | R²: 0.6407
#   Anomaly Detection: 112/0
#   0 | 0
#   145 | 22928
#
# Node 2.4 Epoch 61 Summary:
#   MSE: 0.0342 | RMSE: 0.1840
#   MAE: 0.1449 | R²: 0.7172
#   Anomaly Detection: 112/0
#   0 | 0
#   145 | 22929
# EPOCH: 89
#
# Node 2.4 Epoch 62 Summary:
#   MSE: 0.0350 | RMSE: 0.1860
#   MAE: 0.1464 | R²: 0.7107
#   Anomaly Detection: 112/0
#   0 | 0
#   148 | 23260
#
# Node 2.5 Epoch 88 Summary:
#   MSE: 0.0204 | RMSE: 0.1427
#   MAE: 0.1089 | R²: 0.8305
#   Anomaly Detection: 112/0
#   0 | 0
#   148 | 23261
#
# Node 2.6 Epoch 56 Summary:
#   MSE: 0.0436 | RMSE: 0.2078
#   MAE: 0.1643 | R²: 0.6375
#   Anomaly Detection: 112/0
#   0 | 0
#   149 | 23261
# EPOCH: 90
#
# Node 2.6 Epoch 57 Summary:
#   MSE: 0.0427 | RMSE: 0.2060
#   MAE: 0.1629 | R²: 0.6452
#   Anomaly Detection: 112/0
#   0 | 0
#   152 | 23592
#
# Node 2.4 Epoch 63 Summary:
#   MSE: 0.0335 | RMSE: 0.1824
#   MAE: 0.1435 | R²: 0.7230
#   Anomaly Detection: 112/0
#   0 | 0
#   152 | 23593
#
# Node 2.5 Epoch 89 Summary:
#   MSE: 0.0194 | RMSE: 0.1391
#   MAE: 0.1058 | R²: 0.8390
#   Anomaly Detection: 112/0
#   0 | 0
#   152 | 23594
# EPOCH: 91
#
# Node 2.4 Epoch 64 Summary:
#   MSE: 0.0335 | RMSE: 0.1824
#   MAE: 0.1435 | R²: 0.7226
#   Anomaly Detection: 112/0
#   0 | 0
#   155 | 23925
#
# Node 2.6 Epoch 58 Summary:
#   MSE: 0.0418 | RMSE: 0.2036
#   MAE: 0.1609 | R²: 0.6528
#   Anomaly Detection: 112/0
#   0 | 0
#   155 | 23926
#
# Node 2.5 Epoch 90 Summary:
#   MSE: 0.0191 | RMSE: 0.1380
#   MAE: 0.1049 | R²: 0.8416
#   Anomaly Detection: 112/0
#   0 | 0
#   155 | 23927
# EPOCH: 92
#
# Node 2.6 Epoch 59 Summary:
#   MSE: 0.0414 | RMSE: 0.2028
#   MAE: 0.1601 | R²: 0.6561
#   Anomaly Detection: 112/0
#   0 | 0
#   157 | 24259
#
# Node 2.5 Epoch 91 Summary:
#   MSE: 0.0191 | RMSE: 0.1379
#   MAE: 0.1047 | R²: 0.8419
#   Anomaly Detection: 112/0
#   0 | 0
#   157 | 24260
#
# Node 2.4 Epoch 65 Summary:
#   MSE: 0.0332 | RMSE: 0.1816
#   MAE: 0.1428 | R²: 0.7253
#   Anomaly Detection: 112/0
#   0 | 0
#   157 | 24261
# EPOCH: 93
#
# Node 2.4 Epoch 66 Summary:
#   MSE: 0.0343 | RMSE: 0.1844
#   MAE: 0.1452 | R²: 0.7160
#   Anomaly Detection: 112/0
#   0 | 0
#   160 | 24592
#
# Node 2.6 Epoch 60 Summary:
#   MSE: 0.0421 | RMSE: 0.2042
#   MAE: 0.1612 | R²: 0.6503
#   Anomaly Detection: 112/0
#   0 | 0
#   160 | 24593
#
# Node 2.5 Epoch 92 Summary:
#   MSE: 0.0197 | RMSE: 0.1400
#   MAE: 0.1067 | R²: 0.8368
#   Anomaly Detection: 112/0
#   0 | 0
#   160 | 24594
# EPOCH: 94
#
# Node 2.6 Epoch 61 Summary:
#   MSE: 0.0419 | RMSE: 0.2035
#   MAE: 0.1605 | R²: 0.6521
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 24926
#
# Node 2.4 Epoch 67 Summary:
#   MSE: 0.0342 | RMSE: 0.1839
#   MAE: 0.1447 | R²: 0.7172
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 24927
# EPOCH: 95
#
# Node 2.4 Epoch 68 Summary:
#   MSE: 0.0307 | RMSE: 0.1749
#   MAE: 0.1371 | R²: 0.7457
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 25150
#
# Node 2.6 Epoch 62 Summary:
#   MSE: 0.0441 | RMSE: 0.2094
#   MAE: 0.1655 | R²: 0.6340
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 25151
# EPOCH: 96
#
# Node 2.4 Epoch 69 Summary:
#   MSE: 0.0303 | RMSE: 0.1737
#   MAE: 0.1361 | R²: 0.7497
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 25374
#
# Node 2.6 Epoch 63 Summary:
#   MSE: 0.0434 | RMSE: 0.2080
#   MAE: 0.1644 | R²: 0.6392
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 25375
# EPOCH: 97
#
# Node 2.4 Epoch 70 Summary:
#   MSE: 0.0305 | RMSE: 0.1744
#   MAE: 0.1367 | R²: 0.7474
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 25598
#
# Node 2.6 Epoch 64 Summary:
#   MSE: 0.0432 | RMSE: 0.2076
#   MAE: 0.1640 | R²: 0.6407
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 25599
# EPOCH: 98
#
# Node 2.6 Epoch 65 Summary:
#   MSE: 0.0430 | RMSE: 0.2071
#   MAE: 0.1636 | R²: 0.6426
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 25822
#
# Node 2.4 Epoch 71 Summary:
#   MSE: 0.0300 | RMSE: 0.1730
#   MAE: 0.1355 | R²: 0.7515
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 25823
# EPOCH: 99
#
# Node 2.6 Epoch 66 Summary:
#   MSE: 0.0431 | RMSE: 0.2072
#   MAE: 0.1636 | R²: 0.6418
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 26046
#
# Node 2.4 Epoch 72 Summary:
#   MSE: 0.0305 | RMSE: 0.1744
#   MAE: 0.1367 | R²: 0.7474
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 26047
# EPOCH: 100
#
# Node 2.4 Epoch 73 Summary:
#   MSE: 0.0302 | RMSE: 0.1735
#   MAE: 0.1359 | R²: 0.7502
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 26270
#
# Node 2.6 Epoch 67 Summary:
#   MSE: 0.0429 | RMSE: 0.2068
#   MAE: 0.1632 | R²: 0.6433
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 26271
# EPOCH: 101
#
# Node 2.4 Epoch 74 Summary:
#   MSE: 0.0284 | RMSE: 0.1684
#   MAE: 0.1316 | R²: 0.7648
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 26494
#
# Node 2.6 Epoch 68 Summary:
#   MSE: 0.0406 | RMSE: 0.2013
#   MAE: 0.1585 | R²: 0.6624
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 26495
# EPOCH: 102
#
# Node 2.6 Epoch 69 Summary:
#   MSE: 0.0397 | RMSE: 0.1989
#   MAE: 0.1564 | R²: 0.6701
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 26718
#
# Node 2.4 Epoch 75 Summary:
#   MSE: 0.0279 | RMSE: 0.1667
#   MAE: 0.1300 | R²: 0.7695
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 26719
# EPOCH: 103
#
# Node 2.4 Epoch 76 Summary:
#   MSE: 0.0284 | RMSE: 0.1681
#   MAE: 0.1313 | R²: 0.7649
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 26942
#
# Node 2.6 Epoch 70 Summary:
#   MSE: 0.0401 | RMSE: 0.1996
#   MAE: 0.1570 | R²: 0.6672
#   Anomaly Detection: 112/0
#   0 | 0
#   162 | 26943
# EPOCH: 104
#
# Node 2.6 Epoch 71 Summary:
#   MSE: 0.0395 | RMSE: 0.1983
#   MAE: 0.1558 | R²: 0.6717
#   Anomaly Detection: 112/0
#   0 | 0
#   164 | 27164
# EPOCH: 105
#
# Node 2.6 Epoch 72 Summary:
#   MSE: 0.0243 | RMSE: 0.1555
#   MAE: 0.1188 | R²: 0.7978
#   Anomaly Detection: 112/0
#   0 | 0
#   168 | 27272
# EPOCH: 106
#
# Node 2.6 Epoch 73 Summary:
#   MSE: 0.0208 | RMSE: 0.1439
#   MAE: 0.1088 | R²: 0.8273
#   Anomaly Detection: 112/0
#   0 | 0
#   170 | 27382
# EPOCH: 107
#
# Node 2.6 Epoch 74 Summary:
#   MSE: 0.0203 | RMSE: 0.1419
#   MAE: 0.1074 | R²: 0.8316
#   Anomaly Detection: 112/0
#   0 | 0
#   175 | 27489
# EPOCH: 108
#
# Node 2.6 Epoch 75 Summary:
#   MSE: 0.0193 | RMSE: 0.1383
#   MAE: 0.1043 | R²: 0.8396
#   Anomaly Detection: 112/0
#   0 | 0
#   182 | 27594
# EPOCH: 109
#
# Node 2.6 Epoch 76 Summary:
#   MSE: 0.0192 | RMSE: 0.1376
#   MAE: 0.1040 | R²: 0.8403
#   Anomaly Detection: 112/0
#   0 | 0
#   184 | 27704
# EPOCH: 110
#
# Node 2.6 Epoch 77 Summary:
#   MSE: 0.0183 | RMSE: 0.1345
#   MAE: 0.1016 | R²: 0.8478
#   Anomaly Detection: 112/0
#   0 | 0
#   187 | 27813
# EPOCH: 111
#
# Node 2.6 Epoch 78 Summary:
#   MSE: 0.0171 | RMSE: 0.1300
#   MAE: 0.0981 | R²: 0.8576
#   Anomaly Detection: 112/0
#   0 | 0
#   193 | 27919
# EPOCH: 112
#
# Node 2.6 Epoch 79 Summary:
#   MSE: 0.0162 | RMSE: 0.1264
#   MAE: 0.0952 | R²: 0.8656
#   Anomaly Detection: 112/0
#   0 | 0
#   195 | 28029
# EPOCH: 113
#
# Node 2.6 Epoch 80 Summary:
#   MSE: 0.0170 | RMSE: 0.1290
#   MAE: 0.0973 | R²: 0.8589
#   Anomaly Detection: 112/0
#   0 | 0
#   198 | 28138
# EPOCH: 114
#
# Node 2.6 Epoch 81 Summary:
#   MSE: 0.0154 | RMSE: 0.1233
#   MAE: 0.0929 | R²: 0.8717
#   Anomaly Detection: 112/0
#   0 | 0
#   200 | 28248
# EPOCH: 115
#
# Node 2.6 Epoch 82 Summary:
#   MSE: 0.0141 | RMSE: 0.1177
#   MAE: 0.0886 | R²: 0.8830
#   Anomaly Detection: 112/0
#   0 | 0
#   201 | 28359
# EPOCH: 116
#
# Node 2.6 Epoch 83 Summary:
#   MSE: 0.0145 | RMSE: 0.1194
#   MAE: 0.0900 | R²: 0.8795
#   Anomaly Detection: 112/0
#   0 | 0
#   207 | 28465
# EPOCH: 117
#
# Node 2.6 Epoch 84 Summary:
#   MSE: 0.0134 | RMSE: 0.1150
#   MAE: 0.0867 | R²: 0.8883
#   Anomaly Detection: 112/0
#   0 | 0
#   208 | 28576
# EPOCH: 118
#
# Node 2.6 Epoch 85 Summary:
#   MSE: 0.0132 | RMSE: 0.1138
#   MAE: 0.0858 | R²: 0.8906
#   Anomaly Detection: 112/0
#   0 | 0
#   210 | 28686
# EPOCH: 119
#
# Node 2.6 Epoch 86 Summary:
#   MSE: 0.0122 | RMSE: 0.1096
#   MAE: 0.0825 | R²: 0.8986
#   Anomaly Detection: 112/0
#   0 | 0
#   210 | 28798
# EPOCH: 120
#
# Node 2.6 Epoch 87 Summary:
#   MSE: 0.0128 | RMSE: 0.1120
#   MAE: 0.0845 | R²: 0.8934
#   Anomaly Detection: 112/0
#   0 | 0
#   210 | 28910
# EPOCH: 121
#
# Node 2.6 Epoch 88 Summary:
#   MSE: 0.0114 | RMSE: 0.1061
#   MAE: 0.0799 | R²: 0.9053
#   Anomaly Detection: 112/0
#   0 | 0
#   210 | 29022
# EPOCH: 122
#
# Node 2.6 Epoch 89 Summary:
#   MSE: 0.0113 | RMSE: 0.1054
#   MAE: 0.0795 | R²: 0.9061
#   Anomaly Detection: 112/0
#   0 | 0
#   210 | 29134
# EPOCH: 123
#
# Node 2.6 Epoch 90 Summary:
#   MSE: 0.0111 | RMSE: 0.1048
#   MAE: 0.0789 | R²: 0.9076
#   Anomaly Detection: 112/0
#   0 | 0
#   210 | 29246
# EPOCH: 124
#
# Node 2.6 Epoch 91 Summary:
#   MSE: 0.0108 | RMSE: 0.1028
#   MAE: 0.0774 | R²: 0.9105
#   Anomaly Detection: 112/0
#   0 | 0
#   212 | 29356
# EPOCH: 125
#
# Node 2.6 Epoch 92 Summary:
#   MSE: 0.0104 | RMSE: 0.1009
#   MAE: 0.0761 | R²: 0.9139
#   Anomaly Detection: 112/0
#   0 | 0
#   216 | 29464
# EPOCH: 126
#
# Node 2.6 Epoch 93 Summary:
#   MSE: 0.0106 | RMSE: 0.1019
#   MAE: 0.0769 | R²: 0.9120
#   Anomaly Detection: 112/0
#   0 | 0
#   217 | 29575
# EPOCH: 127
#
# Node 2.6 Epoch 94 Summary:
#   MSE: 0.0100 | RMSE: 0.0990
#   MAE: 0.0747 | R²: 0.9171
#   Anomaly Detection: 112/0
#   0 | 0
#   217 | 29687
# EPOCH: 128
#
# Node 2.6 Epoch 95 Summary:
#   MSE: 0.0119 | RMSE: 0.1064
#   MAE: 0.0806 | R²: 0.9008
#   Anomaly Detection: 112/0
#   0 | 0
#   220 | 29796
# EPOCH: 129
#
# Node 2.6 Epoch 96 Summary:
#   MSE: 0.0104 | RMSE: 0.1006
#   MAE: 0.0758 | R²: 0.9137
#   Anomaly Detection: 112/0
#   0 | 0
#   222 | 29906
# EPOCH: 130
#
# Node 2.6 Epoch 97 Summary:
#   MSE: 0.0091 | RMSE: 0.0947
#   MAE: 0.0712 | R²: 0.9246
#   Anomaly Detection: 112/0
#   0 | 0
#   222 | 30018
# EPOCH: 131
#
# Node 2.6 Epoch 98 Summary:
#   MSE: 0.0085 | RMSE: 0.0916
#   MAE: 0.0691 | R²: 0.9290
#   Anomaly Detection: 112/0
#   0 | 0
#   225 | 30127
# EPOCH: 132
#
# Node 2.6 Epoch 99 Summary:
#   MSE: 0.0090 | RMSE: 0.0941
#   MAE: 0.0709 | R²: 0.9254
#   Anomaly Detection: 112/0
#   0 | 0
#   228 | 30236
# EPOCH: 133
#
# Node 2.6 Epoch 100 Summary:
#   MSE: 0.0081 | RMSE: 0.0894
#   MAE: 0.0674 | R²: 0.9324
#   Anomaly Detection: 112/0
#   0 | 0
#   232 | 30344
# EPOCH: 134
#
# Node 2.6 Epoch 101 Summary:
#   MSE: 0.0099 | RMSE: 0.0961
#   MAE: 0.0729 | R²: 0.9179
#   Anomaly Detection: 112/0
#   0 | 0
#   233 | 30455
# EPOCH: 135
#
# Node 2.6 Epoch 102 Summary:
#   MSE: 0.0102 | RMSE: 0.0989
#   MAE: 0.0748 | R²: 0.9157
#   Anomaly Detection: 112/0
#   0 | 0
#   235 | 30565
# EPOCH: 136
#
# Node 2.6 Epoch 103 Summary:
#   MSE: 0.0079 | RMSE: 0.0875
#   MAE: 0.0659 | R²: 0.9340
#   Anomaly Detection: 112/0
#   0 | 0
#   241 | 30671
# EPOCH: 137
#
# Node 2.6 Epoch 104 Summary:
#   MSE: 0.0090 | RMSE: 0.0936
#   MAE: 0.0707 | R²: 0.9254
#   Anomaly Detection: 112/0
#   0 | 0
#   242 | 30782
# EPOCH: 138
#
# Node 2.6 Epoch 105 Summary:
#   MSE: 0.0075 | RMSE: 0.0860
#   MAE: 0.0648 | R²: 0.9378
#   Anomaly Detection: 112/0
#   0 | 0
#   243 | 30893
# EPOCH: 139
#
# Node 2.6 Epoch 106 Summary:
#   MSE: 0.0072 | RMSE: 0.0832
#   MAE: 0.0628 | R²: 0.9404
#   Anomaly Detection: 112/0
#   0 | 0
#   243 | 31005
# EPOCH: 140
#
# Node 2.6 Epoch 107 Summary:
#   MSE: 0.0067 | RMSE: 0.0812
#   MAE: 0.0614 | R²: 0.9445
#   Anomaly Detection: 112/0
#   0 | 0
#   243 | 31117
# EPOCH: 141
#
# Node 2.6 Epoch 108 Summary:
#   MSE: 0.0128 | RMSE: 0.1097
#   MAE: 0.0835 | R²: 0.8936
#   Anomaly Detection: 112/0
#   0 | 0
#   247 | 31225
# EPOCH: 142
#
# Node 2.6 Epoch 109 Summary:
#   MSE: 0.0064 | RMSE: 0.0798
#   MAE: 0.0603 | R²: 0.9467
#   Anomaly Detection: 112/0
#   0 | 0
#   248 | 31336
# EPOCH: 143
#
# Node 2.6 Epoch 110 Summary:
#   MSE: 0.0073 | RMSE: 0.0848
#   MAE: 0.0640 | R²: 0.9393
#   Anomaly Detection: 112/0
#   0 | 0
#   250 | 31446
# EPOCH: 144
#
# Node 2.6 Epoch 111 Summary:
#   MSE: 0.0081 | RMSE: 0.0888
#   MAE: 0.0670 | R²: 0.9324
#   Anomaly Detection: 112/0
#   0 | 0
#   251 | 31557
# EPOCH: 145
#
# Node 2.6 Epoch 112 Summary:
#   MSE: 0.0062 | RMSE: 0.0766
#   MAE: 0.0581 | R²: 0.9481
#   Anomaly Detection: 112/0
#   0 | 0
#   252 | 31668
# EPOCH: 146
#
# Node 2.6 Epoch 113 Summary:
#   MSE: 0.0111 | RMSE: 0.1023
#   MAE: 0.0775 | R²: 0.9075
#   Anomaly Detection: 112/0
#   0 | 0
#   255 | 31777
# EPOCH: 147
#
# Node 2.6 Epoch 114 Summary:
#   MSE: 0.0058 | RMSE: 0.0759
#   MAE: 0.0574 | R²: 0.9519
#   Anomaly Detection: 112/0
#   0 | 0
#   255 | 31889
# EPOCH: 148
#
# Node 2.6 Epoch 115 Summary:
#   MSE: 0.0078 | RMSE: 0.0862
#   MAE: 0.0655 | R²: 0.9350
#   Anomaly Detection: 112/0
#   0 | 0
#   257 | 31999
# EPOCH: 149
#
# Node 2.5 Epoch 93 Summary:
#   MSE: 0.0202 | RMSE: 0.1417
#   MAE: 0.1082 | R²: 0.8326
#   Anomaly Detection: 112/0
#   0 | 0
#   258 | 32110
#
# Node 2.6 Epoch 116 Summary:
#   MSE: 0.0078 | RMSE: 0.0860
#   MAE: 0.0650 | R²: 0.9354
#   Anomaly Detection: 112/0
#   0 | 0
#   258 | 32111
# EPOCH: 150
#
# Node 2.6 Epoch 117 Summary:
#   MSE: 0.0120 | RMSE: 0.1078
#   MAE: 0.0824 | R²: 0.9004
#   Anomaly Detection: 112/0
#   0 | 0
#   258 | 32334
#
# Node 2.5 Epoch 94 Summary:
#   MSE: 0.0249 | RMSE: 0.1574
#   MAE: 0.1207 | R²: 0.7937
#   Anomaly Detection: 112/0
#   0 | 0
#   258 | 32335
# EPOCH: 151
#
# Node 2.5 Epoch 95 Summary:
#   MSE: 0.0224 | RMSE: 0.1495
#   MAE: 0.1142 | R²: 0.8141
#   Anomaly Detection: 112/0
#   0 | 0
#   258 | 32558
# EPOCH: 152
#
# Node 2.5 Epoch 96 Summary:
#   MSE: 0.0128 | RMSE: 0.1127
#   MAE: 0.0838 | R²: 0.8942
#   Anomaly Detection: 112/0
#   0 | 0
#   259 | 32669
# EPOCH: 153
#
# Node 2.5 Epoch 97 Summary:
#   MSE: 0.0113 | RMSE: 0.1060
#   MAE: 0.0787 | R²: 0.9063
#   Anomaly Detection: 112/0
#   0 | 0
#   259 | 32781
# EPOCH: 154
#
# Node 2.5 Epoch 98 Summary:
#   MSE: 0.0105 | RMSE: 0.1021
#   MAE: 0.0755 | R²: 0.9131
#   Anomaly Detection: 112/0
#   0 | 0
#   261 | 32891
# EPOCH: 155
#
# Node 2.6 Epoch 118 Summary:
#   MSE: 0.0111 | RMSE: 0.1042
#   MAE: 0.0793 | R²: 0.9081
#   Anomaly Detection: 112/0
#   0 | 0
#   262 | 33002
#
# Node 2.5 Epoch 99 Summary:
#   MSE: 0.0101 | RMSE: 0.1002
#   MAE: 0.0742 | R²: 0.9160
#   Anomaly Detection: 112/0
#   0 | 0
#   262 | 33003
# EPOCH: 156
#
# Node 2.5 Epoch 100 Summary:
#   MSE: 0.0131 | RMSE: 0.1140
#   MAE: 0.0850 | R²: 0.8910
#   Anomaly Detection: 112/0
#   0 | 0
#   262 | 33226
#
# Node 2.6 Epoch 119 Summary:
#   MSE: 0.0096 | RMSE: 0.0976
#   MAE: 0.0740 | R²: 0.9201
#   Anomaly Detection: 112/0
#   0 | 0
#   262 | 33227
# EPOCH: 157
#
# Node 2.6 Epoch 120 Summary:
#   MSE: 0.0092 | RMSE: 0.0953
#   MAE: 0.0722 | R²: 0.9234
#   Anomaly Detection: 112/0
#   0 | 0
#   263 | 33449
#
# Node 2.5 Epoch 101 Summary:
#   MSE: 0.0124 | RMSE: 0.1109
#   MAE: 0.0824 | R²: 0.8969
#   Anomaly Detection: 112/0
#   0 | 0
#   263 | 33450
# EPOCH: 158
#
# Node 2.5 Epoch 102 Summary:
#   MSE: 0.0123 | RMSE: 0.1101
#   MAE: 0.0818 | R²: 0.8982
#   Anomaly Detection: 112/0
#   0 | 0
#   263 | 33673
#
# Node 2.6 Epoch 121 Summary:
#   MSE: 0.0088 | RMSE: 0.0932
#   MAE: 0.0705 | R²: 0.9269
#   Anomaly Detection: 112/0
#   0 | 0
#   263 | 33674
# EPOCH: 159
#
# Node 2.5 Epoch 103 Summary:
#   MSE: 0.0120 | RMSE: 0.1090
#   MAE: 0.0809 | R²: 0.9002
#   Anomaly Detection: 112/0
#   0 | 0
#   263 | 33897
#
# Node 2.6 Epoch 122 Summary:
#   MSE: 0.0085 | RMSE: 0.0917
#   MAE: 0.0695 | R²: 0.9291
#   Anomaly Detection: 112/0
#   0 | 0
#   263 | 33898
# EPOCH: 160
#
# Node 2.6 Epoch 123 Summary:
#   MSE: 0.0087 | RMSE: 0.0927
#   MAE: 0.0701 | R²: 0.9276
#   Anomaly Detection: 112/0
#   0 | 0
#   263 | 34121
#
# Node 2.5 Epoch 104 Summary:
#   MSE: 0.0121 | RMSE: 0.1095
#   MAE: 0.0812 | R²: 0.8995
#   Anomaly Detection: 112/0
#   0 | 0
#   263 | 34122
# EPOCH: 161
#
# Node 2.5 Epoch 105 Summary:
#   MSE: 0.0115 | RMSE: 0.1064
#   MAE: 0.0789 | R²: 0.9049
#   Anomaly Detection: 112/0
#   0 | 0
#   265 | 34343
#
# Node 2.6 Epoch 124 Summary:
#   MSE: 0.0081 | RMSE: 0.0895
#   MAE: 0.0676 | R²: 0.9327
#   Anomaly Detection: 112/0
#   0 | 0
#   265 | 34344
# EPOCH: 162
#
# Node 2.5 Epoch 106 Summary:
#   MSE: 0.0118 | RMSE: 0.1076
#   MAE: 0.0798 | R²: 0.9023
#   Anomaly Detection: 112/0
#   0 | 0
#   267 | 34565
#
# Node 2.6 Epoch 125 Summary:
#   MSE: 0.0090 | RMSE: 0.0937
#   MAE: 0.0709 | R²: 0.9256
#   Anomaly Detection: 112/0
#   0 | 0
#   267 | 34566
# EPOCH: 163
#
# Node 2.6 Epoch 126 Summary:
#   MSE: 0.0078 | RMSE: 0.0880
#   MAE: 0.0664 | R²: 0.9353
#   Anomaly Detection: 112/0
#   0 | 0
#   267 | 34789
#
# Node 2.5 Epoch 107 Summary:
#   MSE: 0.0105 | RMSE: 0.1019
#   MAE: 0.0753 | R²: 0.9132
#   Anomaly Detection: 112/0
#   0 | 0
#   267 | 34790
# EPOCH: 164
#
# Node 2.6 Epoch 127 Summary:
#   MSE: 0.0080 | RMSE: 0.0890
#   MAE: 0.0673 | R²: 0.9333
#   Anomaly Detection: 112/0
#   0 | 0
#   269 | 35011
#
# Node 2.5 Epoch 108 Summary:
#   MSE: 0.0106 | RMSE: 0.1025
#   MAE: 0.0759 | R²: 0.9117
#   Anomaly Detection: 112/0
#   0 | 0
#   269 | 35012
# EPOCH: 165
#
# Node 2.6 Epoch 128 Summary:
#   MSE: 0.0087 | RMSE: 0.0925
#   MAE: 0.0701 | R²: 0.9273
#   Anomaly Detection: 112/0
#   0 | 0
#   271 | 35233
#
# Node 2.5 Epoch 109 Summary:
#   MSE: 0.0116 | RMSE: 0.1070
#   MAE: 0.0795 | R²: 0.9037
#   Anomaly Detection: 112/0
#   0 | 0
#   271 | 35234
# EPOCH: 166
#
# Node 2.6 Epoch 129 Summary:
#   MSE: 0.0086 | RMSE: 0.0920
#   MAE: 0.0696 | R²: 0.9284
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 35456
#
# Node 2.5 Epoch 110 Summary:
#   MSE: 0.0116 | RMSE: 0.1070
#   MAE: 0.0794 | R²: 0.9037
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 35457
# EPOCH: 167
#
# Node 2.6 Epoch 130 Summary:
#   MSE: 0.0081 | RMSE: 0.0893
#   MAE: 0.0674 | R²: 0.9331
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 35680
#
# Node 2.5 Epoch 111 Summary:
#   MSE: 0.0111 | RMSE: 0.1047
#   MAE: 0.0777 | R²: 0.9078
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 35681
# EPOCH: 168
#
# Node 2.6 Epoch 131 Summary:
#   MSE: 0.0079 | RMSE: 0.0885
#   MAE: 0.0669 | R²: 0.9343
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 35904
#
# Node 2.5 Epoch 112 Summary:
#   MSE: 0.0110 | RMSE: 0.1044
#   MAE: 0.0774 | R²: 0.9085
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 35905
# EPOCH: 169
#
# Node 2.6 Epoch 132 Summary:
#   MSE: 0.0088 | RMSE: 0.0923
#   MAE: 0.0699 | R²: 0.9271
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 36128
#
# Node 2.5 Epoch 113 Summary:
#   MSE: 0.0115 | RMSE: 0.1066
#   MAE: 0.0791 | R²: 0.9042
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 36129
# EPOCH: 170
#
# Node 2.6 Epoch 133 Summary:
#   MSE: 0.0077 | RMSE: 0.0869
#   MAE: 0.0655 | R²: 0.9364
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 36352
#
# Node 2.5 Epoch 114 Summary:
#   MSE: 0.0106 | RMSE: 0.1022
#   MAE: 0.0757 | R²: 0.9123
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 36353
# EPOCH: 171
#
# Node 2.5 Epoch 115 Summary:
#   MSE: 0.0113 | RMSE: 0.1058
#   MAE: 0.0786 | R²: 0.9060
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 36576
#
# Node 2.6 Epoch 134 Summary:
#   MSE: 0.0079 | RMSE: 0.0885
#   MAE: 0.0668 | R²: 0.9343
#   Anomaly Detection: 112/0
#   0 | 0
#   272 | 36577
# EPOCH: 172
#
# Node 2.5 Epoch 116 Summary:
#   MSE: 0.0098 | RMSE: 0.0983
#   MAE: 0.0724 | R²: 0.9190
#   Anomaly Detection: 112/0
#   0 | 0
#   279 | 36793
#
# Node 2.6 Epoch 135 Summary:
#   MSE: 0.0071 | RMSE: 0.0838
#   MAE: 0.0632 | R²: 0.9411
#   Anomaly Detection: 112/0
#   0 | 0
#   279 | 36794
# EPOCH: 173
#
# Node 2.5 Epoch 117 Summary:
#   MSE: 0.0111 | RMSE: 0.1045
#   MAE: 0.0775 | R²: 0.9080
#   Anomaly Detection: 112/0
#   0 | 0
#   281 | 37015
#
# ...
#   MAE: 0.0308 | R²: 0.9853
#   Anomaly Detection: 112/0
#   568 | 16
#   494 | 124123
# EPOCH: 534
#
# Node 2.4 Epoch 344 Summary:
#   MSE: 0.0030 | RMSE: 0.0542
#   MAE: 0.0403 | R²: 0.9755
#   Anomaly Detection: 112/0
#   568 | 16
#   494 | 124236
#
# Node 2.5 Epoch 350 Summary:
#   MSE: 0.8897 | RMSE: 0.1288
#   MAE: 0.1006 | R²: 0.9776
#   Anomaly Detection: 112/1
#   571 | 16
#   494 | 124345
# EPOCH: 535
#
# Node 2.4 Epoch 345 Summary:
#   MSE: 2.5944 | RMSE: 0.3122
#   MAE: 0.2463 | R²: 0.9506
#   Anomaly Detection: 112/3
#   573 | 16
#   494 | 124462
#
# Node 2.5 Epoch 351 Summary:
#   MSE: 0.8965 | RMSE: 0.1297
#   MAE: 0.1018 | R²: 0.9771
#   Anomaly Detection: 112/1
#   573 | 16
#   494 | 124569
# EPOCH: 536
#
# Node 2.4 Epoch 346 Summary:
#   MSE: 0.9125 | RMSE: 0.1422
#   MAE: 0.1102 | R²: 0.9681
#   Anomaly Detection: 112/1
#   575 | 16
#   494 | 124685
#
# Node 2.5 Epoch 352 Summary:
#   MSE: 0.9162 | RMSE: 0.1304
#   MAE: 0.1015 | R²: 0.9773
#   Anomaly Detection: 112/1
#   576 | 16
#   494 | 124793
# EPOCH: 537
#
# Node 2.4 Epoch 347 Summary:
#   MSE: 0.8660 | RMSE: 0.1397
#   MAE: 0.1084 | R²: 0.9683
#   Anomaly Detection: 112/1
#   576 | 16
#   494 | 124911
#
# Node 2.5 Epoch 353 Summary:
#   MSE: 0.8788 | RMSE: 0.1281
#   MAE: 0.1004 | R²: 0.9777
#   Anomaly Detection: 112/1
#   577 | 16
#   494 | 125017
# EPOCH: 538
#
# Node 2.4 Epoch 348 Summary:
#   MSE: 0.0029 | RMSE: 0.0534
#   MAE: 0.0397 | R²: 0.9763
#   Anomaly Detection: 112/0
#   577 | 16
#   494 | 125133
#
# Node 2.5 Epoch 354 Summary:
#   MSE: 0.0017 | RMSE: 0.0409
#   MAE: 0.0302 | R²: 0.9860
#   Anomaly Detection: 112/0
#   577 | 16
#   494 | 125241
# EPOCH: 539
#
# Node 2.4 Epoch 349 Summary:
#   MSE: 0.8537 | RMSE: 0.1395
#   MAE: 0.1087 | R²: 0.9679
#   Anomaly Detection: 112/1
#   579 | 16
#   494 | 125357
#
# Node 2.5 Epoch 355 Summary:
#   MSE: 0.9070 | RMSE: 0.1307
#   MAE: 0.1025 | R²: 0.9768
#   Anomaly Detection: 112/1
#   579 | 16
#   494 | 125466
# EPOCH: 540
#
# Node 2.4 Epoch 350 Summary:
#   MSE: 0.8779 | RMSE: 0.1402
#   MAE: 0.1086 | R²: 0.9684
#   Anomaly Detection: 112/1
#   580 | 16
#   494 | 125583
#
# Node 2.5 Epoch 356 Summary:
#   MSE: 0.0016 | RMSE: 0.0394
#   MAE: 0.0292 | R²: 0.9871
#   Anomaly Detection: 112/0
#   580 | 16
#   494 | 125689
# EPOCH: 541
#
# Node 2.4 Epoch 351 Summary:
#   MSE: 1.7409 | RMSE: 0.2257
#   MAE: 0.1766 | R²: 0.9604
#   Anomaly Detection: 112/2
#   583 | 16
#   494 | 125808
#
# Node 2.5 Epoch 357 Summary:
#   MSE: 1.7356 | RMSE: 0.2140
#   MAE: 0.1689 | R²: 0.9691
#   Anomaly Detection: 112/2
#   585 | 16
#   494 | 125912
# EPOCH: 542
#
# Node 2.4 Epoch 352 Summary:
#   MSE: 1.8054 | RMSE: 0.2294
#   MAE: 0.1801 | R²: 0.9600
#   Anomaly Detection: 112/2
#   587 | 16
#   494 | 126031
# EPOCH: 543
#
# Node 2.5 Epoch 358 Summary:
#   MSE: 0.8735 | RMSE: 0.1276
#   MAE: 0.0996 | R²: 0.9779
#   Anomaly Detection: 112/1
#   587 | 16
#   494 | 126136
#
# Node 2.4 Epoch 353 Summary:
#   MSE: 0.0028 | RMSE: 0.0528
#   MAE: 0.0393 | R²: 0.9769
#   Anomaly Detection: 112/0
#   587 | 16
#   494 | 126256
# EPOCH: 544
#
# Node 2.5 Epoch 359 Summary:
#   MSE: 0.0018 | RMSE: 0.0417
#   MAE: 0.0308 | R²: 0.9853
#   Anomaly Detection: 112/0
#   588 | 16
#   494 | 126359
#
# Node 2.4 Epoch 354 Summary:
#   MSE: 0.9158 | RMSE: 0.1419
#   MAE: 0.1102 | R²: 0.9685
#   Anomaly Detection: 112/1
#   590 | 16
#   494 | 126478
# EPOCH: 545
#
# Node 2.5 Epoch 360 Summary:
#   MSE: 3.4055 | RMSE: 0.3808
#   MAE: 0.3007 | R²: 0.9530
#   Anomaly Detection: 112/4
#   592 | 16
#   494 | 126587
#
# Node 2.4 Epoch 355 Summary:
#   MSE: 1.7412 | RMSE: 0.2251
#   MAE: 0.1764 | R²: 0.9609
#   Anomaly Detection: 112/2
#   596 | 16
#   494 | 126701
# EPOCH: 546
#
# Node 2.5 Epoch 361 Summary:
#   MSE: 1.7808 | RMSE: 0.2160
#   MAE: 0.1697 | R²: 0.9693
#   Anomaly Detection: 112/2
#   596 | 16
#   494 | 126811
#
# Node 2.4 Epoch 356 Summary:
#   MSE: 0.9514 | RMSE: 0.1434
#   MAE: 0.1109 | R²: 0.9688
#   Anomaly Detection: 112/1
#   597 | 16
#   494 | 126926
# EPOCH: 547
#
# Node 2.5 Epoch 362 Summary:
#   MSE: 0.0016 | RMSE: 0.0398
#   MAE: 0.0294 | R²: 0.9868
#   Anomaly Detection: 112/0
#   597 | 16
#   494 | 127033
#
# Node 2.4 Epoch 357 Summary:
#   MSE: 0.9397 | RMSE: 0.1422
#   MAE: 0.1110 | R²: 0.9693
#   Anomaly Detection: 112/1
#   598 | 16
#   494 | 127151
# EPOCH: 548
#
# Node 2.5 Epoch 363 Summary:
#   MSE: 0.0016 | RMSE: 0.0398
#   MAE: 0.0295 | R²: 0.9868
#   Anomaly Detection: 112/0
#   599 | 16
#   494 | 127256
#
# Node 2.4 Epoch 358 Summary:
#   MSE: 1.7713 | RMSE: 0.2272
#   MAE: 0.1782 | R²: 0.9605
#   Anomaly Detection: 112/2
#   600 | 16
#   494 | 127377
# EPOCH: 549
#
# Node 2.5 Epoch 364 Summary:
#   MSE: 0.9301 | RMSE: 0.1302
#   MAE: 0.1020 | R²: 0.9779
#   Anomaly Detection: 112/1
#   601 | 16
#   494 | 127480
#
# Node 2.4 Epoch 359 Summary:
#   MSE: 0.0027 | RMSE: 0.0517
#   MAE: 0.0386 | R²: 0.9778
#   Anomaly Detection: 112/0
#   603 | 16
#   494 | 127597
# EPOCH: 550
#
# Node 2.5 Epoch 365 Summary:
#   MSE: 3.5114 | RMSE: 0.3860
#   MAE: 0.3050 | R²: 0.9530
#   Anomaly Detection: 112/4
#   606 | 16
#   494 | 127707
#
# Node 2.4 Epoch 360 Summary:
#   MSE: 1.7537 | RMSE: 0.2258
#   MAE: 0.1769 | R²: 0.9609
#   Anomaly Detection: 112/2
#   608 | 16
#   494 | 127820
# EPOCH: 551
#
# Node 2.5 Epoch 366 Summary:
#   MSE: 0.8921 | RMSE: 0.1290
#   MAE: 0.1004 | R²: 0.9774
#   Anomaly Detection: 112/1
#   610 | 16
#   494 | 127929
#
# Node 2.4 Epoch 361 Summary:
#   MSE: 1.7541 | RMSE: 0.2262
#   MAE: 0.1780 | R²: 0.9606
#   Anomaly Detection: 112/2
#   611 | 16
#   494 | 128046
# EPOCH: 552
#
# Node 2.5 Epoch 367 Summary:
#   MSE: 0.9111 | RMSE: 0.1289
#   MAE: 0.1006 | R²: 0.9782
#   Anomaly Detection: 112/1
#   611 | 16
#   494 | 128153
#
# Node 2.4 Epoch 362 Summary:
#   MSE: 0.8735 | RMSE: 0.1384
#   MAE: 0.1080 | R²: 0.9697
#   Anomaly Detection: 112/1
#   612 | 16
#   494 | 128271
# EPOCH: 553
#
# Node 2.5 Epoch 368 Summary:
#   MSE: 0.9062 | RMSE: 0.1277
#   MAE: 0.1005 | R²: 0.9788
#   Anomaly Detection: 112/1
#   614 | 16
#   494 | 128376
#
# Node 2.4 Epoch 363 Summary:
#   MSE: 0.9546 | RMSE: 0.1425
#   MAE: 0.1105 | R²: 0.9697
#   Anomaly Detection: 112/1
#   614 | 16
#   494 | 128495
# EPOCH: 554
#
# Node 2.5 Epoch 369 Summary:
#   MSE: 0.0016 | RMSE: 0.0396
#   MAE: 0.0293 | R²: 0.9869
#   Anomaly Detection: 112/0
#   614 | 16
#   494 | 128600
#
# Node 2.4 Epoch 364 Summary:
#   MSE: 0.0026 | RMSE: 0.0514
#   MAE: 0.0383 | R²: 0.9781
#   Anomaly Detection: 112/0
#   616 | 16
#   494 | 128716
# EPOCH: 555
#
# Node 2.5 Epoch 370 Summary:
#   MSE: 2.5933 | RMSE: 0.2985
#   MAE: 0.2349 | R²: 0.9612
#   Anomaly Detection: 112/3
#   619 | 16
#   494 | 128826
#
# Node 2.4 Epoch 365 Summary:
#   MSE: 2.6200 | RMSE: 0.3117
#   MAE: 0.2456 | R²: 0.9523
#   Anomaly Detection: 112/3
#   621 | 16
#   494 | 128941
# EPOCH: 556
#
# Node 2.5 Epoch 371 Summary:
#   MSE: 0.9213 | RMSE: 0.1288
#   MAE: 0.1006 | R²: 0.9786
#   Anomaly Detection: 112/1
#   621 | 16
#   494 | 129050
#
# Node 2.4 Epoch 366 Summary:
#   MSE: 0.8900 | RMSE: 0.1394
#   MAE: 0.1092 | R²: 0.9695
#   Anomaly Detection: 112/1
#   623 | 16
#   494 | 129166
# EPOCH: 557
#
# Node 2.5 Epoch 372 Summary:
#   MSE: 1.7392 | RMSE: 0.2142
#   MAE: 0.1695 | R²: 0.9691
#   Anomaly Detection: 112/2
#   624 | 16
#   494 | 129274
#
# Node 2.4 Epoch 367 Summary:
#   MSE: 0.8825 | RMSE: 0.1387
#   MAE: 0.1076 | R²: 0.9699
#   Anomaly Detection: 112/1
#   625 | 16
#   494 | 129390
# EPOCH: 558
#
# Node 2.5 Epoch 373 Summary:
#   MSE: 0.8811 | RMSE: 0.1272
#   MAE: 0.0986 | R²: 0.9783
#   Anomaly Detection: 112/1
#   627 | 16
#   494 | 129498
#
# Node 2.4 Epoch 368 Summary:
#   MSE: 0.8923 | RMSE: 0.1402
#   MAE: 0.1089 | R²: 0.9690
#   Anomaly Detection: 112/1
#   627 | 16
#   494 | 129613
# EPOCH: 559
#
# Node 2.5 Epoch 374 Summary:
#   MSE: 0.0016 | RMSE: 0.0400
#   MAE: 0.0296 | R²: 0.9866
#   Anomaly Detection: 112/0
#   628 | 16
#   494 | 129720
#
# Node 2.4 Epoch 369 Summary:
#   MSE: 1.7990 | RMSE: 0.2275
#   MAE: 0.1794 | R²: 0.9614
#   Anomaly Detection: 112/2
#   631 | 16
#   495 | 129836
# EPOCH: 560
#
# Node 2.5 Epoch 375 Summary:
#   MSE: 1.7648 | RMSE: 0.2149
#   MAE: 0.1692 | R²: 0.9694
#   Anomaly Detection: 112/2
#   631 | 16
#   495 | 129944
#
# Node 2.4 Epoch 370 Summary:
#   MSE: 0.0027 | RMSE: 0.0514
#   MAE: 0.0384 | R²: 0.9780
#   Anomaly Detection: 112/0
#   631 | 16
#   495 | 130060
# EPOCH: 561
#
# Node 2.5 Epoch 376 Summary:
#   MSE: 0.0017 | RMSE: 0.0411
#   MAE: 0.0304 | R²: 0.9858
#   Anomaly Detection: 112/0
#   631 | 16
#   495 | 130169
#
# Node 2.4 Epoch 371 Summary:
#   MSE: 0.9374 | RMSE: 0.1416
#   MAE: 0.1103 | R²: 0.9697
#   Anomaly Detection: 112/1
#   632 | 16
#   495 | 130285
# EPOCH: 562
#
# Node 2.5 Epoch 377 Summary:
#   MSE: 0.0015 | RMSE: 0.0389
#   MAE: 0.0288 | R²: 0.9873
#   Anomaly Detection: 112/0
#   633 | 16
#   496 | 130390
#
# Node 2.4 Epoch 372 Summary:
#   MSE: 0.8830 | RMSE: 0.1377
#   MAE: 0.1072 | R²: 0.9708
#   Anomaly Detection: 112/1
#   633 | 16
#   496 | 130509
# EPOCH: 563
#
# Node 2.5 Epoch 378 Summary:
#   MSE: 0.0014 | RMSE: 0.0377
#   MAE: 0.0280 | R²: 0.9881
#   Anomaly Detection: 112/0
#   633 | 16
#   496 | 130613
#
# Node 2.4 Epoch 373 Summary:
#   MSE: 1.8352 | RMSE: 0.2293
#   MAE: 0.1811 | R²: 0.9613
#   Anomaly Detection: 112/2
#   636 | 16
#   496 | 130735
# EPOCH: 564
#
# Node 2.5 Epoch 379 Summary:
#   MSE: 1.8271 | RMSE: 0.2184
#   MAE: 0.1726 | R²: 0.9692
#   Anomaly Detection: 112/2
#   637 | 16
#   496 | 130837
#
# Node 2.4 Epoch 374 Summary:
#   MSE: 0.0026 | RMSE: 0.0506
#   MAE: 0.0378 | R²: 0.9788
#   Anomaly Detection: 112/0
#   638 | 16
#   496 | 130956
# EPOCH: 565
#
# Node 2.5 Epoch 380 Summary:
#   MSE: 0.8831 | RMSE: 0.1263
#   MAE: 0.0985 | R²: 0.9790
#   Anomaly Detection: 112/1
#   638 | 16
#   496 | 131063
#
# Node 2.4 Epoch 375 Summary:
#   MSE: 1.7220 | RMSE: 0.2234
#   MAE: 0.1753 | R²: 0.9616
#   Anomaly Detection: 112/2
#   640 | 16
#   496 | 131183
# EPOCH: 566
#
# Node 2.5 Epoch 381 Summary:
#   MSE: 0.9033 | RMSE: 0.1294
#   MAE: 0.1013 | R²: 0.9774
#   Anomaly Detection: 112/1
#   641 | 16
#   496 | 131285
#
# Node 2.4 Epoch 376 Summary:
#   MSE: 1.7253 | RMSE: 0.2236
#   MAE: 0.1756 | R²: 0.9615
#   Anomaly Detection: 112/2
#   644 | 16
#   496 | 131407
# EPOCH: 567
#
# Node 2.5 Epoch 382 Summary:
#   MSE: 1.7877 | RMSE: 0.2149
#   MAE: 0.1695 | R²: 0.9702
#   Anomaly Detection: 112/2
#   645 | 16
#   496 | 131509
#
# Node 2.4 Epoch 377 Summary:
#   MSE: 0.0025 | RMSE: 0.0502
#   MAE: 0.0375 | R²: 0.9791
#   Anomaly Detection: 112/0
#   645 | 16
#   496 | 131629
# EPOCH: 568
#
# Node 2.5 Epoch 383 Summary:
#   MSE: 0.0015 | RMSE: 0.0388
#   MAE: 0.0287 | R²: 0.9874
#   Anomaly Detection: 112/0
#   646 | 16
#   496 | 131732
#
# Node 2.4 Epoch 378 Summary:
#   MSE: 0.8969 | RMSE: 0.1392
#   MAE: 0.1088 | R²: 0.9700
#   Anomaly Detection: 112/1
#   646 | 16
#   496 | 131854
# EPOCH: 569
#
# Node 2.5 Epoch 384 Summary:
#   MSE: 0.9165 | RMSE: 0.1302
#   MAE: 0.1018 | R²: 0.9774
#   Anomaly Detection: 112/1
#   648 | 16
#   496 | 131957
#
# Node 2.4 Epoch 379 Summary:
#   MSE: 0.9257 | RMSE: 0.1411
#   MAE: 0.1093 | R²: 0.9696
#   Anomaly Detection: 112/1
#   649 | 16
#   496 | 132078
# EPOCH: 570
#
# Node 2.5 Epoch 385 Summary:
#   MSE: 2.5674 | RMSE: 0.2962
#   MAE: 0.2339 | R²: 0.9619
#   Anomaly Detection: 112/3
#   651 | 16
#   496 | 132184
#
# Node 2.4 Epoch 380 Summary:
#   MSE: 1.7545 | RMSE: 0.2241
#   MAE: 0.1772 | R²: 0.9623
#   Anomaly Detection: 112/2
#   653 | 16
#   496 | 132302
# EPOCH: 571
#
# Node 2.5 Epoch 386 Summary:
#   MSE: 0.0015 | RMSE: 0.0383
#   MAE: 0.0284 | R²: 0.9877
#   Anomaly Detection: 112/0
#   654 | 16
#   496 | 132404
#
# Node 2.4 Epoch 381 Summary:
#   MSE: 2.6150 | RMSE: 0.3095
#   MAE: 0.2450 | R²: 0.9539
#   Anomaly Detection: 112/3
#   657 | 16
#   496 | 132527
# EPOCH: 572
#
# Node 2.5 Epoch 387 Summary:
#   MSE: 0.8838 | RMSE: 0.1261
#   MAE: 0.0984 | R²: 0.9792
#   Anomaly Detection: 112/1
#   658 | 16
#   496 | 132626
#
# Node 2.4 Epoch 382 Summary:
#   MSE: 0.9421 | RMSE: 0.1412
#   MAE: 0.1093 | R²: 0.9702
#   Anomaly Detection: 112/1
#   659 | 16
#   496 | 132752
# EPOCH: 573
#
# Node 2.5 Epoch 388 Summary:
#   MSE: 1.7581 | RMSE: 0.2135
#   MAE: 0.1680 | R²: 0.9702
#   Anomaly Detection: 112/2
#   660 | 16
#   496 | 132852
#
# Node 2.4 Epoch 383 Summary:
#   MSE: 0.0025 | RMSE: 0.0497
#   MAE: 0.0371 | R²: 0.9795
#   Anomaly Detection: 112/0
#   661 | 16
#   496 | 132974
# EPOCH: 574
#
# Node 2.5 Epoch 389 Summary:
#   MSE: 0.9427 | RMSE: 0.1302
#   MAE: 0.1011 | R²: 0.9784
#   Anomaly Detection: 112/1
#   662 | 16
#   496 | 133077
#
# Node 2.4 Epoch 384 Summary:
#   MSE: 1.7756 | RMSE: 0.2256
#   MAE: 0.1774 | R²: 0.9619
#   Anomaly Detection: 112/2
#   664 | 16
#   496 | 133199
# EPOCH: 575
#
# Node 2.5 Epoch 390 Summary:
#   MSE: 2.5367 | RMSE: 0.2944
#   MAE: 0.2332 | R²: 0.9620
#   Anomaly Detection: 112/3
#   668 | 16
#   496 | 133301
#
# Node 2.4 Epoch 385 Summary:
#   MSE: 3.4999 | RMSE: 0.3953
#   MAE: 0.3115 | R²: 0.9457
#   Anomaly Detection: 112/4
#   671 | 16
#   496 | 133424
# EPOCH: 576
#
# Node 2.5 Epoch 391 Summary:
#   MSE: 0.9267 | RMSE: 0.1282
#   MAE: 0.1009 | R²: 0.9792
#   Anomaly Detection: 112/1
#   672 | 16
#   496 | 133522
#
# Node 2.4 Epoch 386 Summary:
#   MSE: 1.7411 | RMSE: 0.2240
#   MAE: 0.1763 | R²: 0.9619
#   Anomaly Detection: 112/2
#   674 | 16
#   496 | 133649
# EPOCH: 577
#
# Node 2.5 Epoch 392 Summary:
#   MSE: 1.6896 | RMSE: 0.2121
#   MAE: 0.1680 | R²: 0.9687
#   Anomaly Detection: 112/2
#   675 | 16
#   496 | 133748
#
# Node 2.4 Epoch 387 Summary:
#   MSE: 0.0027 | RMSE: 0.0514
#   MAE: 0.0384 | R²: 0.9780
#   Anomaly Detection: 112/0
#   677 | 16
#   496 | 133869
# EPOCH: 578
#
# Node 2.5 Epoch 393 Summary:
#   MSE: 2.5949 | RMSE: 0.2969
#   MAE: 0.2342 | R²: 0.9624
#   Anomaly Detection: 112/3
#   678 | 16
#   496 | 133975
#
# Node 2.4 Epoch 388 Summary:
#   MSE: 0.0024 | RMSE: 0.0493
#   MAE: 0.0369 | R²: 0.9798
#   Anomaly Detection: 112/0
#   678 | 16
#   496 | 134093
# EPOCH: 579
#
# Node 2.5 Epoch 394 Summary:
#   MSE: 0.0016 | RMSE: 0.0391
#   MAE: 0.0289 | R²: 0.9871
#   Anomaly Detection: 112/0
#   678 | 16
#   496 | 134198
#
# Node 2.4 Epoch 389 Summary:
#   MSE: 0.8860 | RMSE: 0.1376
#   MAE: 0.1073 | R²: 0.9709
#   Anomaly Detection: 112/1
#   681 | 16
#   496 | 134315
# EPOCH: 580
#
# Node 2.4 Epoch 390 Summary:
#   MSE: 3.4383 | RMSE: 0.3842
#   MAE: 0.3044 | R²: 0.9518
#   Anomaly Detection: 112/4
#   685 | 16
#   496 | 134433
# EPOCH: 581
# EPOCH: 582
#
# Node 2.4 Epoch 391 Summary:
#   MSE: 1.7488 | RMSE: 0.2133
#   MAE: 0.1677 | R²: 0.9701
#   Anomaly Detection: 112/2
#   687 | 16
#   496 | 134545
# EPOCH: 583
#
# Node 2.4 Epoch 392 Summary:
#   MSE: 0.9000 | RMSE: 0.1269
#   MAE: 0.1002 | R²: 0.9792
#   Anomaly Detection: 112/1
#   688 | 16
#   496 | 134657
# EPOCH: 584
#
# Node 2.4 Epoch 393 Summary:
#   MSE: 0.9027 | RMSE: 0.1266
#   MAE: 0.0981 | R²: 0.9795
#   Anomaly Detection: 112/1
#   689 | 16
#   496 | 134769
# EPOCH: 585
#
# Node 2.4 Epoch 394 Summary:
#   MSE: 0.0014 | RMSE: 0.0373
#   MAE: 0.0279 | R²: 0.9885
#   Anomaly Detection: 112/0
#   689 | 16
#   496 | 134881
# EPOCH: 586
#
# Node 2.4 Epoch 395 Summary:
#   MSE: 0.0014 | RMSE: 0.0370
#   MAE: 0.0277 | R²: 0.9886
#   Anomaly Detection: 112/0
#   689 | 16
#   496 | 134993
# EPOCH: 587
#
# Node 2.4 Epoch 396 Summary:
#   MSE: 0.9303 | RMSE: 0.1269
#   MAE: 0.0990 | R²: 0.9802
#   Anomaly Detection: 112/1
#   690 | 16
#   496 | 135105
# EPOCH: 588
#
# Node 2.4 Epoch 397 Summary:
#   MSE: 0.8677 | RMSE: 0.1236
#   MAE: 0.0968 | R²: 0.9803
#   Anomaly Detection: 112/1
#   691 | 16
#   496 | 135217
# EPOCH: 589
#
# Node 2.4 Epoch 398 Summary:
#   MSE: 1.7357 | RMSE: 0.2099
#   MAE: 0.1665 | R²: 0.9718
#   Anomaly Detection: 112/2
#   693 | 16
#   496 | 135329
# EPOCH: 590
#
# Node 2.4 Epoch 399 Summary:
#   MSE: 0.0013 | RMSE: 0.0359
#   MAE: 0.0269 | R²: 0.9893
#   Anomaly Detection: 112/0
#   693 | 16
#   496 | 135441
# EPOCH: 591
#
# Node 2.4 Epoch 400 Summary:
#   MSE: 1.7655 | RMSE: 0.2110
#   MAE: 0.1670 | R²: 0.9721
#   Anomaly Detection: 112/2
#   695 | 16
#   496 | 135553
# EPOCH: 592
#
# Node 2.4 Epoch 401 Summary:
#   MSE: 0.9185 | RMSE: 0.1254
#   MAE: 0.0982 | R²: 0.9808
#   Anomaly Detection: 112/1
#   696 | 16
#   496 | 135665
# EPOCH: 593
#
# Node 2.4 Epoch 402 Summary:
#   MSE: 0.8868 | RMSE: 0.1235
#   MAE: 0.0971 | R²: 0.9809
#   Anomaly Detection: 112/1
#   697 | 16
#   496 | 135777
# EPOCH: 594
#
# Node 2.4 Epoch 403 Summary:
#   MSE: 0.0012 | RMSE: 0.0353
#   MAE: 0.0266 | R²: 0.9897
#   Anomaly Detection: 112/0
#   697 | 16
#   496 | 135889
# EPOCH: 595
#
# Node 2.4 Epoch 404 Summary:
#   MSE: 1.7627 | RMSE: 0.2102
#   MAE: 0.1669 | R²: 0.9725
#   Anomaly Detection: 112/2
#   699 | 16
#   496 | 136001
# EPOCH: 596
#
# Node 2.4 Epoch 405 Summary:
#   MSE: 0.8422 | RMSE: 0.1209
#   MAE: 0.0947 | R²: 0.9811
#   Anomaly Detection: 112/1
#   700 | 16
#   496 | 136113
# EPOCH: 597
#
# Node 2.4 Epoch 406 Summary:
#   MSE: 0.8672 | RMSE: 0.1221
#   MAE: 0.0965 | R²: 0.9812
#   Anomaly Detection: 112/1
#   701 | 16
#   496 | 136225
# EPOCH: 598
#
# Node 2.4 Epoch 407 Summary:
#   MSE: 0.0012 | RMSE: 0.0346
#   MAE: 0.0262 | R²: 0.9901
#   Anomaly Detection: 112/0
#   701 | 16
#   496 | 136337
# EPOCH: 599
#
# Node 2.4 Epoch 408 Summary:
#   MSE: 1.7529 | RMSE: 0.2094
#   MAE: 0.1664 | R²: 0.9727
#   Anomaly Detection: 112/2
#   703 | 16
#   496 | 136449

# %%
TP = 703
FP = 169
TN = 68231
FN = 16

# %%
Accuracy = (TP + TN) / (TP + TN + FP + FN)

# %%
Recall = TP / (TP + FN)

# %%
FPR = FP / (FP + TN)
