# %%
import random
from pathlib import Path

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %%
METHOD_NAME = "retrofl"
SCHEDULE_NAME = "continue"

RANDOM_SEED = 42
batch_size = 128
learning_rate = 1e-3
val_ratio = 0.1
prox_mu = 1e-4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(RANDOM_SEED)

print("device:", DEVICE)
print("torch version:", torch.__version__)
print("method:", METHOD_NAME, "| schedule:", SCHEDULE_NAME)
# Out:
# device: cuda
# torch version: 2.10.0+cu130
# method: retrofl | schedule: continue

# %%
class MLP(nn.Module):
    def __init__(self, input_dim, output_dim=8):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.LeakyReLU(),
            nn.Linear(512, 1024),
            nn.LeakyReLU(),
            nn.Linear(1024, 512),
            nn.LeakyReLU(),
            nn.Linear(512, 256),
            nn.LeakyReLU(),
            nn.Linear(256, output_dim),
        )

    def forward(self, x):
        return self.net(x)

# %%
class ParaServer:
    def __init__(self, input_dim, learning_rate=learning_rate):
        self.input_dim = input_dim
        self.model = MLP(input_dim=input_dim).to(DEVICE)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=learning_rate)
        self.scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
            self.optimizer,
            T_max=600,
            eta_min=1e-6
        )
        self.freqs = {}

    def upload(self, grads, freq, score):
        self.freqs[freq] = max(0.0, float(score.detach()))
        
        self.optimizer.zero_grad()
        for p, g in zip(self.model.parameters(), grads):
            p.grad = g.detach()
        self.optimizer.step()
        return self.download()

    def download(self):
        model = MLP(self.input_dim).to(DEVICE)
        model.load_state_dict(self.model.state_dict())
        return model

# %%
def validate(model, X, y):
    model.eval()
    with torch.no_grad():
        y_pred = model(X)
        mse = torch.mean((y_pred - y) ** 2)
        rmse = torch.sqrt(mse)
        mae = torch.mean(torch.abs(y_pred - y))

        y_mean = torch.mean(y)
        denom = torch.sum((y - y_mean) ** 2)
        if torch.abs(denom) < 1e-12:
            r2 = torch.tensor(float("nan"), device=y.device)
        else:
            r2 = 1 - torch.sum((y_pred - y) ** 2) / denom

    return {
        "mse": float(mse.item()),
        "rmse": float(rmse.item()),
        "mae": float(mae.item()),
        "r2": float(r2.item()),
    }

# %%
class Node:
    def __init__(self, dsName, freq, input_dim, val_ratio=0.2, batch_size=batch_size):
        self.freq = freq
        self.input_dim = input_dim
        self.otfreqs = {}
        self.anchor_model = None

        dataset = pd.read_csv(dsName, encoding="utf-8").sample(
            frac=1, random_state=RANDOM_SEED
        ).reset_index(drop=True)

        X_all = dataset.loc[:, "freq":"L4"].to_numpy(dtype=np.float32)
        y_all = dataset.loc[:, "S11r":"S41i"].to_numpy(dtype=np.float32)

        n_total = X_all.shape[0]
        n_val = max(1, int(n_total * val_ratio))
        n_train = n_total - n_val

        self.X_train = X_all[:n_train]
        self.y_train = y_all[:n_train]
        self.X_vali = X_all[n_train:]
        self.y_vali = y_all[n_train:]

        self.X_train_t = torch.from_numpy(self.X_train).to(DEVICE)
        self.y_train_t = torch.from_numpy(self.y_train).to(DEVICE)

        self.X_vali_t = torch.from_numpy(self.X_vali).to(DEVICE)
        self.y_vali_t = torch.from_numpy(self.y_vali).to(DEVICE)

        train_ds = TensorDataset(
            torch.from_numpy(self.X_train),
            torch.from_numpy(self.y_train),
        )
        self.train_loader = DataLoader(
            train_ds,
            batch_size=batch_size,
            shuffle=True,
            drop_last=False,
        )

        print(
            "client {} | train:{} | val:{}".format(
                self.freq, self.X_train.shape[0], self.X_vali.shape[0]
            )
        )

    def train(self, ps, global_round=None, first_epoch=False):
        if first_epoch:
            self.anchor_model = ps.download()
            self.anchor_model.eval()
            self.otfreqs = dict(ps.freqs)

        model = ps.download()
        model.train()

        for X_batch, y_batch in self.train_loader:
            X_batch = X_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)

            model.zero_grad(set_to_none=True)
            y_pred = model(X_batch)
            tr_mse = torch.mean((y_pred - y_batch) ** 2)
            tr_mse.backward()

            grads = [p.grad.detach().clone() for p in model.parameters()]

            y_mean = torch.mean(y_batch)
            denom = torch.sum((y_batch - y_mean) ** 2)
            if torch.abs(denom) < 1e-12:
                tr_r2 = torch.tensor(float("nan"), device=DEVICE)
            else:
                tr_r2 = 1 - torch.sum((y_pred - y_batch) ** 2) / denom

            sum_r2 = 1.0
            if self.anchor_model is not None:
                for k, v in self.otfreqs.items():
                    if abs(k - self.freq) < 1e-12 or abs(v) < 1e-12:
                        continue

                    X_i = X_batch.clone()
                    X_i[:, 0] = float(k)
                    with torch.no_grad():
                        y_i = self.anchor_model(X_i)

                    model.zero_grad(set_to_none=True)
                    y_pred_i = model(X_i)
                    loss_i = torch.mean((y_pred_i - y_i) ** 2)
                    loss_i.backward()

                    grad_i = [p.grad.detach().clone() for p in model.parameters()]
                    grads = [g + gi * float(v) for g, gi in zip(grads, grad_i)]
                    sum_r2 += float(v)

            avg_grads = [g / sum_r2 for g in grads]
            model = ps.upload(avg_grads, self.freq, tr_r2)
        
        train_metrics = validate(model, self.X_train_t, self.y_train_t)

        print("node:{} round:{}".format(self.freq, global_round))
        print(
            "train mse:{:.6f} rmse:{:.6f} mae:{:.6f} r2:{:.6f}".format(
                train_metrics["mse"],
                train_metrics["rmse"],
                train_metrics["mae"],
                train_metrics["r2"],
            )
        )
        return train_metrics["r2"], self.freq

# %%
r2_train = []
r2_vali = []
round_owner = []

r2_client_val = {
    2.4: [],
    2.5: [],
    2.6: [],
}

# %%
test_dataset = pd.read_csv("Test.csv", encoding="utf-8").sample(
    frac=1, random_state=RANDOM_SEED
).reset_index(drop=True)

X_vali = test_dataset.loc[:, "freq":"L4"].to_numpy(dtype=np.float32)
y_vali = test_dataset.loc[:, "S11r":"S41i"].to_numpy(dtype=np.float32)

input_dim = X_vali.shape[1]

X_vali_t = torch.from_numpy(X_vali).to(DEVICE)
y_vali_t = torch.from_numpy(y_vali).to(DEVICE)

print("global test shape:", X_vali.shape, y_vali.shape)
print("input_dim:", input_dim)
# Out:
# global test shape: (4500, 13) (4500, 8)
# input_dim: 13

# %%
ps = ParaServer(input_dim=input_dim, learning_rate=learning_rate)

nodeList = [
    Node("./24Train.csv", 2.4, input_dim=input_dim, val_ratio=val_ratio, batch_size=batch_size),
    Node("./25Train.csv", 2.5, input_dim=input_dim, val_ratio=val_ratio, batch_size=batch_size),
    Node("./26Train.csv", 2.6, input_dim=input_dim, val_ratio=val_ratio, batch_size=batch_size),
]
# Out:
# client 2.4 | train:25650 | val:2850
# client 2.5 | train:25650 | val:2850
# client 2.6 | train:25650 | val:2850

# %%
TOTAL_ROUNDS = 600
orders = [0, 1, 2]

turn = [
    np.array([[0, 100], [300, 400]]),
    np.array([[100, 200], [400, 500]]),
    np.array([[200, 300], [500, 600]]),
]
SHUFFLE_ORDERS = False

for global_round in range(TOTAL_ROUNDS):
    if SHUFFLE_ORDERS:
        random.shuffle(orders)

    for client_idx in orders:
        for start_round, end_round in turn[client_idx]:
            if start_round <= global_round < end_round:
                first_epoch = start_round == global_round
                cur_r2, owner = nodeList[client_idx].train(ps, global_round=global_round, first_epoch=first_epoch)
                r2_train.append(cur_r2)
                round_owner.append(owner)
    
    ps.scheduler.step()

    model = ps.download()
    all_r2 = validate(model, X_vali_t, y_vali_t)["r2"]
    r2_vali.append(all_r2)

    for node in nodeList:
        node_r2 = validate(model, node.X_vali_t, node.y_vali_t)["r2"]
        r2_client_val[node.freq].append(node_r2)

    print(
        "per-client val r2 | 2.4GHz: {:.6f} | 2.5GHz: {:.6f} | 2.6GHz: {:.6f}".format(
            r2_client_val[2.4][-1],
            r2_client_val[2.5][-1],
            r2_client_val[2.6][-1],
        )
    )
# Out:
# node:2.4 round:0
# train mse:0.073888 rmse:0.271824 mae:0.219337 r2:0.388903
# per-client val r2 | 2.4GHz: 0.390141 | 2.5GHz: 0.358390 | 2.6GHz: 0.319482
# node:2.4 round:1
# train mse:0.062837 rmse:0.250673 mae:0.200179 r2:0.480304
# per-client val r2 | 2.4GHz: 0.476829 | 2.5GHz: 0.447045 | 2.6GHz: 0.401630
# node:2.4 round:2
# train mse:0.058180 rmse:0.241205 mae:0.191710 r2:0.518819
# per-client val r2 | 2.4GHz: 0.512149 | 2.5GHz: 0.465532 | 2.6GHz: 0.386041
# node:2.4 round:3
# train mse:0.055222 rmse:0.234994 mae:0.187588 r2:0.543282
# per-client val r2 | 2.4GHz: 0.532297 | 2.5GHz: 0.495595 | 2.6GHz: 0.413464
# node:2.4 round:4
# train mse:0.049939 rmse:0.223469 mae:0.176753 r2:0.586980
# per-client val r2 | 2.4GHz: 0.578240 | 2.5GHz: 0.515923 | 2.6GHz: 0.392140
# node:2.4 round:5
# train mse:0.045258 rmse:0.212739 mae:0.167625 r2:0.625691
# per-client val r2 | 2.4GHz: 0.615590 | 2.5GHz: 0.512431 | 2.6GHz: 0.314968
# node:2.4 round:6
# train mse:0.040831 rmse:0.202067 mae:0.157678 r2:0.662305
# per-client val r2 | 2.4GHz: 0.654183 | 2.5GHz: 0.463833 | 2.6GHz: 0.149931
# node:2.4 round:7
# train mse:0.038582 rmse:0.196423 mae:0.151733 r2:0.680905
# per-client val r2 | 2.4GHz: 0.675554 | 2.5GHz: 0.395663 | 2.6GHz: -0.032360
# node:2.4 round:8
# train mse:0.034842 rmse:0.186660 mae:0.145057 r2:0.711837
# per-client val r2 | 2.4GHz: 0.704870 | 2.5GHz: 0.363463 | 2.6GHz: -0.096018
# node:2.4 round:9
# train mse:0.025531 rmse:0.159783 mae:0.122093 r2:0.788848
# per-client val r2 | 2.4GHz: 0.781660 | 2.5GHz: 0.555604 | 2.6GHz: 0.082585
# node:2.4 round:10
# train mse:0.022664 rmse:0.150547 mae:0.114476 r2:0.812552
# per-client val r2 | 2.4GHz: 0.805137 | 2.5GHz: 0.623625 | 2.6GHz: 0.124507
# node:2.4 round:11
# train mse:0.021597 rmse:0.146958 mae:0.111839 r2:0.821384
# per-client val r2 | 2.4GHz: 0.812689 | 2.5GHz: 0.515130 | 2.6GHz: -0.039417
# node:2.4 round:12
# train mse:0.021778 rmse:0.147573 mae:0.112945 r2:0.819886
# per-client val r2 | 2.4GHz: 0.810313 | 2.5GHz: 0.660189 | 2.6GHz: 0.133227
# node:2.4 round:13
# train mse:0.018738 rmse:0.136888 mae:0.103877 r2:0.845024
# per-client val r2 | 2.4GHz: 0.833812 | 2.5GHz: 0.494683 | 2.6GHz: -0.093059
# node:2.4 round:14
# train mse:0.018367 rmse:0.135527 mae:0.103359 r2:0.848091
# per-client val r2 | 2.4GHz: 0.840750 | 2.5GHz: 0.542384 | 2.6GHz: -0.029756
# node:2.4 round:15
# train mse:0.017968 rmse:0.134045 mae:0.101862 r2:0.851394
# per-client val r2 | 2.4GHz: 0.841635 | 2.5GHz: 0.607884 | 2.6GHz: 0.026782
# node:2.4 round:16
# train mse:0.018397 rmse:0.135635 mae:0.104484 r2:0.847849
# per-client val r2 | 2.4GHz: 0.839856 | 2.5GHz: 0.573777 | 2.6GHz: -0.013641
# node:2.4 round:17
# train mse:0.017357 rmse:0.131745 mae:0.100503 r2:0.856450
# per-client val r2 | 2.4GHz: 0.845724 | 2.5GHz: 0.513476 | 2.6GHz: -0.074424
# node:2.4 round:18
# train mse:0.016758 rmse:0.129454 mae:0.099059 r2:0.861400
# per-client val r2 | 2.4GHz: 0.849161 | 2.5GHz: 0.503851 | 2.6GHz: -0.094989
# node:2.4 round:19
# train mse:0.015589 rmse:0.124855 mae:0.094680 r2:0.871071
# per-client val r2 | 2.4GHz: 0.861606 | 2.5GHz: 0.493081 | 2.6GHz: -0.120910
# node:2.4 round:20
# train mse:0.014441 rmse:0.120171 mae:0.090972 r2:0.880564
# per-client val r2 | 2.4GHz: 0.868481 | 2.5GHz: 0.514230 | 2.6GHz: -0.110151
# node:2.4 round:21
# train mse:0.014506 rmse:0.120441 mae:0.091453 r2:0.880028
# per-client val r2 | 2.4GHz: 0.869230 | 2.5GHz: 0.485546 | 2.6GHz: -0.142092
# node:2.4 round:22
# train mse:0.017059 rmse:0.130611 mae:0.100220 r2:0.858911
# per-client val r2 | 2.4GHz: 0.848499 | 2.5GHz: 0.676425 | 2.6GHz: 0.070463
# node:2.4 round:23
# train mse:0.013495 rmse:0.116170 mae:0.088459 r2:0.888385
# per-client val r2 | 2.4GHz: 0.874197 | 2.5GHz: 0.531431 | 2.6GHz: -0.113994
# node:2.4 round:24
# train mse:0.013887 rmse:0.117843 mae:0.090099 r2:0.885146
# per-client val r2 | 2.4GHz: 0.873433 | 2.5GHz: 0.571555 | 2.6GHz: -0.072566
# node:2.4 round:25
# train mse:0.012479 rmse:0.111710 mae:0.084826 r2:0.896791
# per-client val r2 | 2.4GHz: 0.885353 | 2.5GHz: 0.524436 | 2.6GHz: -0.120330
# node:2.4 round:26
# train mse:0.013067 rmse:0.114311 mae:0.086701 r2:0.891929
# per-client val r2 | 2.4GHz: 0.878380 | 2.5GHz: 0.502087 | 2.6GHz: -0.137547
# node:2.4 round:27
# train mse:0.016673 rmse:0.129124 mae:0.098033 r2:0.862106
# per-client val r2 | 2.4GHz: 0.848678 | 2.5GHz: 0.665481 | 2.6GHz: 0.051639
# node:2.4 round:28
# train mse:0.012865 rmse:0.113423 mae:0.087138 r2:0.893602
# per-client val r2 | 2.4GHz: 0.879152 | 2.5GHz: 0.532074 | 2.6GHz: -0.113568
# node:2.4 round:29
# train mse:0.013078 rmse:0.114360 mae:0.086808 r2:0.891836
# per-client val r2 | 2.4GHz: 0.877748 | 2.5GHz: 0.614558 | 2.6GHz: -0.028998
# node:2.4 round:30
# train mse:0.011863 rmse:0.108919 mae:0.082527 r2:0.901883
# per-client val r2 | 2.4GHz: 0.887110 | 2.5GHz: 0.509841 | 2.6GHz: -0.147167
# node:2.4 round:31
# train mse:0.013900 rmse:0.117899 mae:0.089489 r2:0.885038
# per-client val r2 | 2.4GHz: 0.871751 | 2.5GHz: 0.685476 | 2.6GHz: 0.034337
# node:2.4 round:32
# train mse:0.011292 rmse:0.106265 mae:0.080918 r2:0.906606
# per-client val r2 | 2.4GHz: 0.891499 | 2.5GHz: 0.507690 | 2.6GHz: -0.144545
# node:2.4 round:33
# train mse:0.011182 rmse:0.105745 mae:0.080609 r2:0.907519
# per-client val r2 | 2.4GHz: 0.892380 | 2.5GHz: 0.505704 | 2.6GHz: -0.159796
# node:2.4 round:34
# train mse:0.011256 rmse:0.106092 mae:0.081171 r2:0.906910
# per-client val r2 | 2.4GHz: 0.891474 | 2.5GHz: 0.584665 | 2.6GHz: -0.074554
# node:2.4 round:35
# train mse:0.011392 rmse:0.106733 mae:0.081340 r2:0.905782
# per-client val r2 | 2.4GHz: 0.889245 | 2.5GHz: 0.601283 | 2.6GHz: -0.076227
# node:2.4 round:36
# train mse:0.009979 rmse:0.099895 mae:0.076243 r2:0.917468
# per-client val r2 | 2.4GHz: 0.901549 | 2.5GHz: 0.526744 | 2.6GHz: -0.147171
# node:2.4 round:37
# train mse:0.009987 rmse:0.099936 mae:0.075951 r2:0.917401
# per-client val r2 | 2.4GHz: 0.902317 | 2.5GHz: 0.522522 | 2.6GHz: -0.146883
# node:2.4 round:38
# train mse:0.012904 rmse:0.113596 mae:0.086349 r2:0.893277
# per-client val r2 | 2.4GHz: 0.878392 | 2.5GHz: 0.648727 | 2.6GHz: -0.010837
# node:2.4 round:39
# train mse:0.009657 rmse:0.098272 mae:0.074675 r2:0.920128
# per-client val r2 | 2.4GHz: 0.904182 | 2.5GHz: 0.602072 | 2.6GHz: -0.076353
# node:2.4 round:40
# train mse:0.009743 rmse:0.098709 mae:0.075358 r2:0.919417
# per-client val r2 | 2.4GHz: 0.902631 | 2.5GHz: 0.479776 | 2.6GHz: -0.219599
# node:2.4 round:41
# train mse:0.010303 rmse:0.101506 mae:0.077565 r2:0.914785
# per-client val r2 | 2.4GHz: 0.898446 | 2.5GHz: 0.576791 | 2.6GHz: -0.112766
# node:2.4 round:42
# train mse:0.008689 rmse:0.093215 mae:0.071194 r2:0.928137
# per-client val r2 | 2.4GHz: 0.912608 | 2.5GHz: 0.531033 | 2.6GHz: -0.155018
# node:2.4 round:43
# train mse:0.010195 rmse:0.100970 mae:0.077204 r2:0.915683
# per-client val r2 | 2.4GHz: 0.900047 | 2.5GHz: 0.544432 | 2.6GHz: -0.110743
# node:2.4 round:44
# train mse:0.009568 rmse:0.097818 mae:0.074250 r2:0.920864
# per-client val r2 | 2.4GHz: 0.905061 | 2.5GHz: 0.612490 | 2.6GHz: -0.071976
# node:2.4 round:45
# train mse:0.009907 rmse:0.099534 mae:0.075857 r2:0.918063
# per-client val r2 | 2.4GHz: 0.901829 | 2.5GHz: 0.451934 | 2.6GHz: -0.231472
# node:2.4 round:46
# train mse:0.008271 rmse:0.090943 mae:0.069567 r2:0.931598
# per-client val r2 | 2.4GHz: 0.914755 | 2.5GHz: 0.526459 | 2.6GHz: -0.167420
# node:2.4 round:47
# train mse:0.010364 rmse:0.101805 mae:0.077510 r2:0.914281
# per-client val r2 | 2.4GHz: 0.896823 | 2.5GHz: 0.382355 | 2.6GHz: -0.294510
# node:2.4 round:48
# train mse:0.008426 rmse:0.091795 mae:0.070167 r2:0.930309
# per-client val r2 | 2.4GHz: 0.912650 | 2.5GHz: 0.598621 | 2.6GHz: -0.111302
# node:2.4 round:49
# train mse:0.007987 rmse:0.089372 mae:0.068155 r2:0.933940
# per-client val r2 | 2.4GHz: 0.916976 | 2.5GHz: 0.569943 | 2.6GHz: -0.125057
# node:2.4 round:50
# train mse:0.008609 rmse:0.092785 mae:0.070198 r2:0.928798
# per-client val r2 | 2.4GHz: 0.910619 | 2.5GHz: 0.465623 | 2.6GHz: -0.220420
# node:2.4 round:51
# train mse:0.008198 rmse:0.090542 mae:0.068941 r2:0.932200
# per-client val r2 | 2.4GHz: 0.914059 | 2.5GHz: 0.550359 | 2.6GHz: -0.144645
# node:2.4 round:52
# train mse:0.007045 rmse:0.083935 mae:0.063992 r2:0.941733
# per-client val r2 | 2.4GHz: 0.923983 | 2.5GHz: 0.512989 | 2.6GHz: -0.179607
# node:2.4 round:53
# train mse:0.009896 rmse:0.099479 mae:0.075284 r2:0.918154
# per-client val r2 | 2.4GHz: 0.901367 | 2.5GHz: 0.386375 | 2.6GHz: -0.292624
# node:2.4 round:54
# train mse:0.007727 rmse:0.087902 mae:0.067127 r2:0.936095
# per-client val r2 | 2.4GHz: 0.917981 | 2.5GHz: 0.533563 | 2.6GHz: -0.165703
# node:2.4 round:55
# train mse:0.006961 rmse:0.083433 mae:0.063465 r2:0.942428
# per-client val r2 | 2.4GHz: 0.923114 | 2.5GHz: 0.524351 | 2.6GHz: -0.174470
# node:2.4 round:56
# train mse:0.006893 rmse:0.083021 mae:0.063480 r2:0.942995
# per-client val r2 | 2.4GHz: 0.924894 | 2.5GHz: 0.507342 | 2.6GHz: -0.192520
# node:2.4 round:57
# train mse:0.015109 rmse:0.122919 mae:0.093131 r2:0.875039
# per-client val r2 | 2.4GHz: 0.857687 | 2.5GHz: 0.287377 | 2.6GHz: -0.353543
# node:2.4 round:58
# train mse:0.007878 rmse:0.088759 mae:0.067949 r2:0.934843
# per-client val r2 | 2.4GHz: 0.916615 | 2.5GHz: 0.547299 | 2.6GHz: -0.150290
# node:2.4 round:59
# train mse:0.006417 rmse:0.080108 mae:0.061233 r2:0.946926
# per-client val r2 | 2.4GHz: 0.927467 | 2.5GHz: 0.543473 | 2.6GHz: -0.162552
# node:2.4 round:60
# train mse:0.007996 rmse:0.089421 mae:0.068354 r2:0.933867
# per-client val r2 | 2.4GHz: 0.913830 | 2.5GHz: 0.438503 | 2.6GHz: -0.250274
# node:2.4 round:61
# train mse:0.006622 rmse:0.081376 mae:0.061822 r2:0.945231
# per-client val r2 | 2.4GHz: 0.927482 | 2.5GHz: 0.511808 | 2.6GHz: -0.200045
# node:2.4 round:62
# train mse:0.008193 rmse:0.090518 mae:0.069089 r2:0.932235
# per-client val r2 | 2.4GHz: 0.913461 | 2.5GHz: 0.436863 | 2.6GHz: -0.241123
# node:2.4 round:63
# train mse:0.007226 rmse:0.085007 mae:0.065335 r2:0.940235
# per-client val r2 | 2.4GHz: 0.921129 | 2.5GHz: 0.544084 | 2.6GHz: -0.156174
# node:2.4 round:64
# train mse:0.006853 rmse:0.082780 mae:0.062963 r2:0.943326
# per-client val r2 | 2.4GHz: 0.924642 | 2.5GHz: 0.508281 | 2.6GHz: -0.188074
# node:2.4 round:65
# train mse:0.007059 rmse:0.084018 mae:0.064595 r2:0.941619
# per-client val r2 | 2.4GHz: 0.922545 | 2.5GHz: 0.496012 | 2.6GHz: -0.188821
# node:2.4 round:66
# train mse:0.007426 rmse:0.086173 mae:0.065629 r2:0.938584
# per-client val r2 | 2.4GHz: 0.918429 | 2.5GHz: 0.426989 | 2.6GHz: -0.272572
# node:2.4 round:67
# train mse:0.007061 rmse:0.084029 mae:0.064451 r2:0.941603
# per-client val r2 | 2.4GHz: 0.923494 | 2.5GHz: 0.494165 | 2.6GHz: -0.194221
# node:2.4 round:68
# train mse:0.008384 rmse:0.091564 mae:0.069785 r2:0.930660
# per-client val r2 | 2.4GHz: 0.911341 | 2.5GHz: 0.644300 | 2.6GHz: -0.054912
# node:2.4 round:69
# train mse:0.006695 rmse:0.081822 mae:0.062257 r2:0.944630
# per-client val r2 | 2.4GHz: 0.923532 | 2.5GHz: 0.564264 | 2.6GHz: -0.149257
# node:2.4 round:70
# train mse:0.006122 rmse:0.078241 mae:0.060063 r2:0.949370
# per-client val r2 | 2.4GHz: 0.928758 | 2.5GHz: 0.549049 | 2.6GHz: -0.164859
# node:2.4 round:71
# train mse:0.007462 rmse:0.086384 mae:0.065733 r2:0.938284
# per-client val r2 | 2.4GHz: 0.918105 | 2.5GHz: 0.622330 | 2.6GHz: -0.077931
# node:2.4 round:72
# train mse:0.005739 rmse:0.075759 mae:0.057859 r2:0.952531
# per-client val r2 | 2.4GHz: 0.930685 | 2.5GHz: 0.493535 | 2.6GHz: -0.224047
# node:2.4 round:73
# train mse:0.005605 rmse:0.074865 mae:0.057339 r2:0.953646
# per-client val r2 | 2.4GHz: 0.932729 | 2.5GHz: 0.518025 | 2.6GHz: -0.198168
# node:2.4 round:74
# train mse:0.008494 rmse:0.092161 mae:0.070662 r2:0.929753
# per-client val r2 | 2.4GHz: 0.909963 | 2.5GHz: 0.626502 | 2.6GHz: -0.058002
# node:2.4 round:75
# train mse:0.005547 rmse:0.074476 mae:0.056897 r2:0.954126
# per-client val r2 | 2.4GHz: 0.932297 | 2.5GHz: 0.487808 | 2.6GHz: -0.241168
# node:2.4 round:76
# train mse:0.006258 rmse:0.079107 mae:0.060777 r2:0.948243
# per-client val r2 | 2.4GHz: 0.926926 | 2.5GHz: 0.428181 | 2.6GHz: -0.275631
# node:2.4 round:77
# train mse:0.005671 rmse:0.075304 mae:0.057742 r2:0.953101
# per-client val r2 | 2.4GHz: 0.930561 | 2.5GHz: 0.530689 | 2.6GHz: -0.190794
# node:2.4 round:78
# train mse:0.007722 rmse:0.087873 mae:0.067247 r2:0.936138
# per-client val r2 | 2.4GHz: 0.913114 | 2.5GHz: 0.383727 | 2.6GHz: -0.307635
# node:2.4 round:79
# train mse:0.006328 rmse:0.079547 mae:0.060972 r2:0.947666
# per-client val r2 | 2.4GHz: 0.925005 | 2.5GHz: 0.432259 | 2.6GHz: -0.279354
# node:2.4 round:80
# train mse:0.005335 rmse:0.073041 mae:0.055753 r2:0.955876
# per-client val r2 | 2.4GHz: 0.932835 | 2.5GHz: 0.489336 | 2.6GHz: -0.222220
# node:2.4 round:81
# train mse:0.005222 rmse:0.072267 mae:0.055235 r2:0.956807
# per-client val r2 | 2.4GHz: 0.934511 | 2.5GHz: 0.502845 | 2.6GHz: -0.209323
# node:2.4 round:82
# train mse:0.005611 rmse:0.074905 mae:0.057176 r2:0.953596
# per-client val r2 | 2.4GHz: 0.930407 | 2.5GHz: 0.459375 | 2.6GHz: -0.258890
# node:2.4 round:83
# train mse:0.005091 rmse:0.071353 mae:0.054646 r2:0.957893
# per-client val r2 | 2.4GHz: 0.934906 | 2.5GHz: 0.522406 | 2.6GHz: -0.208425
# node:2.4 round:84
# train mse:0.007435 rmse:0.086229 mae:0.065149 r2:0.938504
# per-client val r2 | 2.4GHz: 0.915653 | 2.5GHz: 0.642818 | 2.6GHz: -0.074702
# node:2.4 round:85
# train mse:0.005727 rmse:0.075675 mae:0.058341 r2:0.952637
# per-client val r2 | 2.4GHz: 0.929910 | 2.5GHz: 0.524114 | 2.6GHz: -0.194306
# node:2.4 round:86
# train mse:0.004974 rmse:0.070526 mae:0.053978 r2:0.958863
# per-client val r2 | 2.4GHz: 0.934357 | 2.5GHz: 0.513476 | 2.6GHz: -0.221007
# node:2.4 round:87
# train mse:0.005349 rmse:0.073140 mae:0.056225 r2:0.955757
# per-client val r2 | 2.4GHz: 0.933405 | 2.5GHz: 0.539123 | 2.6GHz: -0.184835
# node:2.4 round:88
# train mse:0.004756 rmse:0.068962 mae:0.052792 r2:0.960667
# per-client val r2 | 2.4GHz: 0.937755 | 2.5GHz: 0.509468 | 2.6GHz: -0.211416
# node:2.4 round:89
# train mse:0.004729 rmse:0.068769 mae:0.053082 r2:0.960887
# per-client val r2 | 2.4GHz: 0.937359 | 2.5GHz: 0.526082 | 2.6GHz: -0.193430
# node:2.4 round:90
# train mse:0.007148 rmse:0.084544 mae:0.064371 r2:0.940884
# per-client val r2 | 2.4GHz: 0.916984 | 2.5GHz: 0.395128 | 2.6GHz: -0.288363
# node:2.4 round:91
# train mse:0.005128 rmse:0.071609 mae:0.055020 r2:0.957589
# per-client val r2 | 2.4GHz: 0.933408 | 2.5GHz: 0.566151 | 2.6GHz: -0.166727
# node:2.4 round:92
# train mse:0.004925 rmse:0.070175 mae:0.054042 r2:0.959271
# per-client val r2 | 2.4GHz: 0.934408 | 2.5GHz: 0.521982 | 2.6GHz: -0.198121
# node:2.4 round:93
# train mse:0.004306 rmse:0.065622 mae:0.050482 r2:0.964385
# per-client val r2 | 2.4GHz: 0.939771 | 2.5GHz: 0.497314 | 2.6GHz: -0.226596
# node:2.4 round:94
# train mse:0.004747 rmse:0.068896 mae:0.052862 r2:0.960743
# per-client val r2 | 2.4GHz: 0.934955 | 2.5GHz: 0.472968 | 2.6GHz: -0.248835
# node:2.4 round:95
# train mse:0.005217 rmse:0.072228 mae:0.055439 r2:0.956854
# per-client val r2 | 2.4GHz: 0.931472 | 2.5GHz: 0.472007 | 2.6GHz: -0.228158
# node:2.4 round:96
# train mse:0.005623 rmse:0.074989 mae:0.057035 r2:0.953491
# per-client val r2 | 2.4GHz: 0.928532 | 2.5GHz: 0.605015 | 2.6GHz: -0.117994
# node:2.4 round:97
# train mse:0.005355 rmse:0.073178 mae:0.055933 r2:0.955711
# per-client val r2 | 2.4GHz: 0.929904 | 2.5GHz: 0.581566 | 2.6GHz: -0.137866
# node:2.4 round:98
# train mse:0.005346 rmse:0.073118 mae:0.055619 r2:0.955783
# per-client val r2 | 2.4GHz: 0.929784 | 2.5GHz: 0.434816 | 2.6GHz: -0.279334
# node:2.4 round:99
# train mse:0.006424 rmse:0.080153 mae:0.060444 r2:0.946866
# per-client val r2 | 2.4GHz: 0.921346 | 2.5GHz: 0.399940 | 2.6GHz: -0.310095
# node:2.5 round:100
# train mse:0.020920 rmse:0.144637 mae:0.109564 r2:0.826569
# per-client val r2 | 2.4GHz: 0.846004 | 2.5GHz: 0.815507 | 2.6GHz: 0.284332
# node:2.5 round:101
# train mse:0.019139 rmse:0.138345 mae:0.104939 r2:0.841329
# per-client val r2 | 2.4GHz: 0.839183 | 2.5GHz: 0.829849 | 2.6GHz: 0.316722
# node:2.5 round:102
# train mse:0.016211 rmse:0.127324 mae:0.096003 r2:0.865602
# per-client val r2 | 2.4GHz: 0.816841 | 2.5GHz: 0.854283 | 2.6GHz: 0.375381
# node:2.5 round:103
# train mse:0.021619 rmse:0.147033 mae:0.112426 r2:0.820773
# per-client val r2 | 2.4GHz: 0.861827 | 2.5GHz: 0.805470 | 2.6GHz: 0.277404
# node:2.5 round:104
# train mse:0.019475 rmse:0.139554 mae:0.105282 r2:0.838543
# per-client val r2 | 2.4GHz: 0.846090 | 2.5GHz: 0.822656 | 2.6GHz: 0.317041
# node:2.5 round:105
# train mse:0.023818 rmse:0.154330 mae:0.118806 r2:0.802543
# per-client val r2 | 2.4GHz: 0.875864 | 2.5GHz: 0.784337 | 2.6GHz: 0.256101
# node:2.5 round:106
# train mse:0.018469 rmse:0.135899 mae:0.103588 r2:0.846890
# per-client val r2 | 2.4GHz: 0.839309 | 2.5GHz: 0.830006 | 2.6GHz: 0.345241
# node:2.5 round:107
# train mse:0.019287 rmse:0.138876 mae:0.106652 r2:0.840108
# per-client val r2 | 2.4GHz: 0.851658 | 2.5GHz: 0.822630 | 2.6GHz: 0.328709
# node:2.5 round:108
# train mse:0.015653 rmse:0.125111 mae:0.094984 r2:0.870234
# per-client val r2 | 2.4GHz: 0.820965 | 2.5GHz: 0.854125 | 2.6GHz: 0.404682
# node:2.5 round:109
# train mse:0.019442 rmse:0.139434 mae:0.106824 r2:0.838821
# per-client val r2 | 2.4GHz: 0.856799 | 2.5GHz: 0.820328 | 2.6GHz: 0.333118
# node:2.5 round:110
# train mse:0.016459 rmse:0.128295 mae:0.097342 r2:0.863546
# per-client val r2 | 2.4GHz: 0.838179 | 2.5GHz: 0.844514 | 2.6GHz: 0.385095
# node:2.5 round:111
# train mse:0.020238 rmse:0.142259 mae:0.109495 r2:0.832224
# per-client val r2 | 2.4GHz: 0.865334 | 2.5GHz: 0.809756 | 2.6GHz: 0.328122
# node:2.5 round:112
# train mse:0.021711 rmse:0.147347 mae:0.113953 r2:0.820009
# per-client val r2 | 2.4GHz: 0.876434 | 2.5GHz: 0.796323 | 2.6GHz: 0.294436
# node:2.5 round:113
# train mse:0.016787 rmse:0.129565 mae:0.098329 r2:0.860830
# per-client val r2 | 2.4GHz: 0.839254 | 2.5GHz: 0.841482 | 2.6GHz: 0.394018
# node:2.5 round:114
# train mse:0.023347 rmse:0.152798 mae:0.117528 r2:0.806444
# per-client val r2 | 2.4GHz: 0.883451 | 2.5GHz: 0.780177 | 2.6GHz: 0.277502
# node:2.5 round:115
# train mse:0.016397 rmse:0.128050 mae:0.097905 r2:0.864066
# per-client val r2 | 2.4GHz: 0.840118 | 2.5GHz: 0.843736 | 2.6GHz: 0.409401
# node:2.5 round:116
# train mse:0.019486 rmse:0.139593 mae:0.106425 r2:0.838453
# per-client val r2 | 2.4GHz: 0.866423 | 2.5GHz: 0.812722 | 2.6GHz: 0.353828
# node:2.5 round:117
# train mse:0.017665 rmse:0.132910 mae:0.101423 r2:0.853552
# per-client val r2 | 2.4GHz: 0.858860 | 2.5GHz: 0.830575 | 2.6GHz: 0.386340
# node:2.5 round:118
# train mse:0.014050 rmse:0.118534 mae:0.090052 r2:0.883518
# per-client val r2 | 2.4GHz: 0.828605 | 2.5GHz: 0.862881 | 2.6GHz: 0.463530
# node:2.5 round:119
# train mse:0.017962 rmse:0.134023 mae:0.103345 r2:0.851088
# per-client val r2 | 2.4GHz: 0.866653 | 2.5GHz: 0.822672 | 2.6GHz: 0.383062
# node:2.5 round:120
# train mse:0.014912 rmse:0.122114 mae:0.093022 r2:0.876376
# per-client val r2 | 2.4GHz: 0.836997 | 2.5GHz: 0.852807 | 2.6GHz: 0.453831
# node:2.5 round:121
# train mse:0.019404 rmse:0.139298 mae:0.107352 r2:0.839134
# per-client val r2 | 2.4GHz: 0.877326 | 2.5GHz: 0.811902 | 2.6GHz: 0.359247
# node:2.5 round:122
# train mse:0.016433 rmse:0.128192 mae:0.097397 r2:0.863763
# per-client val r2 | 2.4GHz: 0.858218 | 2.5GHz: 0.838826 | 2.6GHz: 0.416286
# node:2.5 round:123
# train mse:0.019220 rmse:0.138637 mae:0.106928 r2:0.840658
# per-client val r2 | 2.4GHz: 0.884829 | 2.5GHz: 0.810931 | 2.6GHz: 0.367922
# node:2.5 round:124
# train mse:0.015537 rmse:0.124648 mae:0.095340 r2:0.871193
# per-client val r2 | 2.4GHz: 0.859773 | 2.5GHz: 0.843731 | 2.6GHz: 0.441260
# node:2.5 round:125
# train mse:0.014114 rmse:0.118800 mae:0.090307 r2:0.882995
# per-client val r2 | 2.4GHz: 0.850786 | 2.5GHz: 0.858365 | 2.6GHz: 0.474468
# node:2.5 round:126
# train mse:0.015139 rmse:0.123041 mae:0.093296 r2:0.874492
# per-client val r2 | 2.4GHz: 0.862121 | 2.5GHz: 0.846576 | 2.6GHz: 0.455386
# node:2.5 round:127
# train mse:0.016269 rmse:0.127549 mae:0.097431 r2:0.865128
# per-client val r2 | 2.4GHz: 0.871785 | 2.5GHz: 0.833913 | 2.6GHz: 0.437282
# node:2.5 round:128
# train mse:0.014759 rmse:0.121488 mae:0.092425 r2:0.877640
# per-client val r2 | 2.4GHz: 0.862453 | 2.5GHz: 0.850334 | 2.6GHz: 0.472824
# node:2.5 round:129
# train mse:0.016880 rmse:0.129925 mae:0.099548 r2:0.860056
# per-client val r2 | 2.4GHz: 0.881368 | 2.5GHz: 0.831405 | 2.6GHz: 0.433798
# node:2.5 round:130
# train mse:0.014781 rmse:0.121576 mae:0.092489 r2:0.877463
# per-client val r2 | 2.4GHz: 0.874434 | 2.5GHz: 0.846713 | 2.6GHz: 0.476889
# node:2.5 round:131
# train mse:0.014800 rmse:0.121656 mae:0.093075 r2:0.877302
# per-client val r2 | 2.4GHz: 0.870118 | 2.5GHz: 0.849282 | 2.6GHz: 0.489349
# node:2.5 round:132
# train mse:0.013753 rmse:0.117271 mae:0.088694 r2:0.885987
# per-client val r2 | 2.4GHz: 0.870229 | 2.5GHz: 0.858261 | 2.6GHz: 0.516921
# node:2.5 round:133
# train mse:0.014788 rmse:0.121608 mae:0.092708 r2:0.877399
# per-client val r2 | 2.4GHz: 0.877925 | 2.5GHz: 0.848584 | 2.6GHz: 0.508315
# node:2.5 round:134
# train mse:0.012826 rmse:0.113254 mae:0.085499 r2:0.893665
# per-client val r2 | 2.4GHz: 0.852847 | 2.5GHz: 0.868549 | 2.6GHz: 0.572378
# node:2.5 round:135
# train mse:0.023184 rmse:0.152263 mae:0.116905 r2:0.807797
# per-client val r2 | 2.4GHz: 0.910892 | 2.5GHz: 0.773564 | 2.6GHz: 0.396484
# node:2.5 round:136
# train mse:0.015255 rmse:0.123510 mae:0.093726 r2:0.873534
# per-client val r2 | 2.4GHz: 0.896803 | 2.5GHz: 0.844251 | 2.6GHz: 0.515764
# node:2.5 round:137
# train mse:0.011546 rmse:0.107455 mae:0.080673 r2:0.904276
# per-client val r2 | 2.4GHz: 0.868769 | 2.5GHz: 0.875683 | 2.6GHz: 0.607920
# node:2.5 round:138
# train mse:0.011769 rmse:0.108484 mae:0.081575 r2:0.902433
# per-client val r2 | 2.4GHz: 0.879489 | 2.5GHz: 0.872779 | 2.6GHz: 0.603514
# node:2.5 round:139
# train mse:0.014586 rmse:0.120774 mae:0.091412 r2:0.879075
# per-client val r2 | 2.4GHz: 0.896888 | 2.5GHz: 0.848391 | 2.6GHz: 0.572052
# node:2.5 round:140
# train mse:0.029213 rmse:0.170918 mae:0.131488 r2:0.757815
# per-client val r2 | 2.4GHz: 0.898738 | 2.5GHz: 0.720050 | 2.6GHz: 0.388192
# node:2.5 round:141
# train mse:0.020745 rmse:0.144031 mae:0.110214 r2:0.828018
# per-client val r2 | 2.4GHz: 0.916246 | 2.5GHz: 0.789574 | 2.6GHz: 0.491711
# node:2.5 round:142
# train mse:0.014534 rmse:0.120557 mae:0.091287 r2:0.879509
# per-client val r2 | 2.4GHz: 0.900313 | 2.5GHz: 0.851107 | 2.6GHz: 0.588098
# node:2.5 round:143
# train mse:0.013144 rmse:0.114647 mae:0.086037 r2:0.891032
# per-client val r2 | 2.4GHz: 0.903558 | 2.5GHz: 0.860876 | 2.6GHz: 0.630153
# node:2.5 round:144
# train mse:0.013631 rmse:0.116753 mae:0.088728 r2:0.886992
# per-client val r2 | 2.4GHz: 0.908079 | 2.5GHz: 0.858129 | 2.6GHz: 0.613031
# node:2.5 round:145
# train mse:0.009446 rmse:0.097192 mae:0.072473 r2:0.921687
# per-client val r2 | 2.4GHz: 0.807649 | 2.5GHz: 0.894481 | 2.6GHz: 0.816559
# node:2.5 round:146
# train mse:0.009048 rmse:0.095121 mae:0.070722 r2:0.924990
# per-client val r2 | 2.4GHz: 0.880346 | 2.5GHz: 0.898716 | 2.6GHz: 0.739198
# node:2.5 round:147
# train mse:0.010361 rmse:0.101791 mae:0.076504 r2:0.914100
# per-client val r2 | 2.4GHz: 0.906697 | 2.5GHz: 0.884740 | 2.6GHz: 0.718697
# node:2.5 round:148
# train mse:0.008868 rmse:0.094168 mae:0.070735 r2:0.926484
# per-client val r2 | 2.4GHz: 0.829158 | 2.5GHz: 0.898411 | 2.6GHz: 0.822856
# node:2.5 round:149
# train mse:0.008142 rmse:0.090232 mae:0.067364 r2:0.932501
# per-client val r2 | 2.4GHz: 0.870914 | 2.5GHz: 0.904324 | 2.6GHz: 0.785815
# node:2.5 round:150
# train mse:0.007629 rmse:0.087346 mae:0.065477 r2:0.936751
# per-client val r2 | 2.4GHz: 0.864006 | 2.5GHz: 0.909274 | 2.6GHz: 0.833241
# node:2.5 round:151
# train mse:0.012024 rmse:0.109656 mae:0.081753 r2:0.900314
# per-client val r2 | 2.4GHz: 0.911092 | 2.5GHz: 0.869140 | 2.6GHz: 0.719371
# node:2.5 round:152
# train mse:0.010667 rmse:0.103282 mae:0.077263 r2:0.911566
# per-client val r2 | 2.4GHz: 0.915447 | 2.5GHz: 0.881460 | 2.6GHz: 0.743155
# node:2.5 round:153
# train mse:0.011582 rmse:0.107622 mae:0.080993 r2:0.903978
# per-client val r2 | 2.4GHz: 0.917014 | 2.5GHz: 0.871796 | 2.6GHz: 0.740565
# node:2.5 round:154
# train mse:0.008635 rmse:0.092924 mae:0.069689 r2:0.928415
# per-client val r2 | 2.4GHz: 0.900043 | 2.5GHz: 0.900466 | 2.6GHz: 0.810151
# node:2.5 round:155
# train mse:0.020292 rmse:0.142451 mae:0.108454 r2:0.831770
# per-client val r2 | 2.4GHz: 0.896311 | 2.5GHz: 0.795281 | 2.6GHz: 0.634116
# node:2.5 round:156
# train mse:0.007478 rmse:0.086477 mae:0.064573 r2:0.938002
# per-client val r2 | 2.4GHz: 0.908230 | 2.5GHz: 0.908566 | 2.6GHz: 0.828379
# node:2.5 round:157
# train mse:0.007648 rmse:0.087455 mae:0.065349 r2:0.936592
# per-client val r2 | 2.4GHz: 0.914627 | 2.5GHz: 0.908145 | 2.6GHz: 0.820761
# node:2.5 round:158
# train mse:0.007761 rmse:0.088094 mae:0.066240 r2:0.935662
# per-client val r2 | 2.4GHz: 0.906848 | 2.5GHz: 0.905779 | 2.6GHz: 0.828853
# node:2.5 round:159
# train mse:0.009892 rmse:0.099459 mae:0.074807 r2:0.917992
# per-client val r2 | 2.4GHz: 0.910484 | 2.5GHz: 0.888243 | 2.6GHz: 0.798009
# node:2.5 round:160
# train mse:0.024009 rmse:0.154950 mae:0.116707 r2:0.800954
# per-client val r2 | 2.4GHz: 0.852310 | 2.5GHz: 0.765798 | 2.6GHz: 0.641903
# node:2.5 round:161
# train mse:0.008905 rmse:0.094364 mae:0.070235 r2:0.926178
# per-client val r2 | 2.4GHz: 0.919818 | 2.5GHz: 0.896493 | 2.6GHz: 0.805970
# node:2.5 round:162
# train mse:0.007745 rmse:0.088004 mae:0.065738 r2:0.935794
# per-client val r2 | 2.4GHz: 0.892477 | 2.5GHz: 0.905384 | 2.6GHz: 0.857911
# node:2.5 round:163
# train mse:0.008000 rmse:0.089443 mae:0.067435 r2:0.933677
# per-client val r2 | 2.4GHz: 0.880932 | 2.5GHz: 0.903728 | 2.6GHz: 0.865097
# node:2.5 round:164
# train mse:0.007881 rmse:0.088776 mae:0.066972 r2:0.934662
# per-client val r2 | 2.4GHz: 0.912134 | 2.5GHz: 0.905020 | 2.6GHz: 0.839369
# node:2.5 round:165
# train mse:0.012436 rmse:0.111516 mae:0.082391 r2:0.896902
# per-client val r2 | 2.4GHz: 0.905869 | 2.5GHz: 0.863898 | 2.6GHz: 0.782683
# node:2.5 round:166
# train mse:0.006531 rmse:0.080814 mae:0.060589 r2:0.945857
# per-client val r2 | 2.4GHz: 0.921394 | 2.5GHz: 0.915093 | 2.6GHz: 0.859740
# node:2.5 round:167
# train mse:0.010792 rmse:0.103885 mae:0.076956 r2:0.910531
# per-client val r2 | 2.4GHz: 0.915326 | 2.5GHz: 0.876047 | 2.6GHz: 0.795560
# node:2.5 round:168
# train mse:0.007964 rmse:0.089239 mae:0.067523 r2:0.933980
# per-client val r2 | 2.4GHz: 0.883108 | 2.5GHz: 0.905681 | 2.6GHz: 0.865974
# node:2.5 round:169
# train mse:0.006876 rmse:0.082920 mae:0.062098 r2:0.942998
# per-client val r2 | 2.4GHz: 0.927448 | 2.5GHz: 0.911995 | 2.6GHz: 0.848957
# node:2.5 round:170
# train mse:0.006355 rmse:0.079720 mae:0.060362 r2:0.947312
# per-client val r2 | 2.4GHz: 0.914885 | 2.5GHz: 0.918628 | 2.6GHz: 0.870654
# node:2.5 round:171
# train mse:0.007444 rmse:0.086279 mae:0.064541 r2:0.938286
# per-client val r2 | 2.4GHz: 0.926323 | 2.5GHz: 0.906044 | 2.6GHz: 0.845370
# node:2.5 round:172
# train mse:0.011728 rmse:0.108297 mae:0.080902 r2:0.902769
# per-client val r2 | 2.4GHz: 0.912057 | 2.5GHz: 0.872784 | 2.6GHz: 0.790552
# node:2.5 round:173
# train mse:0.006907 rmse:0.083107 mae:0.062379 r2:0.942740
# per-client val r2 | 2.4GHz: 0.910905 | 2.5GHz: 0.908705 | 2.6GHz: 0.870489
# node:2.5 round:174
# train mse:0.008784 rmse:0.093726 mae:0.070133 r2:0.927174
# per-client val r2 | 2.4GHz: 0.920324 | 2.5GHz: 0.894031 | 2.6GHz: 0.835742
# node:2.5 round:175
# train mse:0.014701 rmse:0.121249 mae:0.090273 r2:0.878121
# per-client val r2 | 2.4GHz: 0.891666 | 2.5GHz: 0.844110 | 2.6GHz: 0.771068
# node:2.5 round:176
# train mse:0.007045 rmse:0.083936 mae:0.063168 r2:0.941593
# per-client val r2 | 2.4GHz: 0.902192 | 2.5GHz: 0.909893 | 2.6GHz: 0.880088
# node:2.5 round:177
# train mse:0.007967 rmse:0.089259 mae:0.066936 r2:0.933950
# per-client val r2 | 2.4GHz: 0.894804 | 2.5GHz: 0.899915 | 2.6GHz: 0.871532
# node:2.5 round:178
# train mse:0.007427 rmse:0.086180 mae:0.064504 r2:0.938427
# per-client val r2 | 2.4GHz: 0.925094 | 2.5GHz: 0.906490 | 2.6GHz: 0.853888
# node:2.5 round:179
# train mse:0.006407 rmse:0.080044 mae:0.060561 r2:0.946884
# per-client val r2 | 2.4GHz: 0.912523 | 2.5GHz: 0.915263 | 2.6GHz: 0.884564
# node:2.5 round:180
# train mse:0.007884 rmse:0.088790 mae:0.066994 r2:0.934642
# per-client val r2 | 2.4GHz: 0.902768 | 2.5GHz: 0.902931 | 2.6GHz: 0.865120
# node:2.5 round:181
# train mse:0.006988 rmse:0.083597 mae:0.063015 r2:0.942064
# per-client val r2 | 2.4GHz: 0.901021 | 2.5GHz: 0.910428 | 2.6GHz: 0.883892
# node:2.5 round:182
# train mse:0.006362 rmse:0.079762 mae:0.060351 r2:0.947258
# per-client val r2 | 2.4GHz: 0.917926 | 2.5GHz: 0.914696 | 2.6GHz: 0.877362
# node:2.5 round:183
# train mse:0.006200 rmse:0.078738 mae:0.059420 r2:0.948603
# per-client val r2 | 2.4GHz: 0.926857 | 2.5GHz: 0.915747 | 2.6GHz: 0.873308
# node:2.5 round:184
# train mse:0.005178 rmse:0.071960 mae:0.054391 r2:0.957071
# per-client val r2 | 2.4GHz: 0.930628 | 2.5GHz: 0.923679 | 2.6GHz: 0.884780
# node:2.5 round:185
# train mse:0.009971 rmse:0.099856 mae:0.074158 r2:0.917335
# per-client val r2 | 2.4GHz: 0.903828 | 2.5GHz: 0.884933 | 2.6GHz: 0.838080
# node:2.5 round:186
# train mse:0.005522 rmse:0.074313 mae:0.056226 r2:0.954218
# per-client val r2 | 2.4GHz: 0.929163 | 2.5GHz: 0.922133 | 2.6GHz: 0.883673
# node:2.5 round:187
# train mse:0.013716 rmse:0.117113 mae:0.086148 r2:0.886294
# per-client val r2 | 2.4GHz: 0.881020 | 2.5GHz: 0.852904 | 2.6GHz: 0.801498
# node:2.5 round:188
# train mse:0.008461 rmse:0.091982 mae:0.069246 r2:0.929858
# per-client val r2 | 2.4GHz: 0.884373 | 2.5GHz: 0.896338 | 2.6GHz: 0.875799
# node:2.5 round:189
# train mse:0.013925 rmse:0.118005 mae:0.088563 r2:0.884555
# per-client val r2 | 2.4GHz: 0.892242 | 2.5GHz: 0.851160 | 2.6GHz: 0.785996
# node:2.5 round:190
# train mse:0.013070 rmse:0.114326 mae:0.084225 r2:0.891642
# per-client val r2 | 2.4GHz: 0.879550 | 2.5GHz: 0.857702 | 2.6GHz: 0.817283
# node:2.5 round:191
# train mse:0.006738 rmse:0.082088 mae:0.061949 r2:0.944136
# per-client val r2 | 2.4GHz: 0.909091 | 2.5GHz: 0.911497 | 2.6GHz: 0.881868
# node:2.5 round:192
# train mse:0.006272 rmse:0.079196 mae:0.059958 r2:0.948003
# per-client val r2 | 2.4GHz: 0.914361 | 2.5GHz: 0.913026 | 2.6GHz: 0.881891
# node:2.5 round:193
# train mse:0.006876 rmse:0.082923 mae:0.062438 r2:0.942995
# per-client val r2 | 2.4GHz: 0.921608 | 2.5GHz: 0.907813 | 2.6GHz: 0.869521
# node:2.5 round:194
# train mse:0.006764 rmse:0.082242 mae:0.061592 r2:0.943927
# per-client val r2 | 2.4GHz: 0.923295 | 2.5GHz: 0.910327 | 2.6GHz: 0.862466
# node:2.5 round:195
# train mse:0.005489 rmse:0.074090 mae:0.056573 r2:0.954492
# per-client val r2 | 2.4GHz: 0.922878 | 2.5GHz: 0.920333 | 2.6GHz: 0.886992
# node:2.5 round:196
# train mse:0.009641 rmse:0.098189 mae:0.074647 r2:0.920072
# per-client val r2 | 2.4GHz: 0.879487 | 2.5GHz: 0.883268 | 2.6GHz: 0.865770
# node:2.5 round:197
# train mse:0.008471 rmse:0.092037 mae:0.068288 r2:0.929775
# per-client val r2 | 2.4GHz: 0.906660 | 2.5GHz: 0.897485 | 2.6GHz: 0.860909
# node:2.5 round:198
# train mse:0.006423 rmse:0.080143 mae:0.060614 r2:0.946753
# per-client val r2 | 2.4GHz: 0.911211 | 2.5GHz: 0.910710 | 2.6GHz: 0.880319
# node:2.5 round:199
# train mse:0.005560 rmse:0.074565 mae:0.055921 r2:0.953906
# per-client val r2 | 2.4GHz: 0.929344 | 2.5GHz: 0.917854 | 2.6GHz: 0.880780
# node:2.6 round:200
# train mse:0.009542 rmse:0.097681 mae:0.072271 r2:0.920782
# per-client val r2 | 2.4GHz: 0.917944 | 2.5GHz: 0.920525 | 2.6GHz: 0.916162
# node:2.6 round:201
# train mse:0.008155 rmse:0.090304 mae:0.067301 r2:0.932296
# per-client val r2 | 2.4GHz: 0.920582 | 2.5GHz: 0.926789 | 2.6GHz: 0.926428
# node:2.6 round:202
# train mse:0.012073 rmse:0.109876 mae:0.080508 r2:0.899767
# per-client val r2 | 2.4GHz: 0.898293 | 2.5GHz: 0.895004 | 2.6GHz: 0.892280
# node:2.6 round:203
# train mse:0.008414 rmse:0.091728 mae:0.067853 r2:0.930143
# per-client val r2 | 2.4GHz: 0.919571 | 2.5GHz: 0.921116 | 2.6GHz: 0.921608
# node:2.6 round:204
# train mse:0.008866 rmse:0.094158 mae:0.070042 r2:0.926394
# per-client val r2 | 2.4GHz: 0.916178 | 2.5GHz: 0.918521 | 2.6GHz: 0.916755
# node:2.6 round:205
# train mse:0.011334 rmse:0.106464 mae:0.078295 r2:0.905896
# per-client val r2 | 2.4GHz: 0.899615 | 2.5GHz: 0.895440 | 2.6GHz: 0.894664
# node:2.6 round:206
# train mse:0.007219 rmse:0.084968 mae:0.063597 r2:0.940061
# per-client val r2 | 2.4GHz: 0.921819 | 2.5GHz: 0.928578 | 2.6GHz: 0.928846
# node:2.6 round:207
# train mse:0.007993 rmse:0.089402 mae:0.067623 r2:0.933641
# per-client val r2 | 2.4GHz: 0.913007 | 2.5GHz: 0.919850 | 2.6GHz: 0.920971
# node:2.6 round:208
# train mse:0.008371 rmse:0.091492 mae:0.067746 r2:0.930503
# per-client val r2 | 2.4GHz: 0.912228 | 2.5GHz: 0.915004 | 2.6GHz: 0.916948
# node:2.6 round:209
# train mse:0.011142 rmse:0.105557 mae:0.078208 r2:0.907491
# per-client val r2 | 2.4GHz: 0.890499 | 2.5GHz: 0.888367 | 2.6GHz: 0.894004
# node:2.6 round:210
# train mse:0.007086 rmse:0.084176 mae:0.063467 r2:0.941172
# per-client val r2 | 2.4GHz: 0.918947 | 2.5GHz: 0.925001 | 2.6GHz: 0.926094
# node:2.6 round:211
# train mse:0.018184 rmse:0.134847 mae:0.100429 r2:0.849031
# per-client val r2 | 2.4GHz: 0.861351 | 2.5GHz: 0.842633 | 2.6GHz: 0.837864
# node:2.6 round:212
# train mse:0.006390 rmse:0.079940 mae:0.059965 r2:0.946944
# per-client val r2 | 2.4GHz: 0.925353 | 2.5GHz: 0.932291 | 2.6GHz: 0.930984
# node:2.6 round:213
# train mse:0.006827 rmse:0.082626 mae:0.062447 r2:0.943319
# per-client val r2 | 2.4GHz: 0.917964 | 2.5GHz: 0.927582 | 2.6GHz: 0.928621
# node:2.6 round:214
# train mse:0.007979 rmse:0.089326 mae:0.066365 r2:0.933754
# per-client val r2 | 2.4GHz: 0.916211 | 2.5GHz: 0.918359 | 2.6GHz: 0.917018
# node:2.6 round:215
# train mse:0.007705 rmse:0.087780 mae:0.066538 r2:0.936027
# per-client val r2 | 2.4GHz: 0.910824 | 2.5GHz: 0.918458 | 2.6GHz: 0.919284
# node:2.6 round:216
# train mse:0.010394 rmse:0.101952 mae:0.075667 r2:0.913703
# per-client val r2 | 2.4GHz: 0.901308 | 2.5GHz: 0.897513 | 2.6GHz: 0.896215
# node:2.6 round:217
# train mse:0.006230 rmse:0.078927 mae:0.059434 r2:0.948280
# per-client val r2 | 2.4GHz: 0.923805 | 2.5GHz: 0.929801 | 2.6GHz: 0.929054
# node:2.6 round:218
# train mse:0.008516 rmse:0.092280 mae:0.068662 r2:0.929299
# per-client val r2 | 2.4GHz: 0.910616 | 2.5GHz: 0.911262 | 2.6GHz: 0.912881
# node:2.6 round:219
# train mse:0.006045 rmse:0.077748 mae:0.058849 r2:0.949814
# per-client val r2 | 2.4GHz: 0.924431 | 2.5GHz: 0.931744 | 2.6GHz: 0.930370
# node:2.6 round:220
# train mse:0.006583 rmse:0.081138 mae:0.061324 r2:0.945341
# per-client val r2 | 2.4GHz: 0.921110 | 2.5GHz: 0.925126 | 2.6GHz: 0.925210
# node:2.6 round:221
# train mse:0.006422 rmse:0.080136 mae:0.060199 r2:0.946683
# per-client val r2 | 2.4GHz: 0.923275 | 2.5GHz: 0.930262 | 2.6GHz: 0.929662
# node:2.6 round:222
# train mse:0.008253 rmse:0.090847 mae:0.067559 r2:0.931479
# per-client val r2 | 2.4GHz: 0.912634 | 2.5GHz: 0.915595 | 2.6GHz: 0.913365
# node:2.6 round:223
# train mse:0.008367 rmse:0.091472 mae:0.068142 r2:0.930533
# per-client val r2 | 2.4GHz: 0.906396 | 2.5GHz: 0.908441 | 2.6GHz: 0.912355
# node:2.6 round:224
# train mse:0.005496 rmse:0.074134 mae:0.056001 r2:0.954371
# per-client val r2 | 2.4GHz: 0.927298 | 2.5GHz: 0.933617 | 2.6GHz: 0.934215
# node:2.6 round:225
# train mse:0.005920 rmse:0.076944 mae:0.058103 r2:0.950846
# per-client val r2 | 2.4GHz: 0.922255 | 2.5GHz: 0.929515 | 2.6GHz: 0.930153
# node:2.6 round:226
# train mse:0.006697 rmse:0.081833 mae:0.061551 r2:0.944402
# per-client val r2 | 2.4GHz: 0.920450 | 2.5GHz: 0.922419 | 2.6GHz: 0.922590
# node:2.6 round:227
# train mse:0.007147 rmse:0.084539 mae:0.063382 r2:0.940664
# per-client val r2 | 2.4GHz: 0.916464 | 2.5GHz: 0.917933 | 2.6GHz: 0.920340
# node:2.6 round:228
# train mse:0.016676 rmse:0.129137 mae:0.095491 r2:0.861547
# per-client val r2 | 2.4GHz: 0.857876 | 2.5GHz: 0.844879 | 2.6GHz: 0.842305
# node:2.6 round:229
# train mse:0.019568 rmse:0.139887 mae:0.103914 r2:0.837534
# per-client val r2 | 2.4GHz: 0.833961 | 2.5GHz: 0.813603 | 2.6GHz: 0.818740
# node:2.6 round:230
# train mse:0.006716 rmse:0.081948 mae:0.062287 r2:0.944245
# per-client val r2 | 2.4GHz: 0.913560 | 2.5GHz: 0.921320 | 2.6GHz: 0.921598
# node:2.6 round:231
# train mse:0.006059 rmse:0.077839 mae:0.058226 r2:0.949696
# per-client val r2 | 2.4GHz: 0.921634 | 2.5GHz: 0.926805 | 2.6GHz: 0.928180
# node:2.6 round:232
# train mse:0.005580 rmse:0.074700 mae:0.056310 r2:0.953672
# per-client val r2 | 2.4GHz: 0.926115 | 2.5GHz: 0.931512 | 2.6GHz: 0.931176
# node:2.6 round:233
# train mse:0.005599 rmse:0.074826 mae:0.056221 r2:0.953515
# per-client val r2 | 2.4GHz: 0.925697 | 2.5GHz: 0.930530 | 2.6GHz: 0.929419
# node:2.6 round:234
# train mse:0.005884 rmse:0.076706 mae:0.058278 r2:0.951150
# per-client val r2 | 2.4GHz: 0.923935 | 2.5GHz: 0.930611 | 2.6GHz: 0.928531
# node:2.6 round:235
# train mse:0.005042 rmse:0.071010 mae:0.053900 r2:0.958135
# per-client val r2 | 2.4GHz: 0.926282 | 2.5GHz: 0.934141 | 2.6GHz: 0.934345
# node:2.6 round:236
# train mse:0.005051 rmse:0.071069 mae:0.053837 r2:0.958066
# per-client val r2 | 2.4GHz: 0.927855 | 2.5GHz: 0.933734 | 2.6GHz: 0.934048
# node:2.6 round:237
# train mse:0.006186 rmse:0.078650 mae:0.059737 r2:0.948643
# per-client val r2 | 2.4GHz: 0.920296 | 2.5GHz: 0.926337 | 2.6GHz: 0.922765
# node:2.6 round:238
# train mse:0.009886 rmse:0.099430 mae:0.073456 r2:0.917920
# per-client val r2 | 2.4GHz: 0.909230 | 2.5GHz: 0.899651 | 2.6GHz: 0.898135
# node:2.6 round:239
# train mse:0.028762 rmse:0.169595 mae:0.128014 r2:0.761202
# per-client val r2 | 2.4GHz: 0.792330 | 2.5GHz: 0.748367 | 2.6GHz: 0.744652
# node:2.6 round:240
# train mse:0.005431 rmse:0.073694 mae:0.056083 r2:0.954911
# per-client val r2 | 2.4GHz: 0.926018 | 2.5GHz: 0.932493 | 2.6GHz: 0.930899
# node:2.6 round:241
# train mse:0.005175 rmse:0.071940 mae:0.054456 r2:0.957032
# per-client val r2 | 2.4GHz: 0.926217 | 2.5GHz: 0.932655 | 2.6GHz: 0.932979
# node:2.6 round:242
# train mse:0.005265 rmse:0.072561 mae:0.054717 r2:0.956287
# per-client val r2 | 2.4GHz: 0.922680 | 2.5GHz: 0.926681 | 2.6GHz: 0.930673
# node:2.6 round:243
# train mse:0.006640 rmse:0.081489 mae:0.061930 r2:0.944869
# per-client val r2 | 2.4GHz: 0.915678 | 2.5GHz: 0.923056 | 2.6GHz: 0.921965
# node:2.6 round:244
# train mse:0.005324 rmse:0.072966 mae:0.055183 r2:0.955797
# per-client val r2 | 2.4GHz: 0.924913 | 2.5GHz: 0.931933 | 2.6GHz: 0.930864
# node:2.6 round:245
# train mse:0.006869 rmse:0.082882 mae:0.062482 r2:0.942968
# per-client val r2 | 2.4GHz: 0.922835 | 2.5GHz: 0.923160 | 2.6GHz: 0.918901
# node:2.6 round:246
# train mse:0.030128 rmse:0.173575 mae:0.131244 r2:0.749864
# per-client val r2 | 2.4GHz: 0.793586 | 2.5GHz: 0.744196 | 2.6GHz: 0.734321
# node:2.6 round:247
# train mse:0.011689 rmse:0.108117 mae:0.080737 r2:0.902951
# per-client val r2 | 2.4GHz: 0.882858 | 2.5GHz: 0.871876 | 2.6GHz: 0.879978
# node:2.6 round:248
# train mse:0.006571 rmse:0.081065 mae:0.060567 r2:0.945441
# per-client val r2 | 2.4GHz: 0.908664 | 2.5GHz: 0.911134 | 2.6GHz: 0.919656
# node:2.6 round:249
# train mse:0.007502 rmse:0.086616 mae:0.064577 r2:0.937712
# per-client val r2 | 2.4GHz: 0.901796 | 2.5GHz: 0.902636 | 2.6GHz: 0.911258
# node:2.6 round:250
# train mse:0.012232 rmse:0.110600 mae:0.083553 r2:0.898441
# per-client val r2 | 2.4GHz: 0.872394 | 2.5GHz: 0.869876 | 2.6GHz: 0.872617
# node:2.6 round:251
# train mse:0.004741 rmse:0.068854 mae:0.052551 r2:0.960640
# per-client val r2 | 2.4GHz: 0.928191 | 2.5GHz: 0.935100 | 2.6GHz: 0.933515
# node:2.6 round:252
# train mse:0.005226 rmse:0.072290 mae:0.054720 r2:0.956613
# per-client val r2 | 2.4GHz: 0.923541 | 2.5GHz: 0.926749 | 2.6GHz: 0.928515
# node:2.6 round:253
# train mse:0.005815 rmse:0.076254 mae:0.057357 r2:0.951725
# per-client val r2 | 2.4GHz: 0.914048 | 2.5GHz: 0.917915 | 2.6GHz: 0.923657
# node:2.6 round:254
# train mse:0.004563 rmse:0.067551 mae:0.051592 r2:0.962115
# per-client val r2 | 2.4GHz: 0.928640 | 2.5GHz: 0.936087 | 2.6GHz: 0.934529
# node:2.6 round:255
# train mse:0.004963 rmse:0.070446 mae:0.053502 r2:0.958799
# per-client val r2 | 2.4GHz: 0.926127 | 2.5GHz: 0.931048 | 2.6GHz: 0.930249
# node:2.6 round:256
# train mse:0.004217 rmse:0.064942 mae:0.049532 r2:0.964985
# per-client val r2 | 2.4GHz: 0.929171 | 2.5GHz: 0.936782 | 2.6GHz: 0.935488
# node:2.6 round:257
# train mse:0.009084 rmse:0.095310 mae:0.070607 r2:0.924580
# per-client val r2 | 2.4GHz: 0.906087 | 2.5GHz: 0.897299 | 2.6GHz: 0.897219
# node:2.6 round:258
# train mse:0.009230 rmse:0.096074 mae:0.071513 r2:0.923367
# per-client val r2 | 2.4GHz: 0.910595 | 2.5GHz: 0.905641 | 2.6GHz: 0.899805
# node:2.6 round:259
# train mse:0.004466 rmse:0.066832 mae:0.050637 r2:0.962918
# per-client val r2 | 2.4GHz: 0.921753 | 2.5GHz: 0.931283 | 2.6GHz: 0.933977
# node:2.6 round:260
# train mse:0.013774 rmse:0.117361 mae:0.087192 r2:0.885645
# per-client val r2 | 2.4GHz: 0.873277 | 2.5GHz: 0.853642 | 2.6GHz: 0.861120
# node:2.6 round:261
# train mse:0.008278 rmse:0.090982 mae:0.068122 r2:0.931275
# per-client val r2 | 2.4GHz: 0.907527 | 2.5GHz: 0.901249 | 2.6GHz: 0.905183
# node:2.6 round:262
# train mse:0.004868 rmse:0.069774 mae:0.052846 r2:0.959580
# per-client val r2 | 2.4GHz: 0.923937 | 2.5GHz: 0.927706 | 2.6GHz: 0.930623
# node:2.6 round:263
# train mse:0.005057 rmse:0.071111 mae:0.053782 r2:0.958016
# per-client val r2 | 2.4GHz: 0.923325 | 2.5GHz: 0.926283 | 2.6GHz: 0.927919
# node:2.6 round:264
# train mse:0.004064 rmse:0.063750 mae:0.048565 r2:0.966259
# per-client val r2 | 2.4GHz: 0.927733 | 2.5GHz: 0.935122 | 2.6GHz: 0.934231
# node:2.6 round:265
# train mse:0.004371 rmse:0.066110 mae:0.050624 r2:0.963714
# per-client val r2 | 2.4GHz: 0.928672 | 2.5GHz: 0.936652 | 2.6GHz: 0.933046
# node:2.6 round:266
# train mse:0.005203 rmse:0.072130 mae:0.054573 r2:0.956805
# per-client val r2 | 2.4GHz: 0.923342 | 2.5GHz: 0.925757 | 2.6GHz: 0.928486
# node:2.6 round:267
# train mse:0.004832 rmse:0.069512 mae:0.053074 r2:0.959883
# per-client val r2 | 2.4GHz: 0.925043 | 2.5GHz: 0.931970 | 2.6GHz: 0.930710
# node:2.6 round:268
# train mse:0.004550 rmse:0.067454 mae:0.051765 r2:0.962223
# per-client val r2 | 2.4GHz: 0.927463 | 2.5GHz: 0.934968 | 2.6GHz: 0.930031
# node:2.6 round:269
# train mse:0.004654 rmse:0.068217 mae:0.051867 r2:0.961364
# per-client val r2 | 2.4GHz: 0.924787 | 2.5GHz: 0.932659 | 2.6GHz: 0.931781
# node:2.6 round:270
# train mse:0.005116 rmse:0.071528 mae:0.054471 r2:0.957522
# per-client val r2 | 2.4GHz: 0.925858 | 2.5GHz: 0.931772 | 2.6GHz: 0.926946
# node:2.6 round:271
# train mse:0.006107 rmse:0.078150 mae:0.058698 r2:0.949293
# per-client val r2 | 2.4GHz: 0.910493 | 2.5GHz: 0.912398 | 2.6GHz: 0.916633
# node:2.6 round:272
# train mse:0.004104 rmse:0.064062 mae:0.049119 r2:0.965927
# per-client val r2 | 2.4GHz: 0.929846 | 2.5GHz: 0.936347 | 2.6GHz: 0.932863
# node:2.6 round:273
# train mse:0.010205 rmse:0.101022 mae:0.074779 r2:0.915271
# per-client val r2 | 2.4GHz: 0.893881 | 2.5GHz: 0.880979 | 2.6GHz: 0.887501
# node:2.6 round:274
# train mse:0.004006 rmse:0.063293 mae:0.048341 r2:0.966740
# per-client val r2 | 2.4GHz: 0.927942 | 2.5GHz: 0.935679 | 2.6GHz: 0.933885
# node:2.6 round:275
# train mse:0.006239 rmse:0.078990 mae:0.058997 r2:0.948198
# per-client val r2 | 2.4GHz: 0.906700 | 2.5GHz: 0.906080 | 2.6GHz: 0.916407
# node:2.6 round:276
# train mse:0.004046 rmse:0.063609 mae:0.048257 r2:0.966408
# per-client val r2 | 2.4GHz: 0.926321 | 2.5GHz: 0.930427 | 2.6GHz: 0.933491
# node:2.6 round:277
# train mse:0.003827 rmse:0.061866 mae:0.047097 r2:0.968224
# per-client val r2 | 2.4GHz: 0.927840 | 2.5GHz: 0.933967 | 2.6GHz: 0.934343
# node:2.6 round:278
# train mse:0.005633 rmse:0.075056 mae:0.057191 r2:0.953229
# per-client val r2 | 2.4GHz: 0.919370 | 2.5GHz: 0.919760 | 2.6GHz: 0.919404
# node:2.6 round:279
# train mse:0.007483 rmse:0.086505 mae:0.064468 r2:0.937872
# per-client val r2 | 2.4GHz: 0.898704 | 2.5GHz: 0.894651 | 2.6GHz: 0.907160
# node:2.6 round:280
# train mse:0.005455 rmse:0.073858 mae:0.055553 r2:0.954711
# per-client val r2 | 2.4GHz: 0.913618 | 2.5GHz: 0.915432 | 2.6GHz: 0.922720
# node:2.6 round:281
# train mse:0.008319 rmse:0.091210 mae:0.068631 r2:0.930930
# per-client val r2 | 2.4GHz: 0.905716 | 2.5GHz: 0.898887 | 2.6GHz: 0.901830
# node:2.6 round:282
# train mse:0.004901 rmse:0.070004 mae:0.052757 r2:0.959314
# per-client val r2 | 2.4GHz: 0.914815 | 2.5GHz: 0.916353 | 2.6GHz: 0.924395
# node:2.6 round:283
# train mse:0.003828 rmse:0.061874 mae:0.047327 r2:0.968215
# per-client val r2 | 2.4GHz: 0.930431 | 2.5GHz: 0.936264 | 2.6GHz: 0.934228
# node:2.6 round:284
# train mse:0.008603 rmse:0.092754 mae:0.069568 r2:0.928572
# per-client val r2 | 2.4GHz: 0.890689 | 2.5GHz: 0.880950 | 2.6GHz: 0.897582
# node:2.6 round:285
# train mse:0.004517 rmse:0.067212 mae:0.050986 r2:0.962494
# per-client val r2 | 2.4GHz: 0.919651 | 2.5GHz: 0.922658 | 2.6GHz: 0.928178
# node:2.6 round:286
# train mse:0.003695 rmse:0.060787 mae:0.046365 r2:0.969322
# per-client val r2 | 2.4GHz: 0.925053 | 2.5GHz: 0.931484 | 2.6GHz: 0.933137
# node:2.6 round:287
# train mse:0.003666 rmse:0.060545 mae:0.046291 r2:0.969566
# per-client val r2 | 2.4GHz: 0.928839 | 2.5GHz: 0.935507 | 2.6GHz: 0.934427
# node:2.6 round:288
# train mse:0.006939 rmse:0.083302 mae:0.063451 r2:0.942387
# per-client val r2 | 2.4GHz: 0.910851 | 2.5GHz: 0.913063 | 2.6GHz: 0.906682
# node:2.6 round:289
# train mse:0.005214 rmse:0.072208 mae:0.055233 r2:0.956711
# per-client val r2 | 2.4GHz: 0.923066 | 2.5GHz: 0.925515 | 2.6GHz: 0.919976
# node:2.6 round:290
# train mse:0.003898 rmse:0.062433 mae:0.047298 r2:0.967638
# per-client val r2 | 2.4GHz: 0.924479 | 2.5GHz: 0.926194 | 2.6GHz: 0.930583
# node:2.6 round:291
# train mse:0.003919 rmse:0.062605 mae:0.048002 r2:0.967460
# per-client val r2 | 2.4GHz: 0.929757 | 2.5GHz: 0.937757 | 2.6GHz: 0.932041
# node:2.6 round:292
# train mse:0.003939 rmse:0.062761 mae:0.048071 r2:0.967297
# per-client val r2 | 2.4GHz: 0.930152 | 2.5GHz: 0.937136 | 2.6GHz: 0.930927
# node:2.6 round:293
# train mse:0.003892 rmse:0.062382 mae:0.047363 r2:0.967691
# per-client val r2 | 2.4GHz: 0.922404 | 2.5GHz: 0.925794 | 2.6GHz: 0.930640
# node:2.6 round:294
# train mse:0.003923 rmse:0.062637 mae:0.047775 r2:0.967426
# per-client val r2 | 2.4GHz: 0.927305 | 2.5GHz: 0.932210 | 2.6GHz: 0.931016
# node:2.6 round:295
# train mse:0.003990 rmse:0.063168 mae:0.047995 r2:0.966872
# per-client val r2 | 2.4GHz: 0.921221 | 2.5GHz: 0.922953 | 2.6GHz: 0.930116
# node:2.6 round:296
# train mse:0.003758 rmse:0.061304 mae:0.046911 r2:0.968798
# per-client val r2 | 2.4GHz: 0.929136 | 2.5GHz: 0.936114 | 2.6GHz: 0.932741
# node:2.6 round:297
# train mse:0.003325 rmse:0.057664 mae:0.044132 r2:0.972393
# per-client val r2 | 2.4GHz: 0.926933 | 2.5GHz: 0.934341 | 2.6GHz: 0.936328
# node:2.6 round:298
# train mse:0.003498 rmse:0.059143 mae:0.045359 r2:0.970959
# per-client val r2 | 2.4GHz: 0.928737 | 2.5GHz: 0.933244 | 2.6GHz: 0.934058
# node:2.6 round:299
# train mse:0.003167 rmse:0.056273 mae:0.043062 r2:0.973709
# per-client val r2 | 2.4GHz: 0.928201 | 2.5GHz: 0.934968 | 2.6GHz: 0.935817
# node:2.4 round:300
# train mse:0.005686 rmse:0.075403 mae:0.056539 r2:0.952977
# per-client val r2 | 2.4GHz: 0.941849 | 2.5GHz: 0.929997 | 2.6GHz: 0.923885
# node:2.4 round:301
# train mse:0.005896 rmse:0.076785 mae:0.057418 r2:0.951237
# per-client val r2 | 2.4GHz: 0.939126 | 2.5GHz: 0.938420 | 2.6GHz: 0.925642
# node:2.4 round:302
# train mse:0.005054 rmse:0.071094 mae:0.053078 r2:0.958197
# per-client val r2 | 2.4GHz: 0.944971 | 2.5GHz: 0.943602 | 2.6GHz: 0.931375
# node:2.4 round:303
# train mse:0.004640 rmse:0.068114 mae:0.051126 r2:0.961628
# per-client val r2 | 2.4GHz: 0.947459 | 2.5GHz: 0.941297 | 2.6GHz: 0.931497
# node:2.4 round:304
# train mse:0.004855 rmse:0.069678 mae:0.052230 r2:0.959846
# per-client val r2 | 2.4GHz: 0.946356 | 2.5GHz: 0.942738 | 2.6GHz: 0.929438
# node:2.4 round:305
# train mse:0.004461 rmse:0.066793 mae:0.050277 r2:0.963102
# per-client val r2 | 2.4GHz: 0.949046 | 2.5GHz: 0.941908 | 2.6GHz: 0.931559
# node:2.4 round:306
# train mse:0.004220 rmse:0.064965 mae:0.048853 r2:0.965095
# per-client val r2 | 2.4GHz: 0.950237 | 2.5GHz: 0.942211 | 2.6GHz: 0.931360
# node:2.4 round:307
# train mse:0.004445 rmse:0.066670 mae:0.049967 r2:0.963238
# per-client val r2 | 2.4GHz: 0.948584 | 2.5GHz: 0.944804 | 2.6GHz: 0.931923
# node:2.4 round:308
# train mse:0.004278 rmse:0.065408 mae:0.049304 r2:0.964617
# per-client val r2 | 2.4GHz: 0.949964 | 2.5GHz: 0.943221 | 2.6GHz: 0.931590
# node:2.4 round:309
# train mse:0.004360 rmse:0.066030 mae:0.049539 r2:0.963941
# per-client val r2 | 2.4GHz: 0.948518 | 2.5GHz: 0.943884 | 2.6GHz: 0.930238
# node:2.4 round:310
# train mse:0.005912 rmse:0.076886 mae:0.057935 r2:0.951108
# per-client val r2 | 2.4GHz: 0.935175 | 2.5GHz: 0.906171 | 2.6GHz: 0.897022
# node:2.4 round:311
# train mse:0.004102 rmse:0.064044 mae:0.048177 r2:0.966077
# per-client val r2 | 2.4GHz: 0.949759 | 2.5GHz: 0.946462 | 2.6GHz: 0.933139
# node:2.4 round:312
# train mse:0.009430 rmse:0.097106 mae:0.072463 r2:0.922012
# per-client val r2 | 2.4GHz: 0.907158 | 2.5GHz: 0.904900 | 2.6GHz: 0.904658
# node:2.4 round:313
# train mse:0.003938 rmse:0.062751 mae:0.047216 r2:0.967433
# per-client val r2 | 2.4GHz: 0.950894 | 2.5GHz: 0.944585 | 2.6GHz: 0.932423
# node:2.4 round:314
# train mse:0.005030 rmse:0.070921 mae:0.053509 r2:0.958401
# per-client val r2 | 2.4GHz: 0.942212 | 2.5GHz: 0.918081 | 2.6GHz: 0.911050
# node:2.4 round:315
# train mse:0.004208 rmse:0.064871 mae:0.048852 r2:0.965196
# ...
# node:2.5 round:495
# train mse:0.001888 rmse:0.043450 mae:0.032712 r2:0.984349
# per-client val r2 | 2.4GHz: 0.956399 | 2.5GHz: 0.955520 | 2.6GHz: 0.941914
# node:2.5 round:496
# train mse:0.001913 rmse:0.043739 mae:0.032880 r2:0.984140
# per-client val r2 | 2.4GHz: 0.956666 | 2.5GHz: 0.954816 | 2.6GHz: 0.941848
# node:2.5 round:497
# train mse:0.001878 rmse:0.043340 mae:0.032607 r2:0.984428
# per-client val r2 | 2.4GHz: 0.956492 | 2.5GHz: 0.955433 | 2.6GHz: 0.942057
# node:2.5 round:498
# train mse:0.001869 rmse:0.043236 mae:0.032522 r2:0.984502
# per-client val r2 | 2.4GHz: 0.956303 | 2.5GHz: 0.955361 | 2.6GHz: 0.942186
# node:2.5 round:499
# train mse:0.001968 rmse:0.044368 mae:0.033348 r2:0.983681
# per-client val r2 | 2.4GHz: 0.956524 | 2.5GHz: 0.953923 | 2.6GHz: 0.941677
# node:2.6 round:500
# train mse:0.003095 rmse:0.055632 mae:0.042239 r2:0.974305
# per-client val r2 | 2.4GHz: 0.955121 | 2.5GHz: 0.955968 | 2.6GHz: 0.945953
# node:2.6 round:501
# train mse:0.002972 rmse:0.054514 mae:0.041326 r2:0.975327
# per-client val r2 | 2.4GHz: 0.954783 | 2.5GHz: 0.955120 | 2.6GHz: 0.946097
# node:2.6 round:502
# train mse:0.002885 rmse:0.053713 mae:0.040748 r2:0.976047
# per-client val r2 | 2.4GHz: 0.954975 | 2.5GHz: 0.954970 | 2.6GHz: 0.946412
# node:2.6 round:503
# train mse:0.002791 rmse:0.052828 mae:0.040159 r2:0.976830
# per-client val r2 | 2.4GHz: 0.955383 | 2.5GHz: 0.956937 | 2.6GHz: 0.946176
# node:2.6 round:504
# train mse:0.002752 rmse:0.052462 mae:0.039921 r2:0.977149
# per-client val r2 | 2.4GHz: 0.955317 | 2.5GHz: 0.957121 | 2.6GHz: 0.946065
# node:2.6 round:505
# train mse:0.002668 rmse:0.051657 mae:0.039273 r2:0.977845
# per-client val r2 | 2.4GHz: 0.954932 | 2.5GHz: 0.956194 | 2.6GHz: 0.946773
# node:2.6 round:506
# train mse:0.002644 rmse:0.051423 mae:0.039101 r2:0.978046
# per-client val r2 | 2.4GHz: 0.955196 | 2.5GHz: 0.956157 | 2.6GHz: 0.946703
# node:2.6 round:507
# train mse:0.002706 rmse:0.052022 mae:0.039642 r2:0.977531
# per-client val r2 | 2.4GHz: 0.954510 | 2.5GHz: 0.957386 | 2.6GHz: 0.945843
# node:2.6 round:508
# train mse:0.002607 rmse:0.051063 mae:0.038869 r2:0.978352
# per-client val r2 | 2.4GHz: 0.955004 | 2.5GHz: 0.957170 | 2.6GHz: 0.946383
# node:2.6 round:509
# train mse:0.002613 rmse:0.051117 mae:0.038776 r2:0.978306
# per-client val r2 | 2.4GHz: 0.954502 | 2.5GHz: 0.954363 | 2.6GHz: 0.946311
# node:2.6 round:510
# train mse:0.002513 rmse:0.050129 mae:0.038143 r2:0.979137
# per-client val r2 | 2.4GHz: 0.955190 | 2.5GHz: 0.956995 | 2.6GHz: 0.946830
# node:2.6 round:511
# train mse:0.002508 rmse:0.050084 mae:0.038071 r2:0.979174
# per-client val r2 | 2.4GHz: 0.955224 | 2.5GHz: 0.956501 | 2.6GHz: 0.946705
# node:2.6 round:512
# train mse:0.002470 rmse:0.049703 mae:0.037832 r2:0.979490
# per-client val r2 | 2.4GHz: 0.955158 | 2.5GHz: 0.957238 | 2.6GHz: 0.946682
# node:2.6 round:513
# train mse:0.002541 rmse:0.050405 mae:0.038218 r2:0.978907
# per-client val r2 | 2.4GHz: 0.954244 | 2.5GHz: 0.954196 | 2.6GHz: 0.946339
# node:2.6 round:514
# train mse:0.002414 rmse:0.049134 mae:0.037360 r2:0.979956
# per-client val r2 | 2.4GHz: 0.955227 | 2.5GHz: 0.956587 | 2.6GHz: 0.946925
# node:2.6 round:515
# train mse:0.002411 rmse:0.049098 mae:0.037371 r2:0.979986
# per-client val r2 | 2.4GHz: 0.955187 | 2.5GHz: 0.957615 | 2.6GHz: 0.946758
# node:2.6 round:516
# train mse:0.002382 rmse:0.048804 mae:0.037113 r2:0.980225
# per-client val r2 | 2.4GHz: 0.955223 | 2.5GHz: 0.956576 | 2.6GHz: 0.946753
# node:2.6 round:517
# train mse:0.002364 rmse:0.048618 mae:0.036962 r2:0.980376
# per-client val r2 | 2.4GHz: 0.954998 | 2.5GHz: 0.956513 | 2.6GHz: 0.946884
# node:2.6 round:518
# train mse:0.002346 rmse:0.048433 mae:0.036851 r2:0.980525
# per-client val r2 | 2.4GHz: 0.955302 | 2.5GHz: 0.956985 | 2.6GHz: 0.946774
# node:2.6 round:519
# train mse:0.002362 rmse:0.048598 mae:0.036919 r2:0.980391
# per-client val r2 | 2.4GHz: 0.954962 | 2.5GHz: 0.956002 | 2.6GHz: 0.946701
# node:2.6 round:520
# train mse:0.002327 rmse:0.048244 mae:0.036676 r2:0.980676
# per-client val r2 | 2.4GHz: 0.955172 | 2.5GHz: 0.956406 | 2.6GHz: 0.946875
# node:2.6 round:521
# train mse:0.002303 rmse:0.047989 mae:0.036493 r2:0.980880
# per-client val r2 | 2.4GHz: 0.955161 | 2.5GHz: 0.956964 | 2.6GHz: 0.946783
# node:2.6 round:522
# train mse:0.002306 rmse:0.048019 mae:0.036498 r2:0.980856
# per-client val r2 | 2.4GHz: 0.955135 | 2.5GHz: 0.956385 | 2.6GHz: 0.946838
# node:2.6 round:523
# train mse:0.002347 rmse:0.048447 mae:0.036745 r2:0.980513
# per-client val r2 | 2.4GHz: 0.954684 | 2.5GHz: 0.955089 | 2.6GHz: 0.946477
# node:2.6 round:524
# train mse:0.002260 rmse:0.047540 mae:0.036147 r2:0.981236
# per-client val r2 | 2.4GHz: 0.955304 | 2.5GHz: 0.957123 | 2.6GHz: 0.946960
# node:2.6 round:525
# train mse:0.002247 rmse:0.047398 mae:0.036032 r2:0.981348
# per-client val r2 | 2.4GHz: 0.955127 | 2.5GHz: 0.956809 | 2.6GHz: 0.946902
# node:2.6 round:526
# train mse:0.002256 rmse:0.047499 mae:0.036082 r2:0.981269
# per-client val r2 | 2.4GHz: 0.955097 | 2.5GHz: 0.956198 | 2.6GHz: 0.946778
# node:2.6 round:527
# train mse:0.002223 rmse:0.047146 mae:0.035871 r2:0.981546
# per-client val r2 | 2.4GHz: 0.955355 | 2.5GHz: 0.957310 | 2.6GHz: 0.946645
# node:2.6 round:528
# train mse:0.002219 rmse:0.047111 mae:0.035813 r2:0.981573
# per-client val r2 | 2.4GHz: 0.955191 | 2.5GHz: 0.956600 | 2.6GHz: 0.946816
# node:2.6 round:529
# train mse:0.002271 rmse:0.047660 mae:0.036189 r2:0.981141
# per-client val r2 | 2.4GHz: 0.954728 | 2.5GHz: 0.955091 | 2.6GHz: 0.946340
# node:2.6 round:530
# train mse:0.002212 rmse:0.047034 mae:0.035749 r2:0.981634
# per-client val r2 | 2.4GHz: 0.955139 | 2.5GHz: 0.956312 | 2.6GHz: 0.946487
# node:2.6 round:531
# train mse:0.002186 rmse:0.046755 mae:0.035531 r2:0.981851
# per-client val r2 | 2.4GHz: 0.955246 | 2.5GHz: 0.956715 | 2.6GHz: 0.946879
# node:2.6 round:532
# train mse:0.002175 rmse:0.046636 mae:0.035458 r2:0.981943
# per-client val r2 | 2.4GHz: 0.955285 | 2.5GHz: 0.957247 | 2.6GHz: 0.946839
# node:2.6 round:533
# train mse:0.002217 rmse:0.047088 mae:0.035751 r2:0.981591
# per-client val r2 | 2.4GHz: 0.954856 | 2.5GHz: 0.955616 | 2.6GHz: 0.946402
# node:2.6 round:534
# train mse:0.002161 rmse:0.046482 mae:0.035346 r2:0.982062
# per-client val r2 | 2.4GHz: 0.955351 | 2.5GHz: 0.956995 | 2.6GHz: 0.946624
# node:2.6 round:535
# train mse:0.002158 rmse:0.046449 mae:0.035298 r2:0.982087
# per-client val r2 | 2.4GHz: 0.955331 | 2.5GHz: 0.956856 | 2.6GHz: 0.946774
# node:2.6 round:536
# train mse:0.002138 rmse:0.046243 mae:0.035159 r2:0.982246
# per-client val r2 | 2.4GHz: 0.955371 | 2.5GHz: 0.957159 | 2.6GHz: 0.946701
# node:2.6 round:537
# train mse:0.002184 rmse:0.046733 mae:0.035480 r2:0.981868
# per-client val r2 | 2.4GHz: 0.954983 | 2.5GHz: 0.955603 | 2.6GHz: 0.946499
# node:2.6 round:538
# train mse:0.002133 rmse:0.046186 mae:0.035097 r2:0.982289
# per-client val r2 | 2.4GHz: 0.955315 | 2.5GHz: 0.956768 | 2.6GHz: 0.946565
# node:2.6 round:539
# train mse:0.002127 rmse:0.046124 mae:0.035036 r2:0.982337
# per-client val r2 | 2.4GHz: 0.955270 | 2.5GHz: 0.956786 | 2.6GHz: 0.946571
# node:2.6 round:540
# train mse:0.002131 rmse:0.046164 mae:0.035137 r2:0.982307
# per-client val r2 | 2.4GHz: 0.955374 | 2.5GHz: 0.957946 | 2.6GHz: 0.946329
# node:2.6 round:541
# train mse:0.002111 rmse:0.045945 mae:0.034910 r2:0.982474
# per-client val r2 | 2.4GHz: 0.955301 | 2.5GHz: 0.956755 | 2.6GHz: 0.946530
# node:2.6 round:542
# train mse:0.002100 rmse:0.045828 mae:0.034824 r2:0.982563
# per-client val r2 | 2.4GHz: 0.955286 | 2.5GHz: 0.956941 | 2.6GHz: 0.946547
# node:2.6 round:543
# train mse:0.002095 rmse:0.045769 mae:0.034779 r2:0.982608
# per-client val r2 | 2.4GHz: 0.955219 | 2.5GHz: 0.956971 | 2.6GHz: 0.946683
# node:2.6 round:544
# train mse:0.002110 rmse:0.045937 mae:0.034882 r2:0.982480
# per-client val r2 | 2.4GHz: 0.955132 | 2.5GHz: 0.956276 | 2.6GHz: 0.946504
# node:2.6 round:545
# train mse:0.002088 rmse:0.045697 mae:0.034722 r2:0.982662
# per-client val r2 | 2.4GHz: 0.955252 | 2.5GHz: 0.956782 | 2.6GHz: 0.946535
# node:2.6 round:546
# train mse:0.002078 rmse:0.045588 mae:0.034638 r2:0.982745
# per-client val r2 | 2.4GHz: 0.955408 | 2.5GHz: 0.956999 | 2.6GHz: 0.946642
# node:2.6 round:547
# train mse:0.002074 rmse:0.045540 mae:0.034600 r2:0.982781
# per-client val r2 | 2.4GHz: 0.955349 | 2.5GHz: 0.957084 | 2.6GHz: 0.946601
# node:2.6 round:548
# train mse:0.002082 rmse:0.045626 mae:0.034651 r2:0.982717
# per-client val r2 | 2.4GHz: 0.955160 | 2.5GHz: 0.956592 | 2.6GHz: 0.946501
# node:2.6 round:549
# train mse:0.002066 rmse:0.045448 mae:0.034565 r2:0.982851
# per-client val r2 | 2.4GHz: 0.955427 | 2.5GHz: 0.957753 | 2.6GHz: 0.946373
# node:2.6 round:550
# train mse:0.002054 rmse:0.045320 mae:0.034457 r2:0.982948
# per-client val r2 | 2.4GHz: 0.955475 | 2.5GHz: 0.957585 | 2.6GHz: 0.946438
# node:2.6 round:551
# train mse:0.002049 rmse:0.045261 mae:0.034409 r2:0.982992
# per-client val r2 | 2.4GHz: 0.955363 | 2.5GHz: 0.957557 | 2.6GHz: 0.946672
# node:2.6 round:552
# train mse:0.002052 rmse:0.045296 mae:0.034407 r2:0.982966
# per-client val r2 | 2.4GHz: 0.955294 | 2.5GHz: 0.956913 | 2.6GHz: 0.946686
# node:2.6 round:553
# train mse:0.002061 rmse:0.045401 mae:0.034488 r2:0.982887
# per-client val r2 | 2.4GHz: 0.955198 | 2.5GHz: 0.956459 | 2.6GHz: 0.946474
# node:2.6 round:554
# train mse:0.002049 rmse:0.045266 mae:0.034384 r2:0.982988
# per-client val r2 | 2.4GHz: 0.955239 | 2.5GHz: 0.956710 | 2.6GHz: 0.946559
# node:2.6 round:555
# train mse:0.002034 rmse:0.045105 mae:0.034284 r2:0.983109
# per-client val r2 | 2.4GHz: 0.955437 | 2.5GHz: 0.957427 | 2.6GHz: 0.946534
# node:2.6 round:556
# train mse:0.002033 rmse:0.045091 mae:0.034277 r2:0.983119
# per-client val r2 | 2.4GHz: 0.955270 | 2.5GHz: 0.957017 | 2.6GHz: 0.946508
# node:2.6 round:557
# train mse:0.002029 rmse:0.045043 mae:0.034223 r2:0.983155
# per-client val r2 | 2.4GHz: 0.955331 | 2.5GHz: 0.957194 | 2.6GHz: 0.946611
# node:2.6 round:558
# train mse:0.002032 rmse:0.045082 mae:0.034242 r2:0.983127
# per-client val r2 | 2.4GHz: 0.955266 | 2.5GHz: 0.956856 | 2.6GHz: 0.946503
# node:2.6 round:559
# train mse:0.002023 rmse:0.044980 mae:0.034171 r2:0.983203
# per-client val r2 | 2.4GHz: 0.955296 | 2.5GHz: 0.957043 | 2.6GHz: 0.946493
# node:2.6 round:560
# train mse:0.002021 rmse:0.044958 mae:0.034152 r2:0.983219
# per-client val r2 | 2.4GHz: 0.955349 | 2.5GHz: 0.957146 | 2.6GHz: 0.946523
# node:2.6 round:561
# train mse:0.002015 rmse:0.044894 mae:0.034124 r2:0.983267
# per-client val r2 | 2.4GHz: 0.955472 | 2.5GHz: 0.957534 | 2.6GHz: 0.946501
# node:2.6 round:562
# train mse:0.002011 rmse:0.044844 mae:0.034081 r2:0.983304
# per-client val r2 | 2.4GHz: 0.955501 | 2.5GHz: 0.957412 | 2.6GHz: 0.946554
# node:2.6 round:563
# train mse:0.002010 rmse:0.044836 mae:0.034067 r2:0.983310
# per-client val r2 | 2.4GHz: 0.955396 | 2.5GHz: 0.957215 | 2.6GHz: 0.946588
# node:2.6 round:564
# train mse:0.002014 rmse:0.044882 mae:0.034093 r2:0.983276
# per-client val r2 | 2.4GHz: 0.955251 | 2.5GHz: 0.956873 | 2.6GHz: 0.946487
# node:2.6 round:565
# train mse:0.002005 rmse:0.044781 mae:0.034034 r2:0.983351
# per-client val r2 | 2.4GHz: 0.955495 | 2.5GHz: 0.957495 | 2.6GHz: 0.946489
# node:2.6 round:566
# train mse:0.002001 rmse:0.044736 mae:0.033991 r2:0.983384
# per-client val r2 | 2.4GHz: 0.955390 | 2.5GHz: 0.957293 | 2.6GHz: 0.946497
# node:2.6 round:567
# train mse:0.002000 rmse:0.044721 mae:0.033983 r2:0.983395
# per-client val r2 | 2.4GHz: 0.955595 | 2.5GHz: 0.957454 | 2.6GHz: 0.946489
# node:2.6 round:568
# train mse:0.002002 rmse:0.044743 mae:0.033978 r2:0.983379
# per-client val r2 | 2.4GHz: 0.955363 | 2.5GHz: 0.956975 | 2.6GHz: 0.946491
# node:2.6 round:569
# train mse:0.002002 rmse:0.044747 mae:0.033994 r2:0.983376
# per-client val r2 | 2.4GHz: 0.955426 | 2.5GHz: 0.957050 | 2.6GHz: 0.946401
# node:2.6 round:570
# train mse:0.001995 rmse:0.044670 mae:0.033958 r2:0.983433
# per-client val r2 | 2.4GHz: 0.955500 | 2.5GHz: 0.957716 | 2.6GHz: 0.946454
# node:2.6 round:571
# train mse:0.001992 rmse:0.044630 mae:0.033912 r2:0.983463
# per-client val r2 | 2.4GHz: 0.955432 | 2.5GHz: 0.957320 | 2.6GHz: 0.946533
# node:2.6 round:572
# train mse:0.002005 rmse:0.044773 mae:0.034001 r2:0.983356
# per-client val r2 | 2.4GHz: 0.955313 | 2.5GHz: 0.956723 | 2.6GHz: 0.946522
# node:2.6 round:573
# train mse:0.001988 rmse:0.044583 mae:0.033872 r2:0.983497
# per-client val r2 | 2.4GHz: 0.955364 | 2.5GHz: 0.957297 | 2.6GHz: 0.946584
# node:2.6 round:574
# train mse:0.001987 rmse:0.044579 mae:0.033870 r2:0.983501
# per-client val r2 | 2.4GHz: 0.955433 | 2.5GHz: 0.957276 | 2.6GHz: 0.946464
# node:2.6 round:575
# train mse:0.001996 rmse:0.044675 mae:0.033924 r2:0.983429
# per-client val r2 | 2.4GHz: 0.955317 | 2.5GHz: 0.956853 | 2.6GHz: 0.946481
# node:2.6 round:576
# train mse:0.001988 rmse:0.044585 mae:0.033864 r2:0.983496
# per-client val r2 | 2.4GHz: 0.955387 | 2.5GHz: 0.957110 | 2.6GHz: 0.946494
# node:2.6 round:577
# train mse:0.001985 rmse:0.044553 mae:0.033846 r2:0.983520
# per-client val r2 | 2.4GHz: 0.955435 | 2.5GHz: 0.957174 | 2.6GHz: 0.946507
# node:2.6 round:578
# train mse:0.001990 rmse:0.044610 mae:0.033880 r2:0.983478
# per-client val r2 | 2.4GHz: 0.955334 | 2.5GHz: 0.956960 | 2.6GHz: 0.946465
# node:2.6 round:579
# train mse:0.001980 rmse:0.044500 mae:0.033809 r2:0.983559
# per-client val r2 | 2.4GHz: 0.955475 | 2.5GHz: 0.957466 | 2.6GHz: 0.946478
# node:2.6 round:580
# train mse:0.001984 rmse:0.044537 mae:0.033828 r2:0.983532
# per-client val r2 | 2.4GHz: 0.955391 | 2.5GHz: 0.957116 | 2.6GHz: 0.946453
# node:2.6 round:581
# train mse:0.001983 rmse:0.044534 mae:0.033825 r2:0.983534
# per-client val r2 | 2.4GHz: 0.955384 | 2.5GHz: 0.957096 | 2.6GHz: 0.946439
# node:2.6 round:582
# train mse:0.001980 rmse:0.044493 mae:0.033798 r2:0.983565
# per-client val r2 | 2.4GHz: 0.955459 | 2.5GHz: 0.957293 | 2.6GHz: 0.946414
# node:2.6 round:583
# train mse:0.001977 rmse:0.044460 mae:0.033776 r2:0.983589
# per-client val r2 | 2.4GHz: 0.955442 | 2.5GHz: 0.957390 | 2.6GHz: 0.946445
# node:2.6 round:584
# train mse:0.001980 rmse:0.044499 mae:0.033798 r2:0.983560
# per-client val r2 | 2.4GHz: 0.955402 | 2.5GHz: 0.957127 | 2.6GHz: 0.946467
# node:2.6 round:585
# train mse:0.001979 rmse:0.044491 mae:0.033795 r2:0.983566
# per-client val r2 | 2.4GHz: 0.955418 | 2.5GHz: 0.957127 | 2.6GHz: 0.946435
# node:2.6 round:586
# train mse:0.001975 rmse:0.044441 mae:0.033767 r2:0.983603
# per-client val r2 | 2.4GHz: 0.955505 | 2.5GHz: 0.957521 | 2.6GHz: 0.946458
# node:2.6 round:587
# train mse:0.001976 rmse:0.044448 mae:0.033766 r2:0.983598
# per-client val r2 | 2.4GHz: 0.955437 | 2.5GHz: 0.957329 | 2.6GHz: 0.946473
# node:2.6 round:588
# train mse:0.001976 rmse:0.044456 mae:0.033770 r2:0.983592
# per-client val r2 | 2.4GHz: 0.955437 | 2.5GHz: 0.957259 | 2.6GHz: 0.946454
# node:2.6 round:589
# train mse:0.001976 rmse:0.044448 mae:0.033764 r2:0.983598
# per-client val r2 | 2.4GHz: 0.955445 | 2.5GHz: 0.957288 | 2.6GHz: 0.946467
# node:2.6 round:590
# train mse:0.001973 rmse:0.044421 mae:0.033749 r2:0.983618
# per-client val r2 | 2.4GHz: 0.955459 | 2.5GHz: 0.957475 | 2.6GHz: 0.946476
# node:2.6 round:591
# train mse:0.001974 rmse:0.044430 mae:0.033751 r2:0.983611
# per-client val r2 | 2.4GHz: 0.955413 | 2.5GHz: 0.957287 | 2.6GHz: 0.946503
# node:2.6 round:592
# train mse:0.001972 rmse:0.044409 mae:0.033740 r2:0.983627
# per-client val r2 | 2.4GHz: 0.955480 | 2.5GHz: 0.957496 | 2.6GHz: 0.946445
# node:2.6 round:593
# train mse:0.001974 rmse:0.044425 mae:0.033747 r2:0.983615
# per-client val r2 | 2.4GHz: 0.955424 | 2.5GHz: 0.957263 | 2.6GHz: 0.946472
# node:2.6 round:594
# train mse:0.001972 rmse:0.044408 mae:0.033738 r2:0.983627
# per-client val r2 | 2.4GHz: 0.955468 | 2.5GHz: 0.957418 | 2.6GHz: 0.946455
# node:2.6 round:595
# train mse:0.001971 rmse:0.044401 mae:0.033736 r2:0.983632
# per-client val r2 | 2.4GHz: 0.955488 | 2.5GHz: 0.957499 | 2.6GHz: 0.946450
# node:2.6 round:596
# train mse:0.001972 rmse:0.044405 mae:0.033736 r2:0.983629
# per-client val r2 | 2.4GHz: 0.955467 | 2.5GHz: 0.957381 | 2.6GHz: 0.946428
# node:2.6 round:597
# train mse:0.001971 rmse:0.044400 mae:0.033734 r2:0.983633
# per-client val r2 | 2.4GHz: 0.955471 | 2.5GHz: 0.957453 | 2.6GHz: 0.946451
# node:2.6 round:598
# train mse:0.001971 rmse:0.044395 mae:0.033727 r2:0.983637
# per-client val r2 | 2.4GHz: 0.955472 | 2.5GHz: 0.957428 | 2.6GHz: 0.946440
# node:2.6 round:599
# train mse:0.001973 rmse:0.044415 mae:0.033739 r2:0.983622
# per-client val r2 | 2.4GHz: 0.955436 | 2.5GHz: 0.957242 | 2.6GHz: 0.946458

# %%
def calc_forgetting(r2_dict):
    forgetting = {}
    for freq, history in r2_dict.items():
        if len(history) == 0:
            forgetting[freq] = np.nan
        else:
            forgetting[freq] = float(np.max(history) - history[-1])
    return forgetting


forgetting = calc_forgetting(r2_client_val)

print("\n===== Forgetting Summary (per-client local val) =====")
for freq in [2.4, 2.5, 2.6]:
    print(
        "client {} GHz | best {:.6f} | final {:.6f} | forgetting {:.6f}".format(
            freq,
            np.max(r2_client_val[freq]),
            r2_client_val[freq][-1],
            forgetting[freq],
        )
    )

avg_forgetting = np.mean([forgetting[2.4], forgetting[2.5], forgetting[2.6]])
print("Average Forgetting: {:.6f}".format(avg_forgetting))


save_dir = Path("./forgetting_logs")
save_dir.mkdir(parents=True, exist_ok=True)

r24 = np.array(r2_client_val[2.4], dtype=np.float32)
r25 = np.array(r2_client_val[2.5], dtype=np.float32)
r26 = np.array(r2_client_val[2.6], dtype=np.float32)

owners = np.array(round_owner, dtype=np.float32)
global_r2 = np.array(r2_vali, dtype=np.float32) if len(r2_vali) > 0 else np.array([], dtype=np.float32)
train_r2 = np.array(r2_train, dtype=np.float32) if len(r2_train) > 0 else np.array([], dtype=np.float32)

n_rounds = min(len(owners), len(r24), len(r25), len(r26))
round_idx = np.arange(n_rounds, dtype=np.int32)

owners = owners[:n_rounds]
r24 = r24[:n_rounds]
r25 = r25[:n_rounds]
r26 = r26[:n_rounds]

save_path = save_dir / f"{METHOD_NAME}_{SCHEDULE_NAME}_forgetting_log.npz"

np.savez(
    save_path,
    method_name=np.array([METHOD_NAME]),
    schedule_name=np.array([SCHEDULE_NAME]),
    round_idx=round_idx,
    round_owner=owners,
    client_24_val_r2=r24,
    client_25_val_r2=r25,
    client_26_val_r2=r26,
    global_test_r2=global_r2,
    train_r2=train_r2,
    best_24=np.array([float(np.max(r24))], dtype=np.float32),
    final_24=np.array([float(r24[-1])], dtype=np.float32),
    forget_24=np.array([forgetting[2.4]], dtype=np.float32),
    best_25=np.array([float(np.max(r25))], dtype=np.float32),
    final_25=np.array([float(r25[-1])], dtype=np.float32),
    forget_25=np.array([forgetting[2.5]], dtype=np.float32),
    best_26=np.array([float(np.max(r26))], dtype=np.float32),
    final_26=np.array([float(r26[-1])], dtype=np.float32),
    forget_26=np.array([forgetting[2.6]], dtype=np.float32),
    avg_forgetting=np.array([avg_forgetting], dtype=np.float32),
)

print(f"Saved to: {save_path}")
# Out:
# ===== Forgetting Summary (per-client local val) =====
# client 2.4 GHz | best 0.956666 | final 0.955436 | forgetting 0.001230
# client 2.5 GHz | best 0.957946 | final 0.957242 | forgetting 0.000704
# client 2.6 GHz | best 0.946960 | final 0.946458 | forgetting 0.000503
# Average Forgetting: 0.000812
# Saved to: forgetting_logs\retrofl_continue_forgetting_log.npz
