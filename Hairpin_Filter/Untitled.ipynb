# %%
import pandas as pd
import numpy as np

# %%
AS_dataset = pd.read_csv('./hairpin_filter_dataset.csv', encoding='utf-8')

# %%
AS = AS_dataset[(AS_dataset['freq'] >= 2.0) & (AS_dataset['freq'] <= 6.0)]

# %%
np.sort(np.unique(AS['freq'].to_numpy())).shape
# Out:
# (41,)

# %%
AS_dataset.shape[0] / 90
# Out:
# 10000.0

# %%
np.sort(np.unique(AS_dataset['W1'].to_numpy())).shape
# Out:
# (9998,)

# %%
(2000.9529 - 200) / (2000 - 200)
# Out:
# 1.0005293888888889
