# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['font.sans-serif'] = ['Times New Roman']  # 中英文兼容

# %%
def plot_confusion_matrix(tp, tn, fp, fn, class_names=['Negative', 'Positive'], title='Confusion Matrix'):
    """
    绘制包含丰富信息的2x2混淆矩阵
    参数:
        tp: True Positive
        tn: True Negative
        fp: False Positive
        fn: False Negative
        class_names: 类别名称列表 [负类, 正类]
    """
    # 构建混淆矩阵
    cm = np.array([[tn, fp],
                   [fn, tp]])
    
    # 计算总体样本数
    total = tn + fp + fn + tp
    
    # 计算各项指标
    accuracy = (tp + tn) / total if total > 0 else 0
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    # 注释文本：数字 + 百分比
    annotations = [[f"{cm[i][j]}\n({cm[i][j]/total:.2%})" for j in range(2)] for i in range(2)]

    # 颜色映射
    cmap = sns.color_palette("Blues", as_cmap=True)

    # 绘制热力图
    plt.figure(figsize=(3, 3))
    sns.heatmap(cm, annot=np.array(annotations), fmt='', cmap=cmap,
                annot_kws={"size": 14}, cbar=False,
                xticklabels=class_names, yticklabels=class_names)

    plt.title(title, fontsize=14)
    plt.xlabel('Predicted', fontsize=14)
    plt.ylabel('Ground truth', fontsize=14)
    plt.xticks(rotation=0, fontsize=14)
    plt.yticks(rotation=90, fontsize=14)
    plt.tight_layout()
    # plt.show()
    plt.savefig(f"{title}.pdf", format="pdf", dpi=300, bbox_inches='tight')

# %%
# LP-8
title = 'Label poisoning (k=8)'
tp = 533
fn = 173
fp = 448
tn = 68270
class_names = ['Normal', 'Abnormal']

plot_confusion_matrix(tp, tn, fp, fn, class_names, title)

# %%
# LP-16
title = 'Label poisoning (k=16)'
tp = 609
fn = 40
fp = 437
tn = 68177
class_names = ['Normal', 'Abnormal']

plot_confusion_matrix(tp, tn, fp, fn, class_names, title)

# %%
# LP-32
title = 'Label poisoning (k=32)'
tp = 719
fn = 17
fp = 382
tn = 68285
class_names = ['Normal', 'Abnormal']

plot_confusion_matrix(tp, tn, fp, fn, class_names, title)

# %%
# FP-8
title = 'Feature poisoning (k=8)'
tp = 705
fn = 4
fp = 371
tn = 68172
class_names = ['Normal', 'Abnormal']

plot_confusion_matrix(tp, tn, fp, fn, class_names, title)

# %%
# FP-16
title = 'Feature poisoning (k=16)'
tp = 744
fn = 0
fp = 327
tn = 68348
class_names = ['Normal', 'Abnormal']

plot_confusion_matrix(tp, tn, fp, fn, class_names, title)

# %%
# FP-32
title = 'Feature poisoning (k=32)'
tp = 764
fn = 3
fp = 324
tn = 68217
class_names = ['Normal', 'Abnormal']

plot_confusion_matrix(tp, tn, fp, fn, class_names, title)
