# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import copy
import math
import random
import os

from collections import deque

# %%
ATTACK_START = False

# %%
ATTACK_TYPE = 'normal'
K_FACTOR = 0

# %%
checkpoint_path = f'./save-{ATTACK_TYPE}-{K_FACTOR}'

# %%
os.makedirs(checkpoint_path, exist_ok=True)

# %%
batch_size = 256
l_rate = 0.001

# %%
@tf.keras.utils.register_keras_serializable()
class MLP(tf.keras.Model):
    def __init__(self, trainable=True, dtype=None, **kwargs):
        super().__init__(trainable=trainable, dtype=dtype, **kwargs)
        self.dense1 = tf.keras.layers.Dense(units=512, activation=tf.nn.leaky_relu)
        self.dense2 = tf.keras.layers.Dense(units=1024, activation=tf.nn.leaky_relu)
        self.dense3 = tf.keras.layers.Dense(units=512, activation=tf.nn.leaky_relu)
        self.dense4 = tf.keras.layers.Dense(units=256, activation=tf.nn.leaky_relu)
        self.dense5 = tf.keras.layers.Dense(units=8)

    def get_config(self):
        config = super().get_config()
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        output = self.dense5(x)
        return output

# %%
class ParaServer:
    def __init__(self):
        self.model = MLP()
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=l_rate)
        self.freqs = {}
        test_dataset = pd.read_csv("Test.csv", encoding='utf-8').sample(frac=1).reset_index(drop=True)
        self.X_v_all = test_dataset.loc[:,'freq':'L4'].to_numpy(dtype = np.float32) 
        self.y_v_all = test_dataset.loc[:,'S11r':'S41i'].to_numpy(dtype = np.float32)

        test_dataset_24 = test_dataset[test_dataset['freq'] == 2.4]
        test_dataset_25 = test_dataset[test_dataset['freq'] == 2.5]
        test_dataset_26 = test_dataset[test_dataset['freq'] == 2.6]
        self.X_v = {}
        self.y_v = {}
        self.X_v[2.4] = test_dataset_24.loc[:,'freq':'L4'].to_numpy(dtype = np.float32)
        self.y_v[2.4] = test_dataset_24.loc[:,'S11r':'S41i'].to_numpy(dtype = np.float32)
        self.X_v[2.5] = test_dataset_25.loc[:,'freq':'L4'].to_numpy(dtype = np.float32)
        self.y_v[2.5] = test_dataset_25.loc[:,'S11r':'S41i'].to_numpy(dtype = np.float32)
        self.X_v[2.6] = test_dataset_26.loc[:,'freq':'L4'].to_numpy(dtype = np.float32)
        self.y_v[2.6] = test_dataset_26.loc[:,'S11r':'S41i'].to_numpy(dtype = np.float32)
        
        self.r2sv = []
        self.model(self.X_v_all)

        self.node_mse_his = {}
        self.node_grad_norm_his = {}


        self.node_A = {2.4: 0, 2.5: 0, 2.6: 0}
        self.node_D = {2.4: 0, 2.5: 0, 2.6: 0}
        
        self.Dic_A = {2.4: 'A', 2.5: 'B', 2.6: 'C'}
        self.Dic_D = {2.4: 'a', 2.5: 'b', 2.6: 'c'}

        self.TP = 0
        self.TN = 0
        self.FP = 0
        self.FN = 0

    def upload(self, grads, freq, GROUNDTRUTH):
        global ATTACK_START
        checkpoint = tf.train.Checkpoint(model=self.model, optimizer=self.optimizer)
        save_path = checkpoint.save(checkpoint_path)

        # 更新
        self.optimizer.apply_gradients(grads_and_vars=zip(grads, self.model.variables))

        after_y_v = self.model(self.X_v_all)
        after_mse = tf.reduce_mean(tf.square(after_y_v - self.y_v_all))

        poision_judge = self.check_anoymous(after_mse, grads, freq)

        if GROUNDTRUTH:
            ATTACK_START = True
            checkpoint.restore(save_path)
        if ATTACK_START:
            if GROUNDTRUTH:
                if poision_judge:
                    self.TP += 1
                    self.node_D[freq] += 1
                else:
                    self.FN += 1
                    self.node_A[freq] += 1
            else:
                if poision_judge:
                    self.FP += 1
                    self.node_D[freq] += 1
                else:
                    self.TN += 1
                    self.node_A[freq] += 1
                
        cur_y_v = self.model(self.X_v[freq])
        score = 1 - tf.reduce_sum(tf.square(cur_y_v - self.y_v[freq])) / tf.reduce_sum(tf.square(self.y_v[freq] - tf.reduce_mean(self.y_v[freq])))

        self.freqs[freq] = max(0, score)

        return self.model, self.freqs
    
    def download(self):
        return self.model, self.freqs

    def lr_decay(self, ratio):
        self.optimizer.learning_rate = self.optimizer.learning_rate * ratio

    def check_anoymous(self, cur_mse, cur_grad, nodeId):
        # 检查MSE异常
        if nodeId not in self.node_mse_his:
            self.node_mse_his[nodeId] = deque(maxlen=16)
        if len(self.node_mse_his[nodeId]) < 16:
            is_mse_anomaly = False
        else:
            mse_mean = np.mean(self.node_mse_his[nodeId])
            mse_std = np.std(self.node_mse_his[nodeId])
            mse_threshold = mse_mean + 3 * mse_std
            is_mse_anomaly = cur_mse > mse_threshold
        

        # 检查梯度异常
        grad_vector = tf.concat([tf.reshape(g, [-1]) for g in cur_grad], axis=0)
        grad_norm = np.linalg.norm(grad_vector)
        if nodeId not in self.node_grad_norm_his:
            self.node_grad_norm_his[nodeId] = deque(maxlen=16)

        if len(self.node_grad_norm_his[nodeId]) < 16:
            is_grad_anomaly = False
        else:
            grad_mean = np.mean(self.node_grad_norm_his[nodeId])
            grad_std = np.std(self.node_grad_norm_his[nodeId])
            grad_threshold = grad_mean + 3 * grad_std
            is_grad_anomaly = grad_norm > grad_threshold

        if is_mse_anomaly and is_grad_anomaly:
            return True
        else:
            self.node_mse_his[nodeId].append(cur_mse)
            self.node_grad_norm_his[nodeId].append(grad_norm)
            return False

# %%
r2s = {2.4:[],2.5:[],2.6:[]}

# %%
ps = ParaServer()

# %%
class Node:
    def __init__(self, dsName, freq):
        self.freq = freq
        self.otfreqs = {}
        self.model = MLP()
        self.zeroModel = MLP()
        self.dataset = pd.read_csv(dsName, encoding='utf-8').sample(frac=1).reset_index(drop=True)
        self.X = self.dataset.loc[:,'freq':'L4'].to_numpy(dtype = np.float32)
        self.y = self.dataset.loc[:,'S11r':'S41i'].to_numpy(dtype = np.float32)
        self.dataset_train = tf.data.Dataset.from_tensor_slices((self.X, self.y))
        self.dataset_train = self.dataset_train.shuffle(buffer_size=self.X.shape[0])
        self.dataset_train = self.dataset_train.batch(batch_size)
        self.dataset_train = self.dataset_train.prefetch(tf.data.experimental.AUTOTUNE)
        self.iterator = iter(self.dataset_train)

        self.current_epoch = 0
        self.epoch_r2 = []
        self.epoch_mse = []
        self.epoch_rmse = []
        self.epoch_mae = []
        self.batch_count = 0

    def getZero(self):
        m, freqs = ps.download()
        self.otfreqs = copy.deepcopy(freqs)
        self.zeroModel = copy.deepcopy(m)
        # print(self.otfreqs)
    def train(self, index_round):
        poisioning = False
        if False:
            poisioning = True
            # print('*',end="")
            poisoned_indices = np.random.choice(len(self.X), size=batch_size, replace=False)
            posionedX = self.X[poisoned_indices].copy()
            posionedY = self.y[poisoned_indices].copy()
            if ATTACK_TYPE == 'label':
                epsilon = np.random.normal(0, np.std(posionedY, 0) * K_FACTOR, posionedY.shape)
                posionedY += epsilon
            elif ATTACK_TYPE == 'feature':
                epsilon = np.random.normal(0, np.std(posionedX[:,1:], 0) * K_FACTOR, posionedX[:,1:].shape)
                posionedX[:,1:] += epsilon
            X, y = tf.convert_to_tensor(posionedX, dtype=tf.float32), tf.convert_to_tensor(posionedY, dtype=tf.float32)
        else:
            # print('-', end="")
            try:
                X, y = next(self.iterator)
                    
            except StopIteration:
                avg_r2 = np.mean(self.epoch_r2)
                avg_mse = np.mean(self.epoch_mse)
                avg_mae = np.mean(self.epoch_mae)
                avg_rmse = np.mean(self.epoch_rmse)
                print(f"\nNode {self.freq} Epoch {self.current_epoch} Summary:")
                print(f"  MSE: {avg_mse:.4f} | RMSE: {avg_rmse:.4f}")
                print(f"  MAE: {avg_mae:.4f} | R²: {avg_r2:.4f}")
                print(f"  Anomaly Detection: {ps.node_A[self.freq]}/{ps.node_D[self.freq]}")
                print(f"  {ps.TP} | {ps.FN}")
                print(f"  {ps.FP} | {ps.TN}")
                r2s[self.freq].append(avg_r2)
                ps.node_A[self.freq], ps.node_D[self.freq] = 0, 0

                self.epoch_r2 = []
                self.epoch_mse = []
                self.epoch_mae = []
                self.epoch_rmse = []
                self.current_epoch += 1
                self.batch_count = 0

                self.dataset_train = tf.data.Dataset.from_tensor_slices((self.X, self.y))
                self.dataset_train = self.dataset_train.shuffle(buffer_size=self.X.shape[0])
                self.dataset_train = self.dataset_train.batch(batch_size)
                self.dataset_train = self.dataset_train.prefetch(tf.data.experimental.AUTOTUNE)
                self.iterator = iter(self.dataset_train)
                X, y = next(self.iterator)

        self.model, _ = ps.download()

        with tf.GradientTape() as tape:
            y_pred = self.model(X)
            tr_mse = tf.reduce_mean(tf.square(y_pred - y))

        tr_rmse = tf.sqrt(tr_mse)
        tr_mae = tf.reduce_mean(tf.abs(y_pred - y))
        tr_r2 = 1 - tf.reduce_sum(tf.square(y_pred - y)) / tf.reduce_sum(tf.square(y - tf.reduce_mean(y)))

        grads = tape.gradient(tr_mse, self.model.variables)

        sum_r2 = 1
        for k, v in self.otfreqs.items():
            if math.isclose(k, self.freq) or math.isclose(v, 0):
                continue
            X_i = tf.tensor_scatter_nd_update(X, [[i, 0] for i in range(X.shape[0])], [k] * X.shape[0])
            y_i = self.zeroModel(X_i)
            with tf.GradientTape() as tape:
                y_pred_i = self.model(X_i)
                loss = tf.reduce_mean(tf.square(y_pred_i - y_i))
            grad = tape.gradient(loss, self.model.variables)
            grads = [grads[i] + grad[i] * v for i in range(len(grads))]
            sum_r2 += v
        self.model, _ = ps.upload([i / sum_r2 for i in grads], self.freq, poisioning)

        # if epoch_index in np.arange(0, num_epochs, 25).tolist() or epoch_index == num_epochs - 1:
        self.epoch_r2.append(tr_r2)
        self.epoch_mse.append(tr_mse)
        self.epoch_mae.append(tr_mae)
        self.epoch_rmse.append(tr_rmse)

# %%
nodeList = [Node('./24Train.csv', 2.4), Node('./25Train.csv', 2.5), Node('./26Train.csv', 2.6)]

# %%
turn = [np.array([[26, 104], [178, 312], [344, 464], [520, 600]]) * 112,
        np.array([[0, 94], [149, 223], [319, 433], [464, 580]]) * 112,
        np.array([[32, 151], [155, 248], [270, 354], [378, 502]]) * 112]

# %%
orders = [0, 1, 2]

for i in range(600 * 112):
    if i % 112 == 0:
        print(f"EPOCH: {i // 112}")
    random.shuffle(orders)
    for j in orders:
        for l, r in turn[j]:
            if l <= i < r:
                if math.isclose(l, i):
                    nodeList[j].getZero()
                nodeList[j].train(i)
    # valiAll(i)
    if i in [100 * 112, 200 * 112, 300 * 112, 400 * 112, 500 * 112]:
        ps.lr_decay(0.7)
# Out:
# EPOCH: 0
# EPOCH: 1
#
# Node 2.5 Epoch 0 Summary:
#   MSE: 2.5253 | RMSE: 0.7066
#   MAE: 0.5565 | R²: -20.0173
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 2
#
# Node 2.5 Epoch 1 Summary:
#   MSE: 0.0878 | RMSE: 0.2962
#   MAE: 0.2412 | R²: 0.2720
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 3
#
# Node 2.5 Epoch 2 Summary:
#   MSE: 0.0854 | RMSE: 0.2922
#   MAE: 0.2371 | R²: 0.2914
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 4
#
# Node 2.5 Epoch 3 Summary:
#   MSE: 0.0828 | RMSE: 0.2876
#   MAE: 0.2327 | R²: 0.3133
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 5
#
# Node 2.5 Epoch 4 Summary:
#   MSE: 0.0814 | RMSE: 0.2851
#   MAE: 0.2301 | R²: 0.3251
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 6
#
# Node 2.5 Epoch 5 Summary:
#   MSE: 0.0790 | RMSE: 0.2810
#   MAE: 0.2264 | R²: 0.3443
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 7
#
# Node 2.5 Epoch 6 Summary:
#   MSE: 0.0752 | RMSE: 0.2741
#   MAE: 0.2206 | R²: 0.3765
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 8
#
# Node 2.5 Epoch 7 Summary:
#   MSE: 0.0761 | RMSE: 0.2757
#   MAE: 0.2218 | R²: 0.3687
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 9
#
# Node 2.5 Epoch 8 Summary:
#   MSE: 0.0719 | RMSE: 0.2681
#   MAE: 0.2155 | R²: 0.4033
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 10
#
# Node 2.5 Epoch 9 Summary:
#   MSE: 0.0690 | RMSE: 0.2627
#   MAE: 0.2108 | R²: 0.4275
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 11
#
# Node 2.5 Epoch 10 Summary:
#   MSE: 0.0690 | RMSE: 0.2625
#   MAE: 0.2106 | R²: 0.4280
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 12
#
# Node 2.5 Epoch 11 Summary:
#   MSE: 0.0667 | RMSE: 0.2583
#   MAE: 0.2069 | R²: 0.4463
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 13
#
# Node 2.5 Epoch 12 Summary:
#   MSE: 0.0649 | RMSE: 0.2546
#   MAE: 0.2039 | R²: 0.4618
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 14
#
# Node 2.5 Epoch 13 Summary:
#   MSE: 0.0632 | RMSE: 0.2514
#   MAE: 0.2011 | R²: 0.4755
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 15
#
# Node 2.5 Epoch 14 Summary:
#   MSE: 0.0602 | RMSE: 0.2453
#   MAE: 0.1959 | R²: 0.5008
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 16
#
# Node 2.5 Epoch 15 Summary:
#   MSE: 0.0604 | RMSE: 0.2456
#   MAE: 0.1959 | R²: 0.4992
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 17
#
# Node 2.5 Epoch 16 Summary:
#   MSE: 0.0586 | RMSE: 0.2420
#   MAE: 0.1929 | R²: 0.5139
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 18
#
# Node 2.5 Epoch 17 Summary:
#   MSE: 0.0571 | RMSE: 0.2388
#   MAE: 0.1902 | R²: 0.5265
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 19
#
# Node 2.5 Epoch 18 Summary:
#   MSE: 0.0559 | RMSE: 0.2364
#   MAE: 0.1879 | R²: 0.5362
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 20
#
# Node 2.5 Epoch 19 Summary:
#   MSE: 0.0534 | RMSE: 0.2310
#   MAE: 0.1835 | R²: 0.5572
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 21
#
# Node 2.5 Epoch 20 Summary:
#   MSE: 0.0519 | RMSE: 0.2277
#   MAE: 0.1805 | R²: 0.5698
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 22
#
# Node 2.5 Epoch 21 Summary:
#   MSE: 0.0501 | RMSE: 0.2237
#   MAE: 0.1772 | R²: 0.5847
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 23
#
# Node 2.5 Epoch 22 Summary:
#   MSE: 0.0470 | RMSE: 0.2167
#   MAE: 0.1714 | R²: 0.6101
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 24
#
# Node 2.5 Epoch 23 Summary:
#   MSE: 0.0441 | RMSE: 0.2099
#   MAE: 0.1653 | R²: 0.6342
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 25
#
# Node 2.5 Epoch 24 Summary:
#   MSE: 0.0417 | RMSE: 0.2040
#   MAE: 0.1602 | R²: 0.6542
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 26
#
# Node 2.5 Epoch 25 Summary:
#   MSE: 0.0403 | RMSE: 0.2008
#   MAE: 0.1570 | R²: 0.6654
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 27
#
# Node 2.5 Epoch 26 Summary:
#   MSE: 0.0441 | RMSE: 0.2095
#   MAE: 0.1649 | R²: 0.6344
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 0 Summary:
#   MSE: 0.0492 | RMSE: 0.2213
#   MAE: 0.1753 | R²: 0.5932
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 28
#
# Node 2.4 Epoch 1 Summary:
#   MSE: 0.0464 | RMSE: 0.2150
#   MAE: 0.1701 | R²: 0.6159
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 27 Summary:
#   MSE: 0.0408 | RMSE: 0.2017
#   MAE: 0.1583 | R²: 0.6617
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 29
#
# Node 2.4 Epoch 2 Summary:
#   MSE: 0.0436 | RMSE: 0.2084
#   MAE: 0.1648 | R²: 0.6389
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 28 Summary:
#   MSE: 0.0376 | RMSE: 0.1936
#   MAE: 0.1514 | R²: 0.6882
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 30
#
# Node 2.4 Epoch 3 Summary:
#   MSE: 0.0430 | RMSE: 0.2069
#   MAE: 0.1635 | R²: 0.6444
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 29 Summary:
#   MSE: 0.0366 | RMSE: 0.1911
#   MAE: 0.1492 | R²: 0.6963
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 31
#
# Node 2.5 Epoch 30 Summary:
#   MSE: 0.0362 | RMSE: 0.1899
#   MAE: 0.1480 | R²: 0.7001
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 4 Summary:
#   MSE: 0.0428 | RMSE: 0.2064
#   MAE: 0.1632 | R²: 0.6462
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 32
#
# Node 2.5 Epoch 31 Summary:
#   MSE: 0.0357 | RMSE: 0.1886
#   MAE: 0.1468 | R²: 0.7040
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 5 Summary:
#   MSE: 0.0420 | RMSE: 0.2046
#   MAE: 0.1619 | R²: 0.6521
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 33
#
# Node 2.5 Epoch 32 Summary:
#   MSE: 0.0359 | RMSE: 0.1892
#   MAE: 0.1476 | R²: 0.7023
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 0 Summary:
#   MSE: 0.0551 | RMSE: 0.2336
#   MAE: 0.1854 | R²: 0.5425
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 6 Summary:
#   MSE: 0.0489 | RMSE: 0.2203
#   MAE: 0.1750 | R²: 0.5957
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 34
#
# Node 2.5 Epoch 33 Summary:
#   MSE: 0.0352 | RMSE: 0.1875
#   MAE: 0.1462 | R²: 0.7079
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 7 Summary:
#   MSE: 0.0481 | RMSE: 0.2188
#   MAE: 0.1738 | R²: 0.6016
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 1 Summary:
#   MSE: 0.0530 | RMSE: 0.2293
#   MAE: 0.1817 | R²: 0.5601
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 35
#
# Node 2.5 Epoch 34 Summary:
#   MSE: 0.0339 | RMSE: 0.1839
#   MAE: 0.1431 | R²: 0.7190
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 8 Summary:
#   MSE: 0.0468 | RMSE: 0.2156
#   MAE: 0.1712 | R²: 0.6130
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 2 Summary:
#   MSE: 0.0528 | RMSE: 0.2291
#   MAE: 0.1818 | R²: 0.5611
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 36
#
# Node 2.6 Epoch 3 Summary:
#   MSE: 0.0521 | RMSE: 0.2276
#   MAE: 0.1803 | R²: 0.5668
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 9 Summary:
#   MSE: 0.0473 | RMSE: 0.2169
#   MAE: 0.1722 | R²: 0.6084
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 35 Summary:
#   MSE: 0.0327 | RMSE: 0.1807
#   MAE: 0.1403 | R²: 0.7286
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 37
#
# Node 2.5 Epoch 36 Summary:
#   MSE: 0.0324 | RMSE: 0.1799
#   MAE: 0.1395 | R²: 0.7313
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 4 Summary:
#   MSE: 0.0520 | RMSE: 0.2271
#   MAE: 0.1799 | R²: 0.5682
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 10 Summary:
#   MSE: 0.0467 | RMSE: 0.2153
#   MAE: 0.1709 | R²: 0.6139
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 38
#
# Node 2.5 Epoch 37 Summary:
#   MSE: 0.0321 | RMSE: 0.1789
#   MAE: 0.1390 | R²: 0.7339
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 11 Summary:
#   MSE: 0.0461 | RMSE: 0.2139
#   MAE: 0.1698 | R²: 0.6187
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 5 Summary:
#   MSE: 0.0519 | RMSE: 0.2268
#   MAE: 0.1796 | R²: 0.5689
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 39
#
# Node 2.4 Epoch 12 Summary:
#   MSE: 0.0456 | RMSE: 0.2129
#   MAE: 0.1690 | R²: 0.6229
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 38 Summary:
#   MSE: 0.0307 | RMSE: 0.1751
#   MAE: 0.1356 | R²: 0.7452
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 6 Summary:
#   MSE: 0.0503 | RMSE: 0.2236
#   MAE: 0.1773 | R²: 0.5821
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 40
#
# Node 2.6 Epoch 7 Summary:
#   MSE: 0.0515 | RMSE: 0.2260
#   MAE: 0.1792 | R²: 0.5724
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 39 Summary:
#   MSE: 0.0307 | RMSE: 0.1752
#   MAE: 0.1357 | R²: 0.7450
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 13 Summary:
#   MSE: 0.0458 | RMSE: 0.2132
#   MAE: 0.1692 | R²: 0.6213
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 41
#
# Node 2.6 Epoch 8 Summary:
#   MSE: 0.0503 | RMSE: 0.2234
#   MAE: 0.1771 | R²: 0.5825
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 40 Summary:
#   MSE: 0.0297 | RMSE: 0.1723
#   MAE: 0.1333 | R²: 0.7534
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 14 Summary:
#   MSE: 0.0442 | RMSE: 0.2095
#   MAE: 0.1662 | R²: 0.6345
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 42
#
# Node 2.6 Epoch 9 Summary:
#   MSE: 0.0502 | RMSE: 0.2231
#   MAE: 0.1770 | R²: 0.5828
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 15 Summary:
#   MSE: 0.0440 | RMSE: 0.2090
#   MAE: 0.1658 | R²: 0.6356
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 41 Summary:
#   MSE: 0.0301 | RMSE: 0.1733
#   MAE: 0.1341 | R²: 0.7503
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 43
#
# Node 2.6 Epoch 10 Summary:
#   MSE: 0.0493 | RMSE: 0.2213
#   MAE: 0.1755 | R²: 0.5900
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 16 Summary:
#   MSE: 0.0439 | RMSE: 0.2091
#   MAE: 0.1660 | R²: 0.6366
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 42 Summary:
#   MSE: 0.0283 | RMSE: 0.1680
#   MAE: 0.1297 | R²: 0.7656
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 44
#
# Node 2.5 Epoch 43 Summary:
#   MSE: 0.0291 | RMSE: 0.1704
#   MAE: 0.1318 | R²: 0.7587
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 11 Summary:
#   MSE: 0.0493 | RMSE: 0.2210
#   MAE: 0.1750 | R²: 0.5905
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 17 Summary:
#   MSE: 0.0439 | RMSE: 0.2085
#   MAE: 0.1653 | R²: 0.6370
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 45
#
# Node 2.5 Epoch 44 Summary:
#   MSE: 0.0275 | RMSE: 0.1656
#   MAE: 0.1278 | R²: 0.7722
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 18 Summary:
#   MSE: 0.0432 | RMSE: 0.2068
#   MAE: 0.1641 | R²: 0.6428
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 12 Summary:
#   MSE: 0.0484 | RMSE: 0.2190
#   MAE: 0.1735 | R²: 0.5981
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 46
#
# Node 2.4 Epoch 19 Summary:
#   MSE: 0.0430 | RMSE: 0.2066
#   MAE: 0.1638 | R²: 0.6444
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 45 Summary:
#   MSE: 0.0272 | RMSE: 0.1647
#   MAE: 0.1270 | R²: 0.7746
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 13 Summary:
#   MSE: 0.0491 | RMSE: 0.2208
#   MAE: 0.1752 | R²: 0.5919
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 47
#
# Node 2.6 Epoch 14 Summary:
#   MSE: 0.0484 | RMSE: 0.2192
#   MAE: 0.1738 | R²: 0.5982
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 20 Summary:
#   MSE: 0.0426 | RMSE: 0.2058
#   MAE: 0.1633 | R²: 0.6478
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 46 Summary:
#   MSE: 0.0264 | RMSE: 0.1622
#   MAE: 0.1249 | R²: 0.7814
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 48
#
# Node 2.5 Epoch 47 Summary:
#   MSE: 0.0268 | RMSE: 0.1635
#   MAE: 0.1262 | R²: 0.7777
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 21 Summary:
#   MSE: 0.0427 | RMSE: 0.2057
#   MAE: 0.1632 | R²: 0.6468
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 15 Summary:
#   MSE: 0.0483 | RMSE: 0.2189
#   MAE: 0.1735 | R²: 0.5988
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 49
#
# Node 2.4 Epoch 22 Summary:
#   MSE: 0.0420 | RMSE: 0.2043
#   MAE: 0.1619 | R²: 0.6522
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 16 Summary:
#   MSE: 0.0480 | RMSE: 0.2182
#   MAE: 0.1729 | R²: 0.6008
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 48 Summary:
#   MSE: 0.0267 | RMSE: 0.1632
#   MAE: 0.1259 | R²: 0.7788
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 50
#
# Node 2.5 Epoch 49 Summary:
#   MSE: 0.0257 | RMSE: 0.1602
#   MAE: 0.1233 | R²: 0.7869
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 23 Summary:
#   MSE: 0.0409 | RMSE: 0.2015
#   MAE: 0.1597 | R²: 0.6616
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 17 Summary:
#   MSE: 0.0477 | RMSE: 0.2175
#   MAE: 0.1723 | R²: 0.6035
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 51
#
# Node 2.5 Epoch 50 Summary:
#   MSE: 0.0251 | RMSE: 0.1584
#   MAE: 0.1219 | R²: 0.7916
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 18 Summary:
#   MSE: 0.0471 | RMSE: 0.2164
#   MAE: 0.1714 | R²: 0.6083
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 24 Summary:
#   MSE: 0.0417 | RMSE: 0.2035
#   MAE: 0.1614 | R²: 0.6550
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 52
#
# Node 2.4 Epoch 25 Summary:
#   MSE: 0.0413 | RMSE: 0.2027
#   MAE: 0.1608 | R²: 0.6581
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 51 Summary:
#   MSE: 0.0252 | RMSE: 0.1586
#   MAE: 0.1220 | R²: 0.7910
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 19 Summary:
#   MSE: 0.0466 | RMSE: 0.2152
#   MAE: 0.1706 | R²: 0.6127
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 53
#
# Node 2.4 Epoch 26 Summary:
#   MSE: 0.0407 | RMSE: 0.2012
#   MAE: 0.1595 | R²: 0.6632
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 20 Summary:
#   MSE: 0.0474 | RMSE: 0.2170
#   MAE: 0.1721 | R²: 0.6064
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 52 Summary:
#   MSE: 0.0241 | RMSE: 0.1552
#   MAE: 0.1192 | R²: 0.8000
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 54
#
# Node 2.6 Epoch 21 Summary:
#   MSE: 0.0466 | RMSE: 0.2150
#   MAE: 0.1705 | R²: 0.6129
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 27 Summary:
#   MSE: 0.0408 | RMSE: 0.2012
#   MAE: 0.1595 | R²: 0.6626
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 53 Summary:
#   MSE: 0.0243 | RMSE: 0.1559
#   MAE: 0.1197 | R²: 0.7982
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 55
#
# Node 2.6 Epoch 22 Summary:
#   MSE: 0.0460 | RMSE: 0.2137
#   MAE: 0.1693 | R²: 0.6179
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 54 Summary:
#   MSE: 0.0241 | RMSE: 0.1550
#   MAE: 0.1190 | R²: 0.8003
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 28 Summary:
#   MSE: 0.0408 | RMSE: 0.2013
#   MAE: 0.1595 | R²: 0.6627
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 56
#
# Node 2.4 Epoch 29 Summary:
#   MSE: 0.0403 | RMSE: 0.2001
#   MAE: 0.1586 | R²: 0.6664
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 23 Summary:
#   MSE: 0.0465 | RMSE: 0.2149
#   MAE: 0.1704 | R²: 0.6133
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 55 Summary:
#   MSE: 0.0238 | RMSE: 0.1542
#   MAE: 0.1184 | R²: 0.8024
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 57
#
# Node 2.6 Epoch 24 Summary:
#   MSE: 0.0458 | RMSE: 0.2134
#   MAE: 0.1691 | R²: 0.6193
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 56 Summary:
#   MSE: 0.0236 | RMSE: 0.1534
#   MAE: 0.1177 | R²: 0.8047
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 30 Summary:
#   MSE: 0.0398 | RMSE: 0.1989
#   MAE: 0.1576 | R²: 0.6704
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 58
#
# Node 2.5 Epoch 57 Summary:
#   MSE: 0.0236 | RMSE: 0.1535
#   MAE: 0.1179 | R²: 0.8042
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 31 Summary:
#   MSE: 0.0399 | RMSE: 0.1991
#   MAE: 0.1577 | R²: 0.6700
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 25 Summary:
#   MSE: 0.0457 | RMSE: 0.2131
#   MAE: 0.1689 | R²: 0.6201
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 59
#
# Node 2.6 Epoch 26 Summary:
#   MSE: 0.0456 | RMSE: 0.2129
#   MAE: 0.1688 | R²: 0.6210
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 32 Summary:
#   MSE: 0.0398 | RMSE: 0.1988
#   MAE: 0.1575 | R²: 0.6707
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 58 Summary:
#   MSE: 0.0235 | RMSE: 0.1532
#   MAE: 0.1176 | R²: 0.8050
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 60
#
# Node 2.6 Epoch 27 Summary:
#   MSE: 0.0448 | RMSE: 0.2109
#   MAE: 0.1670 | R²: 0.6280
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 33 Summary:
#   MSE: 0.0391 | RMSE: 0.1971
#   MAE: 0.1560 | R²: 0.6763
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 59 Summary:
#   MSE: 0.0228 | RMSE: 0.1508
#   MAE: 0.1156 | R²: 0.8112
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 61
#
# Node 2.4 Epoch 34 Summary:
#   MSE: 0.0395 | RMSE: 0.1980
#   MAE: 0.1569 | R²: 0.6735
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 28 Summary:
#   MSE: 0.0453 | RMSE: 0.2121
#   MAE: 0.1680 | R²: 0.6234
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 60 Summary:
#   MSE: 0.0231 | RMSE: 0.1518
#   MAE: 0.1164 | R²: 0.8084
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 62
#
# Node 2.4 Epoch 35 Summary:
#   MSE: 0.0392 | RMSE: 0.1974
#   MAE: 0.1564 | R²: 0.6754
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 29 Summary:
#   MSE: 0.0451 | RMSE: 0.2117
#   MAE: 0.1678 | R²: 0.6256
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 61 Summary:
#   MSE: 0.0228 | RMSE: 0.1509
#   MAE: 0.1155 | R²: 0.8108
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 63
#
# Node 2.5 Epoch 62 Summary:
#   MSE: 0.0224 | RMSE: 0.1495
#   MAE: 0.1145 | R²: 0.8143
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 36 Summary:
#   MSE: 0.0385 | RMSE: 0.1955
#   MAE: 0.1548 | R²: 0.6815
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 30 Summary:
#   MSE: 0.0448 | RMSE: 0.2108
#   MAE: 0.1670 | R²: 0.6282
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 64
#
# Node 2.4 Epoch 37 Summary:
#   MSE: 0.0380 | RMSE: 0.1944
#   MAE: 0.1537 | R²: 0.6854
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 63 Summary:
#   MSE: 0.0219 | RMSE: 0.1478
#   MAE: 0.1130 | R²: 0.8184
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 31 Summary:
#   MSE: 0.0446 | RMSE: 0.2106
#   MAE: 0.1669 | R²: 0.6295
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 65
#
# Node 2.4 Epoch 38 Summary:
#   MSE: 0.0389 | RMSE: 0.1966
#   MAE: 0.1557 | R²: 0.6783
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 32 Summary:
#   MSE: 0.0454 | RMSE: 0.2124
#   MAE: 0.1684 | R²: 0.6231
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 64 Summary:
#   MSE: 0.0220 | RMSE: 0.1482
#   MAE: 0.1134 | R²: 0.8175
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 66
#
# Node 2.6 Epoch 33 Summary:
#   MSE: 0.0439 | RMSE: 0.2090
#   MAE: 0.1654 | R²: 0.6351
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 39 Summary:
#   MSE: 0.0381 | RMSE: 0.1948
#   MAE: 0.1541 | R²: 0.6845
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 65 Summary:
#   MSE: 0.0216 | RMSE: 0.1467
#   MAE: 0.1121 | R²: 0.8211
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 67
#
# Node 2.4 Epoch 40 Summary:
#   MSE: 0.0376 | RMSE: 0.1933
#   MAE: 0.1530 | R²: 0.6890
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 34 Summary:
#   MSE: 0.0440 | RMSE: 0.2092
#   MAE: 0.1656 | R²: 0.6346
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 66 Summary:
#   MSE: 0.0212 | RMSE: 0.1456
#   MAE: 0.1112 | R²: 0.8239
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 68
#
# Node 2.6 Epoch 35 Summary:
#   MSE: 0.0437 | RMSE: 0.2085
#   MAE: 0.1651 | R²: 0.6369
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 41 Summary:
#   MSE: 0.0381 | RMSE: 0.1945
#   MAE: 0.1539 | R²: 0.6851
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 67 Summary:
#   MSE: 0.0211 | RMSE: 0.1452
#   MAE: 0.1109 | R²: 0.8249
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 69
#
# Node 2.5 Epoch 68 Summary:
#   MSE: 0.0209 | RMSE: 0.1444
#   MAE: 0.1102 | R²: 0.8268
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 42 Summary:
#   MSE: 0.0380 | RMSE: 0.1946
#   MAE: 0.1540 | R²: 0.6853
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 36 Summary:
#   MSE: 0.0436 | RMSE: 0.2083
#   MAE: 0.1649 | R²: 0.6379
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 70
#
# Node 2.4 Epoch 43 Summary:
#   MSE: 0.0376 | RMSE: 0.1934
#   MAE: 0.1529 | R²: 0.6890
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 69 Summary:
#   MSE: 0.0207 | RMSE: 0.1438
#   MAE: 0.1098 | R²: 0.8283
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 37 Summary:
#   MSE: 0.0435 | RMSE: 0.2080
#   MAE: 0.1646 | R²: 0.6387
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 71
#
# Node 2.5 Epoch 70 Summary:
#   MSE: 0.0212 | RMSE: 0.1454
#   MAE: 0.1109 | R²: 0.8244
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 44 Summary:
#   MSE: 0.0380 | RMSE: 0.1943
#   MAE: 0.1538 | R²: 0.6853
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 38 Summary:
#   MSE: 0.0440 | RMSE: 0.2092
#   MAE: 0.1656 | R²: 0.6341
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 72
#
# Node 2.4 Epoch 45 Summary:
#   MSE: 0.0373 | RMSE: 0.1926
#   MAE: 0.1522 | R²: 0.6911
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 71 Summary:
#   MSE: 0.0208 | RMSE: 0.1443
#   MAE: 0.1103 | R²: 0.8271
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 39 Summary:
#   MSE: 0.0429 | RMSE: 0.2064
#   MAE: 0.1632 | R²: 0.6435
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 73
#
# Node 2.4 Epoch 46 Summary:
#   MSE: 0.0376 | RMSE: 0.1933
#   MAE: 0.1530 | R²: 0.6889
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 72 Summary:
#   MSE: 0.0207 | RMSE: 0.1438
#   MAE: 0.1097 | R²: 0.8283
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 40 Summary:
#   MSE: 0.0432 | RMSE: 0.2072
#   MAE: 0.1639 | R²: 0.6409
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 74
#
# Node 2.5 Epoch 73 Summary:
#   MSE: 0.0203 | RMSE: 0.1424
#   MAE: 0.1084 | R²: 0.8316
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 41 Summary:
#   MSE: 0.0430 | RMSE: 0.2068
#   MAE: 0.1635 | R²: 0.6425
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 47 Summary:
#   MSE: 0.0372 | RMSE: 0.1923
#   MAE: 0.1521 | R²: 0.6920
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 75
#
# Node 2.5 Epoch 74 Summary:
#   MSE: 0.0199 | RMSE: 0.1411
#   MAE: 0.1075 | R²: 0.8346
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 42 Summary:
#   MSE: 0.0425 | RMSE: 0.2055
#   MAE: 0.1626 | R²: 0.6472
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 48 Summary:
#   MSE: 0.0373 | RMSE: 0.1925
#   MAE: 0.1523 | R²: 0.6917
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 76
#
# Node 2.6 Epoch 43 Summary:
#   MSE: 0.0422 | RMSE: 0.2048
#   MAE: 0.1620 | R²: 0.6494
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 75 Summary:
#   MSE: 0.0200 | RMSE: 0.1413
#   MAE: 0.1077 | R²: 0.8341
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 49 Summary:
#   MSE: 0.0367 | RMSE: 0.1911
#   MAE: 0.1511 | R²: 0.6965
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 77
#
# Node 2.4 Epoch 50 Summary:
#   MSE: 0.0363 | RMSE: 0.1899
#   MAE: 0.1500 | R²: 0.7000
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 76 Summary:
#   MSE: 0.0200 | RMSE: 0.1414
#   MAE: 0.1078 | R²: 0.8339
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 44 Summary:
#   MSE: 0.0422 | RMSE: 0.2048
#   MAE: 0.1619 | R²: 0.6496
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 78
#
# Node 2.5 Epoch 77 Summary:
#   MSE: 0.0200 | RMSE: 0.1413
#   MAE: 0.1076 | R²: 0.8341
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 45 Summary:
#   MSE: 0.0423 | RMSE: 0.2051
#   MAE: 0.1621 | R²: 0.6485
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 51 Summary:
#   MSE: 0.0368 | RMSE: 0.1911
#   MAE: 0.1510 | R²: 0.6959
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 79
#
# Node 2.4 Epoch 52 Summary:
#   MSE: 0.0365 | RMSE: 0.1903
#   MAE: 0.1504 | R²: 0.6982
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 46 Summary:
#   MSE: 0.0420 | RMSE: 0.2041
#   MAE: 0.1614 | R²: 0.6512
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 78 Summary:
#   MSE: 0.0198 | RMSE: 0.1407
#   MAE: 0.1072 | R²: 0.8354
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 80
#
# Node 2.4 Epoch 53 Summary:
#   MSE: 0.0364 | RMSE: 0.1901
#   MAE: 0.1501 | R²: 0.6992
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 79 Summary:
#   MSE: 0.0197 | RMSE: 0.1403
#   MAE: 0.1069 | R²: 0.8365
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 47 Summary:
#   MSE: 0.0418 | RMSE: 0.2039
#   MAE: 0.1611 | R²: 0.6526
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 81
#
# Node 2.4 Epoch 54 Summary:
#   MSE: 0.0361 | RMSE: 0.1894
#   MAE: 0.1497 | R²: 0.7012
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 48 Summary:
#   MSE: 0.0419 | RMSE: 0.2041
#   MAE: 0.1611 | R²: 0.6520
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 80 Summary:
#   MSE: 0.0195 | RMSE: 0.1394
#   MAE: 0.1060 | R²: 0.8385
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 82
#
# Node 2.5 Epoch 81 Summary:
#   MSE: 0.0194 | RMSE: 0.1392
#   MAE: 0.1059 | R²: 0.8389
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 55 Summary:
#   MSE: 0.0362 | RMSE: 0.1897
#   MAE: 0.1499 | R²: 0.7004
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 49 Summary:
#   MSE: 0.0412 | RMSE: 0.2023
#   MAE: 0.1596 | R²: 0.6580
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 83
#
# Node 2.5 Epoch 82 Summary:
#   MSE: 0.0190 | RMSE: 0.1378
#   MAE: 0.1047 | R²: 0.8423
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 56 Summary:
#   MSE: 0.0362 | RMSE: 0.1896
#   MAE: 0.1499 | R²: 0.7005
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 50 Summary:
#   MSE: 0.0414 | RMSE: 0.2028
#   MAE: 0.1602 | R²: 0.6563
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 84
#
# Node 2.6 Epoch 51 Summary:
#   MSE: 0.0413 | RMSE: 0.2025
#   MAE: 0.1600 | R²: 0.6569
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 57 Summary:
#   MSE: 0.0359 | RMSE: 0.1890
#   MAE: 0.1493 | R²: 0.7027
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 83 Summary:
#   MSE: 0.0193 | RMSE: 0.1390
#   MAE: 0.1057 | R²: 0.8396
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 85
#
# Node 2.5 Epoch 84 Summary:
#   MSE: 0.0191 | RMSE: 0.1382
#   MAE: 0.1051 | R²: 0.8413
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 52 Summary:
#   MSE: 0.0411 | RMSE: 0.2020
#   MAE: 0.1594 | R²: 0.6585
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 58 Summary:
#   MSE: 0.0359 | RMSE: 0.1888
#   MAE: 0.1491 | R²: 0.7034
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 86
#
# Node 2.6 Epoch 53 Summary:
#   MSE: 0.0410 | RMSE: 0.2017
#   MAE: 0.1593 | R²: 0.6597
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 59 Summary:
#   MSE: 0.0360 | RMSE: 0.1890
#   MAE: 0.1493 | R²: 0.7024
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 85 Summary:
#   MSE: 0.0189 | RMSE: 0.1373
#   MAE: 0.1043 | R²: 0.8435
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 87
#
# Node 2.5 Epoch 86 Summary:
#   MSE: 0.0190 | RMSE: 0.1378
#   MAE: 0.1048 | R²: 0.8421
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 60 Summary:
#   MSE: 0.0358 | RMSE: 0.1887
#   MAE: 0.1491 | R²: 0.7036
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 54 Summary:
#   MSE: 0.0412 | RMSE: 0.2021
#   MAE: 0.1594 | R²: 0.6580
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 88
#
# Node 2.6 Epoch 55 Summary:
#   MSE: 0.0405 | RMSE: 0.2007
#   MAE: 0.1583 | R²: 0.6634
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 61 Summary:
#   MSE: 0.0345 | RMSE: 0.1851
#   MAE: 0.1460 | R²: 0.7146
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 87 Summary:
#   MSE: 0.0189 | RMSE: 0.1373
#   MAE: 0.1043 | R²: 0.8434
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 89
#
# Node 2.4 Epoch 62 Summary:
#   MSE: 0.0347 | RMSE: 0.1859
#   MAE: 0.1466 | R²: 0.7126
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 88 Summary:
#   MSE: 0.0183 | RMSE: 0.1352
#   MAE: 0.1025 | R²: 0.8481
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 56 Summary:
#   MSE: 0.0403 | RMSE: 0.2001
#   MAE: 0.1578 | R²: 0.6656
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 90
#
# Node 2.5 Epoch 89 Summary:
#   MSE: 0.0183 | RMSE: 0.1351
#   MAE: 0.1025 | R²: 0.8483
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 63 Summary:
#   MSE: 0.0347 | RMSE: 0.1856
#   MAE: 0.1465 | R²: 0.7131
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 57 Summary:
#   MSE: 0.0401 | RMSE: 0.1997
#   MAE: 0.1575 | R²: 0.6668
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 91
#
# Node 2.5 Epoch 90 Summary:
#   MSE: 0.0188 | RMSE: 0.1368
#   MAE: 0.1040 | R²: 0.8444
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 64 Summary:
#   MSE: 0.0348 | RMSE: 0.1858
#   MAE: 0.1466 | R²: 0.7120
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 58 Summary:
#   MSE: 0.0398 | RMSE: 0.1988
#   MAE: 0.1567 | R²: 0.6694
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 92
#
# Node 2.4 Epoch 65 Summary:
#   MSE: 0.0347 | RMSE: 0.1856
#   MAE: 0.1465 | R²: 0.7126
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 59 Summary:
#   MSE: 0.0398 | RMSE: 0.1988
#   MAE: 0.1566 | R²: 0.6692
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 91 Summary:
#   MSE: 0.0184 | RMSE: 0.1357
#   MAE: 0.1030 | R²: 0.8471
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 93
#
# Node 2.5 Epoch 92 Summary:
#   MSE: 0.0188 | RMSE: 0.1371
#   MAE: 0.1043 | R²: 0.8437
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 60 Summary:
#   MSE: 0.0400 | RMSE: 0.1990
#   MAE: 0.1568 | R²: 0.6679
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 66 Summary:
#   MSE: 0.0353 | RMSE: 0.1872
#   MAE: 0.1477 | R²: 0.7076
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 94
#
# Node 2.4 Epoch 67 Summary:
#   MSE: 0.0345 | RMSE: 0.1850
#   MAE: 0.1459 | R²: 0.7149
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 61 Summary:
#   MSE: 0.0398 | RMSE: 0.1989
#   MAE: 0.1567 | R²: 0.6692
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 95
#
# Node 2.6 Epoch 62 Summary:
#   MSE: 0.0397 | RMSE: 0.1988
#   MAE: 0.1566 | R²: 0.6704
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 68 Summary:
#   MSE: 0.0325 | RMSE: 0.1800
#   MAE: 0.1415 | R²: 0.7312
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 96
#
# Node 2.6 Epoch 63 Summary:
#   MSE: 0.0392 | RMSE: 0.1977
#   MAE: 0.1555 | R²: 0.6745
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 69 Summary:
#   MSE: 0.0322 | RMSE: 0.1790
#   MAE: 0.1408 | R²: 0.7340
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 97
#
# Node 2.4 Epoch 70 Summary:
#   MSE: 0.0320 | RMSE: 0.1787
#   MAE: 0.1404 | R²: 0.7349
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 64 Summary:
#   MSE: 0.0390 | RMSE: 0.1970
#   MAE: 0.1549 | R²: 0.6764
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 98
#
# Node 2.4 Epoch 71 Summary:
#   MSE: 0.0320 | RMSE: 0.1784
#   MAE: 0.1401 | R²: 0.7352
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 65 Summary:
#   MSE: 0.0386 | RMSE: 0.1960
#   MAE: 0.1539 | R²: 0.6791
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 99
#
# Node 2.6 Epoch 66 Summary:
#   MSE: 0.0384 | RMSE: 0.1955
#   MAE: 0.1534 | R²: 0.6811
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 72 Summary:
#   MSE: 0.0318 | RMSE: 0.1779
#   MAE: 0.1396 | R²: 0.7367
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 100
#
# Node 2.6 Epoch 67 Summary:
#   MSE: 0.0387 | RMSE: 0.1963
#   MAE: 0.1542 | R²: 0.6783
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 73 Summary:
#   MSE: 0.0320 | RMSE: 0.1784
#   MAE: 0.1401 | R²: 0.7355
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 101
#
# Node 2.6 Epoch 68 Summary:
#   MSE: 0.0355 | RMSE: 0.1882
#   MAE: 0.1470 | R²: 0.7047
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 74 Summary:
#   MSE: 0.0295 | RMSE: 0.1714
#   MAE: 0.1339 | R²: 0.7559
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 102
#
# Node 2.6 Epoch 69 Summary:
#   MSE: 0.0353 | RMSE: 0.1873
#   MAE: 0.1462 | R²: 0.7070
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 75 Summary:
#   MSE: 0.0294 | RMSE: 0.1709
#   MAE: 0.1335 | R²: 0.7568
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 103
#
# Node 2.4 Epoch 76 Summary:
#   MSE: 0.0292 | RMSE: 0.1700
#   MAE: 0.1327 | R²: 0.7588
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 70 Summary:
#   MSE: 0.0349 | RMSE: 0.1861
#   MAE: 0.1451 | R²: 0.7103
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 104
#
# Node 2.6 Epoch 71 Summary:
#   MSE: 0.0336 | RMSE: 0.1827
#   MAE: 0.1420 | R²: 0.7206
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 105
#
# Node 2.6 Epoch 72 Summary:
#   MSE: 0.0210 | RMSE: 0.1447
#   MAE: 0.1091 | R²: 0.8253
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 106
#
# Node 2.6 Epoch 73 Summary:
#   MSE: 0.0179 | RMSE: 0.1337
#   MAE: 0.1001 | R²: 0.8509
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 107
#
# Node 2.6 Epoch 74 Summary:
#   MSE: 0.0174 | RMSE: 0.1312
#   MAE: 0.0983 | R²: 0.8558
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 108
#
# Node 2.6 Epoch 75 Summary:
#   MSE: 0.0161 | RMSE: 0.1262
#   MAE: 0.0945 | R²: 0.8666
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 109
#
# Node 2.6 Epoch 76 Summary:
#   MSE: 0.0162 | RMSE: 0.1264
#   MAE: 0.0949 | R²: 0.8654
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 110
#
# Node 2.6 Epoch 77 Summary:
#   MSE: 0.0164 | RMSE: 0.1264
#   MAE: 0.0949 | R²: 0.8639
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 111
#
# Node 2.6 Epoch 78 Summary:
#   MSE: 0.0143 | RMSE: 0.1189
#   MAE: 0.0891 | R²: 0.8815
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 112
#
# Node 2.6 Epoch 79 Summary:
#   MSE: 0.0146 | RMSE: 0.1201
#   MAE: 0.0903 | R²: 0.8784
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 113
#
# Node 2.6 Epoch 80 Summary:
#   MSE: 0.0134 | RMSE: 0.1151
#   MAE: 0.0863 | R²: 0.8886
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 114
#
# Node 2.6 Epoch 81 Summary:
#   MSE: 0.0123 | RMSE: 0.1105
#   MAE: 0.0828 | R²: 0.8977
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 115
#
# Node 2.6 Epoch 82 Summary:
#   MSE: 0.0127 | RMSE: 0.1121
#   MAE: 0.0841 | R²: 0.8941
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 116
#
# Node 2.6 Epoch 83 Summary:
#   MSE: 0.0121 | RMSE: 0.1092
#   MAE: 0.0820 | R²: 0.8993
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 117
#
# Node 2.6 Epoch 84 Summary:
#   MSE: 0.0122 | RMSE: 0.1095
#   MAE: 0.0821 | R²: 0.8989
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 118
#
# Node 2.6 Epoch 85 Summary:
#   MSE: 0.0109 | RMSE: 0.1040
#   MAE: 0.0781 | R²: 0.9091
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 119
#
# Node 2.6 Epoch 86 Summary:
#   MSE: 0.0107 | RMSE: 0.1029
#   MAE: 0.0773 | R²: 0.9107
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 120
#
# Node 2.6 Epoch 87 Summary:
#   MSE: 0.0103 | RMSE: 0.1008
#   MAE: 0.0756 | R²: 0.9145
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 121
#
# Node 2.6 Epoch 88 Summary:
#   MSE: 0.0128 | RMSE: 0.1103
#   MAE: 0.0833 | R²: 0.8939
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 122
#
# Node 2.6 Epoch 89 Summary:
#   MSE: 0.0099 | RMSE: 0.0989
#   MAE: 0.0742 | R²: 0.9179
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 123
#
# Node 2.6 Epoch 90 Summary:
#   MSE: 0.0092 | RMSE: 0.0956
#   MAE: 0.0718 | R²: 0.9232
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 124
#
# Node 2.6 Epoch 91 Summary:
#   MSE: 0.0093 | RMSE: 0.0960
#   MAE: 0.0721 | R²: 0.9223
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 125
#
# Node 2.6 Epoch 92 Summary:
#   MSE: 0.0086 | RMSE: 0.0924
#   MAE: 0.0693 | R²: 0.9286
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 126
#
# Node 2.6 Epoch 93 Summary:
#   MSE: 0.0105 | RMSE: 0.0980
#   MAE: 0.0739 | R²: 0.9127
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 127
#
# Node 2.6 Epoch 94 Summary:
#   MSE: 0.0301 | RMSE: 0.1674
#   MAE: 0.1290 | R²: 0.7497
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 128
#
# Node 2.6 Epoch 95 Summary:
#   MSE: 0.0108 | RMSE: 0.1034
#   MAE: 0.0775 | R²: 0.9100
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 129
#
# Node 2.6 Epoch 96 Summary:
#   MSE: 0.0095 | RMSE: 0.0967
#   MAE: 0.0724 | R²: 0.9212
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 130
#
# Node 2.6 Epoch 97 Summary:
#   MSE: 0.0099 | RMSE: 0.0977
#   MAE: 0.0733 | R²: 0.9174
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 131
#
# Node 2.6 Epoch 98 Summary:
#   MSE: 0.0078 | RMSE: 0.0881
#   MAE: 0.0659 | R²: 0.9352
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 132
#
# Node 2.6 Epoch 99 Summary:
#   MSE: 0.0073 | RMSE: 0.0851
#   MAE: 0.0637 | R²: 0.9395
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 133
#
# Node 2.6 Epoch 100 Summary:
#   MSE: 0.0089 | RMSE: 0.0924
#   MAE: 0.0696 | R²: 0.9263
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 134
#
# Node 2.6 Epoch 101 Summary:
#   MSE: 0.0085 | RMSE: 0.0912
#   MAE: 0.0686 | R²: 0.9290
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 135
#
# Node 2.6 Epoch 102 Summary:
#   MSE: 0.0069 | RMSE: 0.0828
#   MAE: 0.0621 | R²: 0.9427
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 136
#
# Node 2.6 Epoch 103 Summary:
#   MSE: 0.0096 | RMSE: 0.0966
#   MAE: 0.0726 | R²: 0.9198
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 137
#
# Node 2.6 Epoch 104 Summary:
#   MSE: 0.0065 | RMSE: 0.0806
#   MAE: 0.0605 | R²: 0.9458
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 138
#
# Node 2.6 Epoch 105 Summary:
#   MSE: 0.0076 | RMSE: 0.0863
#   MAE: 0.0649 | R²: 0.9372
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 139
#
# Node 2.6 Epoch 106 Summary:
#   MSE: 0.0086 | RMSE: 0.0911
#   MAE: 0.0687 | R²: 0.9282
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 140
#
# Node 2.6 Epoch 107 Summary:
#   MSE: 0.0061 | RMSE: 0.0780
#   MAE: 0.0587 | R²: 0.9493
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 141
#
# Node 2.6 Epoch 108 Summary:
#   MSE: 0.0167 | RMSE: 0.1201
#   MAE: 0.0917 | R²: 0.8612
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 142
#
# Node 2.6 Epoch 109 Summary:
#   MSE: 0.0086 | RMSE: 0.0914
#   MAE: 0.0688 | R²: 0.9288
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 143
#
# Node 2.6 Epoch 110 Summary:
#   MSE: 0.0058 | RMSE: 0.0761
#   MAE: 0.0572 | R²: 0.9518
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 144
#
# Node 2.6 Epoch 111 Summary:
#   MSE: 0.0079 | RMSE: 0.0875
#   MAE: 0.0657 | R²: 0.9345
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 145
#
# Node 2.6 Epoch 112 Summary:
#   MSE: 0.0077 | RMSE: 0.0852
#   MAE: 0.0642 | R²: 0.9361
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 146
#
# Node 2.6 Epoch 113 Summary:
#   MSE: 0.0072 | RMSE: 0.0842
#   MAE: 0.0632 | R²: 0.9404
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 147
#
# Node 2.6 Epoch 114 Summary:
#   MSE: 0.0068 | RMSE: 0.0818
#   MAE: 0.0615 | R²: 0.9434
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 148
#
# Node 2.6 Epoch 115 Summary:
#   MSE: 0.0063 | RMSE: 0.0782
#   MAE: 0.0589 | R²: 0.9474
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 149
#
# Node 2.5 Epoch 93 Summary:
#   MSE: 0.0181 | RMSE: 0.1344
#   MAE: 0.1020 | R²: 0.8501
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 116 Summary:
#   MSE: 0.0072 | RMSE: 0.0841
#   MAE: 0.0633 | R²: 0.9399
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 150
#
# Node 2.5 Epoch 94 Summary:
#   MSE: 0.0228 | RMSE: 0.1507
#   MAE: 0.1142 | R²: 0.8109
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 117 Summary:
#   MSE: 0.0098 | RMSE: 0.0976
#   MAE: 0.0741 | R²: 0.9183
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 151
#
# Node 2.5 Epoch 95 Summary:
#   MSE: 0.0201 | RMSE: 0.1415
#   MAE: 0.1068 | R²: 0.8335
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 152
#
# Node 2.5 Epoch 96 Summary:
#   MSE: 0.0122 | RMSE: 0.1100
#   MAE: 0.0815 | R²: 0.8991
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 153
#
# Node 2.5 Epoch 97 Summary:
#   MSE: 0.0105 | RMSE: 0.1022
#   MAE: 0.0754 | R²: 0.9129
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 154
#
# Node 2.5 Epoch 98 Summary:
#   MSE: 0.0098 | RMSE: 0.0986
#   MAE: 0.0727 | R²: 0.9191
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 155
#
# Node 2.6 Epoch 118 Summary:
#   MSE: 0.0085 | RMSE: 0.0912
#   MAE: 0.0689 | R²: 0.9292
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 99 Summary:
#   MSE: 0.0092 | RMSE: 0.0958
#   MAE: 0.0706 | R²: 0.9235
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 156
#
# Node 2.5 Epoch 100 Summary:
#   MSE: 0.0106 | RMSE: 0.1026
#   MAE: 0.0761 | R²: 0.9122
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 119 Summary:
#   MSE: 0.0080 | RMSE: 0.0892
#   MAE: 0.0669 | R²: 0.9332
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 157
#
# Node 2.5 Epoch 101 Summary:
#   MSE: 0.0105 | RMSE: 0.1020
#   MAE: 0.0756 | R²: 0.9132
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 120 Summary:
#   MSE: 0.0079 | RMSE: 0.0882
#   MAE: 0.0661 | R²: 0.9345
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 158
#
# Node 2.6 Epoch 121 Summary:
#   MSE: 0.0069 | RMSE: 0.0830
#   MAE: 0.0623 | R²: 0.9423
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 102 Summary:
#   MSE: 0.0098 | RMSE: 0.0988
#   MAE: 0.0733 | R²: 0.9186
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 159
#
# Node 2.6 Epoch 122 Summary:
#   MSE: 0.0067 | RMSE: 0.0813
#   MAE: 0.0609 | R²: 0.9445
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 103 Summary:
#   MSE: 0.0094 | RMSE: 0.0964
#   MAE: 0.0714 | R²: 0.9224
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 160
#
# Node 2.5 Epoch 104 Summary:
#   MSE: 0.0098 | RMSE: 0.0987
#   MAE: 0.0733 | R²: 0.9184
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 123 Summary:
#   MSE: 0.0074 | RMSE: 0.0851
#   MAE: 0.0640 | R²: 0.9386
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 161
#
# Node 2.5 Epoch 105 Summary:
#   MSE: 0.0091 | RMSE: 0.0949
#   MAE: 0.0702 | R²: 0.9246
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 124 Summary:
#   MSE: 0.0066 | RMSE: 0.0810
#   MAE: 0.0607 | R²: 0.9449
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 162
#
# Node 2.6 Epoch 125 Summary:
#   MSE: 0.0065 | RMSE: 0.0797
#   MAE: 0.0599 | R²: 0.9463
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 106 Summary:
#   MSE: 0.0091 | RMSE: 0.0948
#   MAE: 0.0702 | R²: 0.9246
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 163
#
# Node 2.5 Epoch 107 Summary:
#   MSE: 0.0091 | RMSE: 0.0949
#   MAE: 0.0704 | R²: 0.9244
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 126 Summary:
#   MSE: 0.0072 | RMSE: 0.0830
#   MAE: 0.0625 | R²: 0.9406
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 164
#
# Node 2.6 Epoch 127 Summary:
#   MSE: 0.0073 | RMSE: 0.0839
#   MAE: 0.0629 | R²: 0.9397
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 108 Summary:
#   MSE: 0.0095 | RMSE: 0.0971
#   MAE: 0.0720 | R²: 0.9208
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 165
#
# Node 2.5 Epoch 109 Summary:
#   MSE: 0.0084 | RMSE: 0.0916
#   MAE: 0.0678 | R²: 0.9301
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 128 Summary:
#   MSE: 0.0064 | RMSE: 0.0794
#   MAE: 0.0596 | R²: 0.9465
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 166
#
# Node 2.5 Epoch 110 Summary:
#   MSE: 0.0083 | RMSE: 0.0905
#   MAE: 0.0669 | R²: 0.9313
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 129 Summary:
#   MSE: 0.0060 | RMSE: 0.0768
#   MAE: 0.0575 | R²: 0.9503
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 167
#
# Node 2.6 Epoch 130 Summary:
#   MSE: 0.0098 | RMSE: 0.0950
#   MAE: 0.0716 | R²: 0.9183
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 111 Summary:
#   MSE: 0.0112 | RMSE: 0.1035
#   MAE: 0.0774 | R²: 0.9075
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 168
#
# Node 2.5 Epoch 112 Summary:
#   MSE: 0.0083 | RMSE: 0.0906
#   MAE: 0.0671 | R²: 0.9308
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 131 Summary:
#   MSE: 0.0061 | RMSE: 0.0772
#   MAE: 0.0578 | R²: 0.9495
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 169
#
# Node 2.6 Epoch 132 Summary:
#   MSE: 0.0058 | RMSE: 0.0761
#   MAE: 0.0569 | R²: 0.9516
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 113 Summary:
#   MSE: 0.0082 | RMSE: 0.0902
#   MAE: 0.0667 | R²: 0.9321
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 170
#
# Node 2.5 Epoch 114 Summary:
#   MSE: 0.0089 | RMSE: 0.0936
#   MAE: 0.0694 | R²: 0.9258
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 133 Summary:
#   MSE: 0.0073 | RMSE: 0.0829
#   MAE: 0.0623 | R²: 0.9397
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 171
#
# Node 2.5 Epoch 115 Summary:
#   MSE: 0.0094 | RMSE: 0.0963
#   MAE: 0.0713 | R²: 0.9221
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 134 Summary:
#   MSE: 0.0075 | RMSE: 0.0851
#   MAE: 0.0637 | R²: 0.9378
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 172
#
# Node 2.5 Epoch 116 Summary:
#   MSE: 0.0076 | RMSE: 0.0870
#   MAE: 0.0642 | R²: 0.9366
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 135 Summary:
#   MSE: 0.0056 | RMSE: 0.0742
#   MAE: 0.0554 | R²: 0.9538
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 173
#
# Node 2.5 Epoch 117 Summary:
#   MSE: 0.0083 | RMSE: 0.0903
#   MAE: 0.0669 | R²: 0.9312
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 136 Summary:
#   MSE: 0.0064 | RMSE: 0.0786
#   MAE: 0.0590 | R²: 0.9466
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 174
#
# Node 2.6 Epoch 137 Summary:
#   MSE: 0.0064 | RMSE: 0.0794
#   MAE: 0.0595 | R²: 0.9465
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 118 Summary:
#   MSE: 0.0086 | RMSE: 0.0921
#   MAE: 0.0683 | R²: 0.9284
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 175
#
# Node 2.5 Epoch 119 Summary:
#   MSE: 0.0085 | RMSE: 0.0912
#   MAE: 0.0674 | R²: 0.9298
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 138 Summary:
#   MSE: 0.0062 | RMSE: 0.0777
#   MAE: 0.0582 | R²: 0.9482
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 176
#
# Node 2.6 Epoch 139 Summary:
#   MSE: 0.0059 | RMSE: 0.0757
#   MAE: 0.0568 | R²: 0.9507
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 120 Summary:
#   MSE: 0.0078 | RMSE: 0.0878
#   MAE: 0.0650 | R²: 0.9354
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 177
#
# Node 2.6 Epoch 140 Summary:
#   MSE: 0.0075 | RMSE: 0.0830
#   MAE: 0.0623 | R²: 0.9381
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 121 Summary:
#   MSE: 0.0091 | RMSE: 0.0937
#   MAE: 0.0696 | R²: 0.9242
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 178
#
# Node 2.4 Epoch 77 Summary:
#   MSE: 0.0282 | RMSE: 0.1674
#   MAE: 0.1303 | R²: 0.7665
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 122 Summary:
#   MSE: 0.0077 | RMSE: 0.0872
#   MAE: 0.0647 | R²: 0.9359
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 141 Summary:
#   MSE: 0.0059 | RMSE: 0.0760
#   MAE: 0.0569 | R²: 0.9508
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 179
#
# Node 2.6 Epoch 142 Summary:
#   MSE: 0.0093 | RMSE: 0.0945
#   MAE: 0.0712 | R²: 0.9230
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 123 Summary:
#   MSE: 0.0098 | RMSE: 0.0980
#   MAE: 0.0733 | R²: 0.9186
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 78 Summary:
#   MSE: 0.0261 | RMSE: 0.1609
#   MAE: 0.1242 | R²: 0.7845
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 180
#
# Node 2.4 Epoch 79 Summary:
#   MSE: 0.0255 | RMSE: 0.1588
#   MAE: 0.1227 | R²: 0.7894
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 124 Summary:
#   MSE: 0.0111 | RMSE: 0.1035
#   MAE: 0.0776 | R²: 0.9081
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 143 Summary:
#   MSE: 0.0111 | RMSE: 0.1017
#   MAE: 0.0768 | R²: 0.9074
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 181
#
# Node 2.5 Epoch 125 Summary:
#   MSE: 0.0094 | RMSE: 0.0960
#   MAE: 0.0714 | R²: 0.9221
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 144 Summary:
#   MSE: 0.0081 | RMSE: 0.0886
#   MAE: 0.0665 | R²: 0.9323
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 80 Summary:
#   MSE: 0.0231 | RMSE: 0.1519
#   MAE: 0.1171 | R²: 0.8085
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 182
#
# Node 2.6 Epoch 145 Summary:
#   MSE: 0.0085 | RMSE: 0.0904
#   MAE: 0.0679 | R²: 0.9295
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 126 Summary:
#   MSE: 0.0092 | RMSE: 0.0955
#   MAE: 0.0711 | R²: 0.9235
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 81 Summary:
#   MSE: 0.0232 | RMSE: 0.1522
#   MAE: 0.1174 | R²: 0.8077
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 183
#
# Node 2.6 Epoch 146 Summary:
#   MSE: 0.0077 | RMSE: 0.0867
#   MAE: 0.0650 | R²: 0.9358
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 127 Summary:
#   MSE: 0.0090 | RMSE: 0.0942
#   MAE: 0.0700 | R²: 0.9253
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 82 Summary:
#   MSE: 0.0222 | RMSE: 0.1490
#   MAE: 0.1148 | R²: 0.8160
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 184
#
# Node 2.4 Epoch 83 Summary:
#   MSE: 0.0222 | RMSE: 0.1488
#   MAE: 0.1148 | R²: 0.8164
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 128 Summary:
#   MSE: 0.0087 | RMSE: 0.0925
#   MAE: 0.0686 | R²: 0.9282
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 147 Summary:
#   MSE: 0.0076 | RMSE: 0.0864
#   MAE: 0.0647 | R²: 0.9367
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 185
#
# Node 2.4 Epoch 84 Summary:
#   MSE: 0.0219 | RMSE: 0.1479
#   MAE: 0.1141 | R²: 0.8185
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.6 Epoch 148 Summary:
#   MSE: 0.0074 | RMSE: 0.0848
#   MAE: 0.0636 | R²: 0.9386
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 129 Summary:
#   MSE: 0.0086 | RMSE: 0.0923
#   MAE: 0.0686 | R²: 0.9283
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 186
#
# Node 2.6 Epoch 149 Summary:
#   MSE: 0.0080 | RMSE: 0.0879
#   MAE: 0.0661 | R²: 0.9335
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 85 Summary:
#   MSE: 0.0219 | RMSE: 0.1479
#   MAE: 0.1141 | R²: 0.8187
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 130 Summary:
#   MSE: 0.0090 | RMSE: 0.0941
#   MAE: 0.0699 | R²: 0.9256
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 187
#
# Node 2.4 Epoch 86 Summary:
#   MSE: 0.0234 | RMSE: 0.1522
#   MAE: 0.1176 | R²: 0.8065
#   Anomaly Detection: 0/0
# ...
#   MSE: 0.0016 | RMSE: 0.0404
#   MAE: 0.0302 | R²: 0.9865
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 530
#
# Node 2.4 Epoch 341 Summary:
#   MSE: 0.0016 | RMSE: 0.0400
#   MAE: 0.0299 | R²: 0.9867
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 347 Summary:
#   MSE: 0.0012 | RMSE: 0.0347
#   MAE: 0.0257 | R²: 0.9900
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 531
#
# Node 2.5 Epoch 348 Summary:
#   MSE: 0.0012 | RMSE: 0.0346
#   MAE: 0.0256 | R²: 0.9901
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 342 Summary:
#   MSE: 0.0016 | RMSE: 0.0397
#   MAE: 0.0297 | R²: 0.9869
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 532
#
# Node 2.4 Epoch 343 Summary:
#   MSE: 0.0016 | RMSE: 0.0395
#   MAE: 0.0296 | R²: 0.9871
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 349 Summary:
#   MSE: 0.0012 | RMSE: 0.0345
#   MAE: 0.0255 | R²: 0.9901
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 533
#
# Node 2.4 Epoch 344 Summary:
#   MSE: 0.0016 | RMSE: 0.0394
#   MAE: 0.0295 | R²: 0.9871
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 350 Summary:
#   MSE: 0.0012 | RMSE: 0.0345
#   MAE: 0.0256 | R²: 0.9901
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 534
#
# Node 2.5 Epoch 351 Summary:
#   MSE: 0.0012 | RMSE: 0.0351
#   MAE: 0.0259 | R²: 0.9897
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 345 Summary:
#   MSE: 0.0016 | RMSE: 0.0394
#   MAE: 0.0295 | R²: 0.9871
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 535
#
# Node 2.4 Epoch 346 Summary:
#   MSE: 0.0015 | RMSE: 0.0389
#   MAE: 0.0291 | R²: 0.9875
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 352 Summary:
#   MSE: 0.0012 | RMSE: 0.0341
#   MAE: 0.0252 | R²: 0.9903
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 536
#
# Node 2.5 Epoch 353 Summary:
#   MSE: 0.0012 | RMSE: 0.0342
#   MAE: 0.0253 | R²: 0.9903
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 347 Summary:
#   MSE: 0.0015 | RMSE: 0.0389
#   MAE: 0.0292 | R²: 0.9874
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 537
#
# Node 2.5 Epoch 354 Summary:
#   MSE: 0.0012 | RMSE: 0.0344
#   MAE: 0.0255 | R²: 0.9901
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 348 Summary:
#   MSE: 0.0015 | RMSE: 0.0390
#   MAE: 0.0293 | R²: 0.9874
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 538
#
# Node 2.5 Epoch 355 Summary:
#   MSE: 0.0012 | RMSE: 0.0342
#   MAE: 0.0253 | R²: 0.9903
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 349 Summary:
#   MSE: 0.0015 | RMSE: 0.0387
#   MAE: 0.0290 | R²: 0.9876
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 539
#
# Node 2.5 Epoch 356 Summary:
#   MSE: 0.0014 | RMSE: 0.0364
#   MAE: 0.0268 | R²: 0.9883
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 350 Summary:
#   MSE: 0.0016 | RMSE: 0.0396
#   MAE: 0.0297 | R²: 0.9868
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 540
#
# Node 2.4 Epoch 351 Summary:
#   MSE: 0.0018 | RMSE: 0.0417
#   MAE: 0.0312 | R²: 0.9847
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 357 Summary:
#   MSE: 0.0015 | RMSE: 0.0376
#   MAE: 0.0277 | R²: 0.9873
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 541
#
# Node 2.4 Epoch 352 Summary:
#   MSE: 0.0014 | RMSE: 0.0377
#   MAE: 0.0282 | R²: 0.9882
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 358 Summary:
#   MSE: 0.0011 | RMSE: 0.0331
#   MAE: 0.0245 | R²: 0.9909
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 542
#
# Node 2.5 Epoch 359 Summary:
#   MSE: 0.0011 | RMSE: 0.0330
#   MAE: 0.0244 | R²: 0.9910
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 353 Summary:
#   MSE: 0.0014 | RMSE: 0.0376
#   MAE: 0.0282 | R²: 0.9883
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 543
#
# Node 2.5 Epoch 360 Summary:
#   MSE: 0.0011 | RMSE: 0.0330
#   MAE: 0.0244 | R²: 0.9910
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 354 Summary:
#   MSE: 0.0014 | RMSE: 0.0375
#   MAE: 0.0281 | R²: 0.9883
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 544
#
# Node 2.5 Epoch 361 Summary:
#   MSE: 0.0011 | RMSE: 0.0331
#   MAE: 0.0245 | R²: 0.9909
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 355 Summary:
#   MSE: 0.0014 | RMSE: 0.0375
#   MAE: 0.0282 | R²: 0.9883
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 545
#
# Node 2.4 Epoch 356 Summary:
#   MSE: 0.0014 | RMSE: 0.0376
#   MAE: 0.0282 | R²: 0.9883
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 362 Summary:
#   MSE: 0.0011 | RMSE: 0.0331
#   MAE: 0.0245 | R²: 0.9909
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 546
#
# Node 2.5 Epoch 363 Summary:
#   MSE: 0.0011 | RMSE: 0.0332
#   MAE: 0.0246 | R²: 0.9908
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 357 Summary:
#   MSE: 0.0014 | RMSE: 0.0375
#   MAE: 0.0282 | R²: 0.9883
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 547
#
# Node 2.4 Epoch 358 Summary:
#   MSE: 0.0014 | RMSE: 0.0377
#   MAE: 0.0283 | R²: 0.9882
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 364 Summary:
#   MSE: 0.0011 | RMSE: 0.0333
#   MAE: 0.0247 | R²: 0.9908
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 548
#
# Node 2.5 Epoch 365 Summary:
#   MSE: 0.0011 | RMSE: 0.0331
#   MAE: 0.0246 | R²: 0.9909
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 359 Summary:
#   MSE: 0.0014 | RMSE: 0.0375
#   MAE: 0.0281 | R²: 0.9884
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 549
#
# Node 2.5 Epoch 366 Summary:
#   MSE: 0.0011 | RMSE: 0.0333
#   MAE: 0.0247 | R²: 0.9908
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 360 Summary:
#   MSE: 0.0014 | RMSE: 0.0376
#   MAE: 0.0282 | R²: 0.9883
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 550
#
# Node 2.5 Epoch 367 Summary:
#   MSE: 0.0011 | RMSE: 0.0333
#   MAE: 0.0247 | R²: 0.9908
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 361 Summary:
#   MSE: 0.0014 | RMSE: 0.0375
#   MAE: 0.0282 | R²: 0.9883
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 551
#
# Node 2.4 Epoch 362 Summary:
#   MSE: 0.0014 | RMSE: 0.0373
#   MAE: 0.0280 | R²: 0.9885
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 368 Summary:
#   MSE: 0.0011 | RMSE: 0.0332
#   MAE: 0.0247 | R²: 0.9908
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 552
#
# Node 2.5 Epoch 369 Summary:
#   MSE: 0.0011 | RMSE: 0.0333
#   MAE: 0.0247 | R²: 0.9908
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 363 Summary:
#   MSE: 0.0014 | RMSE: 0.0371
#   MAE: 0.0279 | R²: 0.9886
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 553
#
# Node 2.4 Epoch 364 Summary:
#   MSE: 0.0014 | RMSE: 0.0374
#   MAE: 0.0281 | R²: 0.9884
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 370 Summary:
#   MSE: 0.0011 | RMSE: 0.0334
#   MAE: 0.0247 | R²: 0.9907
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 554
#
# Node 2.5 Epoch 371 Summary:
#   MSE: 0.0011 | RMSE: 0.0335
#   MAE: 0.0248 | R²: 0.9907
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 365 Summary:
#   MSE: 0.0014 | RMSE: 0.0374
#   MAE: 0.0281 | R²: 0.9884
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 555
#
# Node 2.5 Epoch 372 Summary:
#   MSE: 0.0011 | RMSE: 0.0336
#   MAE: 0.0249 | R²: 0.9906
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 366 Summary:
#   MSE: 0.0014 | RMSE: 0.0373
#   MAE: 0.0280 | R²: 0.9884
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 556
#
# Node 2.5 Epoch 373 Summary:
#   MSE: 0.0011 | RMSE: 0.0337
#   MAE: 0.0249 | R²: 0.9906
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 367 Summary:
#   MSE: 0.0014 | RMSE: 0.0372
#   MAE: 0.0279 | R²: 0.9886
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 557
#
# Node 2.5 Epoch 374 Summary:
#   MSE: 0.0011 | RMSE: 0.0328
#   MAE: 0.0244 | R²: 0.9910
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 368 Summary:
#   MSE: 0.0014 | RMSE: 0.0368
#   MAE: 0.0276 | R²: 0.9888
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 558
#
# Node 2.4 Epoch 369 Summary:
#   MSE: 0.0014 | RMSE: 0.0369
#   MAE: 0.0278 | R²: 0.9887
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 375 Summary:
#   MSE: 0.0011 | RMSE: 0.0330
#   MAE: 0.0245 | R²: 0.9909
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 559
#
# Node 2.4 Epoch 370 Summary:
#   MSE: 0.0014 | RMSE: 0.0372
#   MAE: 0.0279 | R²: 0.9885
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 376 Summary:
#   MSE: 0.0011 | RMSE: 0.0336
#   MAE: 0.0249 | R²: 0.9906
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 560
#
# Node 2.5 Epoch 377 Summary:
#   MSE: 0.0011 | RMSE: 0.0330
#   MAE: 0.0245 | R²: 0.9909
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 371 Summary:
#   MSE: 0.0014 | RMSE: 0.0368
#   MAE: 0.0276 | R²: 0.9888
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 561
#
# Node 2.5 Epoch 378 Summary:
#   MSE: 0.0011 | RMSE: 0.0329
#   MAE: 0.0244 | R²: 0.9910
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 372 Summary:
#   MSE: 0.0014 | RMSE: 0.0368
#   MAE: 0.0276 | R²: 0.9888
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 562
#
# Node 2.5 Epoch 379 Summary:
#   MSE: 0.0012 | RMSE: 0.0342
#   MAE: 0.0253 | R²: 0.9902
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 373 Summary:
#   MSE: 0.0014 | RMSE: 0.0378
#   MAE: 0.0284 | R²: 0.9881
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 563
#
# Node 2.5 Epoch 380 Summary:
#   MSE: 0.0011 | RMSE: 0.0325
#   MAE: 0.0241 | R²: 0.9912
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 374 Summary:
#   MSE: 0.0013 | RMSE: 0.0362
#   MAE: 0.0272 | R²: 0.9891
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 564
#
# Node 2.4 Epoch 375 Summary:
#   MSE: 0.0013 | RMSE: 0.0364
#   MAE: 0.0274 | R²: 0.9890
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 381 Summary:
#   MSE: 0.0010 | RMSE: 0.0324
#   MAE: 0.0240 | R²: 0.9913
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 565
#
# Node 2.5 Epoch 382 Summary:
#   MSE: 0.0011 | RMSE: 0.0327
#   MAE: 0.0243 | R²: 0.9911
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 376 Summary:
#   MSE: 0.0013 | RMSE: 0.0365
#   MAE: 0.0275 | R²: 0.9889
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 566
#
# Node 2.5 Epoch 383 Summary:
#   MSE: 0.0011 | RMSE: 0.0326
#   MAE: 0.0242 | R²: 0.9911
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 377 Summary:
#   MSE: 0.0013 | RMSE: 0.0364
#   MAE: 0.0273 | R²: 0.9890
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 567
#
# Node 2.4 Epoch 378 Summary:
#   MSE: 0.0013 | RMSE: 0.0365
#   MAE: 0.0274 | R²: 0.9890
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 384 Summary:
#   MSE: 0.0011 | RMSE: 0.0329
#   MAE: 0.0244 | R²: 0.9910
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 568
#
# Node 2.5 Epoch 385 Summary:
#   MSE: 0.0011 | RMSE: 0.0324
#   MAE: 0.0240 | R²: 0.9913
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 379 Summary:
#   MSE: 0.0013 | RMSE: 0.0362
#   MAE: 0.0272 | R²: 0.9891
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 569
#
# Node 2.4 Epoch 380 Summary:
#   MSE: 0.0013 | RMSE: 0.0361
#   MAE: 0.0272 | R²: 0.9892
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 386 Summary:
#   MSE: 0.0011 | RMSE: 0.0325
#   MAE: 0.0241 | R²: 0.9912
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 570
#
# Node 2.4 Epoch 381 Summary:
#   MSE: 0.0013 | RMSE: 0.0362
#   MAE: 0.0273 | R²: 0.9891
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 387 Summary:
#   MSE: 0.0011 | RMSE: 0.0327
#   MAE: 0.0243 | R²: 0.9911
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 571
#
# Node 2.5 Epoch 388 Summary:
#   MSE: 0.0011 | RMSE: 0.0327
#   MAE: 0.0243 | R²: 0.9911
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 382 Summary:
#   MSE: 0.0013 | RMSE: 0.0363
#   MAE: 0.0273 | R²: 0.9891
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 572
#
# Node 2.4 Epoch 383 Summary:
#   MSE: 0.0013 | RMSE: 0.0360
#   MAE: 0.0271 | R²: 0.9893
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 389 Summary:
#   MSE: 0.0010 | RMSE: 0.0323
#   MAE: 0.0240 | R²: 0.9913
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 573
#
# Node 2.4 Epoch 384 Summary:
#   MSE: 0.0013 | RMSE: 0.0363
#   MAE: 0.0273 | R²: 0.9891
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 390 Summary:
#   MSE: 0.0011 | RMSE: 0.0327
#   MAE: 0.0243 | R²: 0.9911
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 574
#
# Node 2.5 Epoch 391 Summary:
#   MSE: 0.0011 | RMSE: 0.0330
#   MAE: 0.0245 | R²: 0.9909
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 385 Summary:
#   MSE: 0.0013 | RMSE: 0.0363
#   MAE: 0.0273 | R²: 0.9891
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 575
#
# Node 2.5 Epoch 392 Summary:
#   MSE: 0.0011 | RMSE: 0.0334
#   MAE: 0.0248 | R²: 0.9907
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 386 Summary:
#   MSE: 0.0013 | RMSE: 0.0365
#   MAE: 0.0274 | R²: 0.9889
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 576
#
# Node 2.5 Epoch 393 Summary:
#   MSE: 0.0010 | RMSE: 0.0319
#   MAE: 0.0237 | R²: 0.9916
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.4 Epoch 387 Summary:
#   MSE: 0.0013 | RMSE: 0.0356
#   MAE: 0.0268 | R²: 0.9895
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 577
#
# Node 2.4 Epoch 388 Summary:
#   MSE: 0.0013 | RMSE: 0.0356
#   MAE: 0.0268 | R²: 0.9895
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 394 Summary:
#   MSE: 0.0010 | RMSE: 0.0321
#   MAE: 0.0238 | R²: 0.9915
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 578
#
# Node 2.4 Epoch 389 Summary:
#   MSE: 0.0013 | RMSE: 0.0359
#   MAE: 0.0270 | R²: 0.9893
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 395 Summary:
#   MSE: 0.0010 | RMSE: 0.0323
#   MAE: 0.0240 | R²: 0.9913
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 579
#
# Node 2.4 Epoch 390 Summary:
#   MSE: 0.0013 | RMSE: 0.0357
#   MAE: 0.0269 | R²: 0.9894
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
#
# Node 2.5 Epoch 396 Summary:
#   MSE: 0.0010 | RMSE: 0.0320
#   MAE: 0.0238 | R²: 0.9915
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 580
#
# Node 2.4 Epoch 391 Summary:
#   MSE: 0.0013 | RMSE: 0.0357
#   MAE: 0.0269 | R²: 0.9894
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 581
#
# Node 2.4 Epoch 392 Summary:
#   MSE: 0.0011 | RMSE: 0.0330
#   MAE: 0.0248 | R²: 0.9910
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 582
#
# Node 2.4 Epoch 393 Summary:
#   MSE: 0.0010 | RMSE: 0.0318
#   MAE: 0.0240 | R²: 0.9916
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 583
#
# Node 2.4 Epoch 394 Summary:
#   MSE: 0.0010 | RMSE: 0.0315
#   MAE: 0.0238 | R²: 0.9918
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 584
#
# Node 2.4 Epoch 395 Summary:
#   MSE: 0.0010 | RMSE: 0.0314
#   MAE: 0.0238 | R²: 0.9918
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 585
#
# Node 2.4 Epoch 396 Summary:
#   MSE: 0.0010 | RMSE: 0.0309
#   MAE: 0.0234 | R²: 0.9921
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 586
#
# Node 2.4 Epoch 397 Summary:
#   MSE: 0.0009 | RMSE: 0.0307
#   MAE: 0.0232 | R²: 0.9922
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 587
#
# Node 2.4 Epoch 398 Summary:
#   MSE: 0.0009 | RMSE: 0.0305
#   MAE: 0.0232 | R²: 0.9923
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 588
#
# Node 2.4 Epoch 399 Summary:
#   MSE: 0.0010 | RMSE: 0.0320
#   MAE: 0.0242 | R²: 0.9915
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 589
#
# Node 2.4 Epoch 400 Summary:
#   MSE: 0.0009 | RMSE: 0.0301
#   MAE: 0.0229 | R²: 0.9925
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 590
#
# Node 2.4 Epoch 401 Summary:
#   MSE: 0.0009 | RMSE: 0.0300
#   MAE: 0.0228 | R²: 0.9926
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 591
#
# Node 2.4 Epoch 402 Summary:
#   MSE: 0.0009 | RMSE: 0.0297
#   MAE: 0.0226 | R²: 0.9927
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 592
#
# Node 2.4 Epoch 403 Summary:
#   MSE: 0.0009 | RMSE: 0.0295
#   MAE: 0.0225 | R²: 0.9928
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 593
#
# Node 2.4 Epoch 404 Summary:
#   MSE: 0.0009 | RMSE: 0.0296
#   MAE: 0.0226 | R²: 0.9927
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 594
#
# Node 2.4 Epoch 405 Summary:
#   MSE: 0.0009 | RMSE: 0.0294
#   MAE: 0.0224 | R²: 0.9928
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 595
#
# Node 2.4 Epoch 406 Summary:
#   MSE: 0.0009 | RMSE: 0.0293
#   MAE: 0.0224 | R²: 0.9929
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 596
#
# Node 2.4 Epoch 407 Summary:
#   MSE: 0.0009 | RMSE: 0.0296
#   MAE: 0.0226 | R²: 0.9927
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 597
#
# Node 2.4 Epoch 408 Summary:
#   MSE: 0.0009 | RMSE: 0.0298
#   MAE: 0.0227 | R²: 0.9927
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 598
#
# Node 2.4 Epoch 409 Summary:
#   MSE: 0.0009 | RMSE: 0.0299
#   MAE: 0.0228 | R²: 0.9926
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0
# EPOCH: 599
#
# Node 2.4 Epoch 410 Summary:
#   MSE: 0.0008 | RMSE: 0.0285
#   MAE: 0.0218 | R²: 0.9933
#   Anomaly Detection: 0/0
#   0 | 0
#   0 | 0

# %%
print(f"  {ps.TP} | {ps.FN}")
print(f"  {ps.FP} | {ps.TN}")
# Out:
#   0 | 0
#   0 | 0

# %%
Accuracy = (ps.TP + ps.TN) / (ps.TP + ps.TN + ps.FP + ps.FN)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-a3ac7ac429aa> in <module>
# ----> 1 Accuracy = (ps.TP + ps.TN) / (ps.TP + ps.TN + ps.FP + ps.FN)
#
# ZeroDivisionError: division by zero

# %%
Recall = ps.TP / (ps.TP + ps.FN)

# %%
Precision = ps.TP / (ps.TP + ps.FP)

# %%
f1_score = 2 * Precision * Recall / (Precision + Recall)

# %%
Accuracy

# %%
Recall

# %%
Precision

# %%
f1_score

# %%
y_v_p = ps.model(ps.X_v_all)
mse = tf.reduce_mean(tf.square(y_v_p - ps.y_v_all), axis=-1)

# %%
np.save(f'{ATTACK_TYPE}-{K_FACTOR}.npy', mse.numpy())
